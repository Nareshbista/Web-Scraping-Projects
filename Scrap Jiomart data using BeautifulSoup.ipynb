# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.jiomart.com/")

# %%
web
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(web.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#  <html lang="en-US"> <head> <title>JioMart: India's online shopping destination</title> <meta charset="utf-8"/> <meta content="INDEX,FOLLOW" name="robots"/> <meta content="India's online shopping destination for Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty, and more. Great Offers. Low Prices. Easy Returns. Pay on Delivery. Top Brands." name="description"> <meta content="Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty" name="keywords"> <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/> <meta content="#ffffff" name="theme-color"> <link href="https://www.jiomart.com/manifest.json" rel="manifest"/> <link href="https://www.jiomart.com/assets/ds2web/jds-icons/favicon.svg" rel="icon" type="image/x-icon"> <link href="https://www.jiomart.com/" rel="canonical"/> <meta content="JioMart" property="og:site_name"/> <meta content="website" property="og:type"/> <meta content="JioMart: India's online shopping destination" property="og:title"/> <meta content="India's online shopping destination for Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty, and more. Great Offers. Low Prices. Easy Returns. Pay on Delivery. Top Brands." property="og:description"/> <meta content="https://www.jiomart.com/" property="og:url"/> <meta content="https://www.jiomart.com/assets/global/logo-fb.png" property="og:image"/> <!-- Appple Touch Icons --> <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png" rel="apple-touch-icon" sizes="48x48"/> <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/> <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-128x128.png" rel="apple-touch-icon" sizes="128x128"/> <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-256x256.png" rel="apple-touch-icon" sizes="256x256"/> <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png" rel="apple-touch-icon"/> <meta content="app-id=com.jpl.jiomart" name="google-play-app"/> <meta content="app-id=1522085683" name="apple-itunes-app"/> <link href="https://www.jiomart.com/manifest.json" rel="manifest"/> <link href="https://www.jiomart.com/assets/version1729101399/ds2web/css/bootstrap.min.css" rel="stylesheet" type="text/css"> <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/ds2_layout.min.css?v=1729854523" rel="stylesheet" type="text/css"> <link href="https://cdn.jsdelivr.net/npm/@algolia/autocomplete-theme-classic" rel="stylesheet"> <link href="https://www.jiomart.com/assets/version1729101399/ds2web/css/swiper.min.css" media="all" rel="stylesheet" type="text/css"> <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/home-cms.min.css" media="all" rel="stylesheet" type="text/css"> <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/ds2-home-cms.min.css" media="all" rel="stylesheet" type="text/css"> <script>
# function noImageError(element){
#     if(element != undefined && element != null){
#         element.error = null;
#         element.src = window.location.origin+"/assets/global/jiomart-default-image-312x420.png";
#     }
# }
# localStorage.removeItem("controlled_serviceability_data");
# document.cookie = "onep=; Max-Age=-99999999;";
# window.productExists = [];
# window.searchKeyData = {};
# window.bannerKeyData = {};
# window.dimension18 = null;
# window.dimension24 = null;
# window.dimension25 = null;
# window.dimension26 = null;
# window.dimension27 = null;
# window.noresult = false;
# window.google_location_api_key = 'AIzaSyB5sQgEo5BdIkJTyrebFTXUvd3b7_nN284';
# window.default_pin = '400020';
# window.default_city = 'Mumbai';
# window.default_state = 'MH';
# window.algolia_filter = false;
# window.algolia_app_id = "3YP0HP3WSH";
# window.algolia_api_key = "aace3f18430a49e185d2c1111602e4b1";
# window.algolia_suffix = 'prod_mart';
#     let cat_config = '2,8582,4,3,8583,1524,6047,6';
#     window.navigation = {
#         allowed_cats:cat_config,
#         source:'algolia',
#         limit:'8'
#     }
# window.personalised = {
#     api_url:'/api/v1/customer/personalizedproducts',
#     limit:'10'
# }
# window.multivertical = JSON.parse('{"status":1,"GROCERIES":"PREMIUMFRUITS"}');
# window.product_image_path = "";
# window.product_image_path = "https://www.jiomart.com/";
#
# window.location_api = "AIzaSyB5sQgEo5BdIkJTyrebFTXUvd3b7_nN284";
# window.default_vertical_city_code = JSON.parse('{"BEAUTY":["PANINDIABEAUTY"],"ELECTRONICS":["PANINDIADIGITAL"],"FASHION":["PANINDIAFASHION"],"GROCERIES":["6217","PANINDIAGROCERIES"],"JEWELLERY":["PANINDIAJEWEL"],"PREMIUMFRUITS":["S575"]}');
# /* window.inventory_store_code = JSON.parse(''); */
# window.locked_phone_html = '';
# window.slideExists = [];
# window.classExists = [];
# window.journeyData = "JM REGULAR";
# window.listResponse = {};
# window.feedback_categories = null;
#     window.emi_design = 'accordion';
# window.autocomplete_inventory = '0';
# window.preorder_status = '0';
# window.multivertical = JSON.parse('{"status":1,"GROCERIES":"PREMIUMFRUITS"}');
# if(!localStorage.getItem('nms_mgo_pincode')){
#     localStorage.setItem('nms_mgo_pincode',window.default_pin);
#     localStorage.setItem('nms_mgo_city',window.default_city);
# }
# window.fynd_api_url = '/platform/logistics/api/v1/promise';
# window.fynd_token = 'cU8ycF93UWtx';
# window.fynd_app_id = 'NWVhNjgyMWIzNDI1YmIwN2M4MmEyNWMx';
# window.fynd_sample_prod = JSON.parse('{"article_id":"491504124","vertical":"GROCERIES","lookup_inventory":false,"tenant_ids":["1003","1008","1007"],"merchant_id":"1"}');
# window.wishlist_api = "/bamboo/api/v2/catalog/mywishlist";
# window.smart_seller_id = '1';
# window.exchange_status = '0';
# window.popular_categories = JSON.parse('[{"name":"Groceries","url_path":"/c/groceries/2","vertical_code":"GROCERIES","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/grocery.png?v=1673368517"},{"name":"Premium fruits","url_path":"/c/premiumfruits/6047","vertical_code":"PREMIUMFRUITS","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/fruits.png?v=1673368517"},{"name":"Home & Kitchen","url_path":"/c/homeandkitchen/8582","vertical_code":"HOMEANDKITCHEN","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/home_kitchen.png?v=1673368517"},{"name":"Fashion","url_path":"/c/fashion/3","vertical_code":"FASHION","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/fashion.png?v=1673368517"},{"name":"Electronics","url_path":"/c/electronics/4","vertical_code":"ELECTRONICS","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/electronics.png?v=1673368517"},{"name":"Jewellery","url_path":"/c/jewellery/1524","vertical_code":"JEWELLERY","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/jewellery.png?v=1673368517"},{"name":"Home Improvement","url_path":"/c/homeimprovement/8583","vertical_code":"HOMEIMPROVEMENT","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/home_improvement.png?v=1673368517"},{"name":"Wellness","url_path":"/c/wellness/6","vertical_code":"WELLNESS","thumbnail_image_path":"images/cms/section/category-url/12806/6.png"}]');
# window.nms_tracker =  "Category List";
# if(localStorage.getItem("nms_product_tracker") != null && localStorage.getItem("nms_product_tracker") != ""){
#     window.nms_tracker =  localStorage.getItem("nms_product_tracker");
#     localStorage.removeItem("nms_product_tracker");
# }
# if(localStorage.getItem("nms_promo_tag") != null && localStorage.getItem("nms_promo_tag") != ""){
#     window.searchKeyData =  localStorage.getItem("nms_promo_tag");
#     localStorage.removeItem("nms_promo_tag");
# }
# if(localStorage.getItem("nms_banner_tag") != null && localStorage.getItem("nms_banner_tag") != ""){
#     window.bannerKeyData =  localStorage.getItem("nms_banner_tag");
#     localStorage.removeItem("nms_banner_tag");
# }
# window.plp_collection_expiry = 0;
# window.plp_collection_expiry = 1;
# window.pdp_separate_tab = false;
# function pdpSeparateTab(){
#     var appseparate_tabVersion = localStorage.getItem("jio_app_version");
#     var appseparate_tabOs = localStorage.getItem("jio_app_os");
#     window.pdp_separate_tab = false;
#     var nativeFlagseparate_tab = null;
#     var iosseparate_tabVersion = "";
#     var androidseparate_tabVersion = "";
#                 nativeFlagseparate_tab = {'app':{'status':'Y','appVersion':'2.0.11.99','iosVersion':'2.0.10.99'}, 'myjio':{'status':'N','appVersion':'7.0.39.99','iosVersion':'7.0.39.99'}, 'web':{'status':'N'}};
#         if(nativeFlagseparate_tab){
#             if(nativeFlagseparate_tab != ""){
#                 if(nativeFlagseparate_tab.hasOwnProperty('web') && nativeFlagseparate_tab.web.hasOwnProperty('status')){
#                     if(nativeFlagseparate_tab.web.status == "Y"){
#                         window.pdp_separate_tab = true;
#                     }
#                 }
#             }
#         }
#     }
# pdpSeparateTab();
# </script> <script>
#     window.jioads_product_ad = JSON.parse('{"status":1,"mnp":10,"ai":"jiomart.com","vr":"WEB-1.8.2","os":"3","get_ads_api":"https://ads.jiomart.com/ads/ad-server/getAds","impression_api":"https://ads.jiomart.com/ads/ad-token-server/token/impressions","click_api":"https://ads.jiomart.com/ads/ad-token-server/token/clicks","slot":6,"sp_slot":"2,5,8,12","fbt_slot":"1,4,8,12","pdp_mnp":10,"pdp_status":1,"sdk_tracking":0,"sdk_params":0,"custom_slot":"2,6,12,18,24,30,36,42,48,54","pdp_title":"You may also like","pdp_pos":"top","pdp_sub_title":"","pdp_min":1,"pdp_max":20,"newplp_slot":"2, 9, 10, 17, 18, 25, 26, 33, 34, 41"}');
#     </script> <script>
#     window.filter_verticals = 'ALL';
#
#     window.scheduled_delivery = JSON.parse('{"message":"Scheduled Delivery by $$$","duration":5,"append":1}');
#
#     window.algolia_status = JSON.parse('{"suggestions":1,"products":1,"brands":1,"categories":1,"showcart":1}');
#
#     window.mylist_pincode_status = JSON.parse('1');
#
# </script> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-NQLHTD8');</script>
# <!--script async src="https://jioadsweb.akamaized.net/jioads/retargeting/default/stable/v2/jioAds.js" crossorigin="anonymous"></script--> <style> .expand-content{ max-height:250px; overflow:hidden; } #btn_deli_username, #sign_in_text{ text-transform:capitalize; } .swiper-button-disabled button{ opacity:0.2; } /*.swiper-button-lock{ display:block !important; }*/ .size_chartBtn {display:none;} .size_chartBtn.active {display:block; color: #0c5273; float: right; font-weight: 500; font-size: 13px;} .jm-modal-open { overflow:hidden; } .compare_icons, .section-offers { display: none;} .selected_container, .product-card-selected.inactive, .product_selection_section.inactive, .showedProducts.inactive, .your_choice.inactive, .select-disable.inactive, .product_compare_added, .added_pdp_count, .is_cart_status, .other_products.inactive{ display: none; } .recommended-product-card-separator{ padding-right:10px; padding-left:10px; } .smart-bazaar .search-discover{ display:none; } .smart-bazaar #btn_deli_username{ display:none; } </style>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch","rua.ceh":"false","rua.ueh":"false","rua.ieh.st":"0"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="5CJLF-ZA3SK-VL8ML-YPN3B-2NPBS",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"5CJLF-ZA3SK-VL8ML-YPN3B-2NPBS";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="onrcuidujl7rczy3pxlq-f-50d6d25f6-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"39","ak.cp":"1422322","ak.ai":parseInt("871072",10),"ak.ol":"0","ak.cr":178,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"11ad347","ak.r":8809,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"115.98.42.0","ak.cport":64540,"ak.gh":"116.74.255.13","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.0rtt.ed":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1729854935","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"16","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.0rtt.ed","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></link></link></link></link></link></link></link></meta></meta></meta></head> <body class="jio-web cms-home jiomart_home home_overflow_hidden"> <script>
#     if (window.location.pathname == "/") {
#         if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#             localStorage.removeItem("jio_smart_bazaar");
#             localStorage.removeItem("jio_category_tree");
#             localStorage.removeItem("jio_smart_delivery_time");
#         }
#     }
#     localStorage.removeItem("jio_smart_bazaar");
#     localStorage.removeItem("smart_cart_info");
#     localStorage.removeItem("jio_smart_cart_id");
#
#     /*if (window.location.pathname == "/smart-bazaar") {
#         localStorage.setItem("jio_smart_bazaar", "yes");
#         localStorage.removeItem("jio_category_tree");
#     }
#
#     if (localStorage.getItem("jio_smart_bazaar") == "yes") {
#         document.getElementsByTagName('body')[0].classList.add("smart-bazaar");
#     }*/
# </script> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NQLHTD8" style="display:none;visibility:hidden" width="0"></iframe></noscript> <style>#main_category_top .vertical_banner .home-item-info .home_ripple .vertical_img {width: 70px !important;height: 100% !important;}.lazyload{min-width:0px !important}.lazyloading{min-width:0px !important}#main_category_top .vertical_banner .swiper-slide{aspect-ratio:1;max-height: 70px;}.gpay-jiomartapp #main-banner[data-id="section_149"]{display:none !important}.time-deal-section, .gpay-jiomartapp #item_1_71_17357, .myjiostore #item_1_71_17357,.gpay-jiomartapp #section_2572,.myjiostore #section_2572,.gpay-jiomartapp #section_2994,.gpay-jiomartapp #main-banner_new[data-id="section_2870"],.gpay-jiomartapp #main-banner_new[data-id="section_1242"],.nms-mobistore #item_1_4134_25632,.nms-mobistore.myjiostore #section_4134,.nms-mobistore.gpay-jiomartapp #section_4134{display:none} .nms-mobistore.jiomartapp #item_1_4134_25632{display:block !important}.new_arrival_section .products_swipe .swiper-slide .pro_items a .cat-img img{max-height:150px;display: flex;margin: 0 auto; width:auto !important}.explore-cat-list img{width: 100%;height: auto;}@supports (-webkit-touch-callout: none) {.widget-product-card-details{min-height:85px !important}} .jio-web .saleday_timer_ds2 .teaser-banner .teaser-content {right: 390px;}</style> <style> .offers-landing-page .copy-code{display:none} #vertical_banner .swiper-slide{width:unset !important} .empty_listing{text-align: center;}.cms-smart-bazaar span{font-size: 14px;} .all-product .product-card-details {min-height:92px; }.widget-product-card-box .swiper-container{padding-right:8px} .jiomart_home .section-seperate{ height:unset} .ds2_json_animation .animation_content svg{ min-height: unset;} .product-return-text ul{list-style-type: disc; padding-left: 20px; } .product-return-text ul li{margin-bottom: 4px;} .header-nav-container .category-ds2-name .ds-categories-menu{ line-height: 18px !important; height: 48px !important;} .cms-home .algolia_products_card_ds2, .cms-home .new_top_deals_product_section_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 { background: #FFE68E !important; max-width: unset !important; padding: 24px 0 !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base { max-width: 1184px !important; margin: 0 auto !important; padding-bottom: 16px !important;} .cms-home .algolia_products_card_ds2 .widget-product-card-box, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box { max-width: 1184px !important; margin: 0 auto !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2 { color: #AA0505 !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-details, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details { padding: 0 12px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container{ background: #fff !important; border-radius: 16px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-pro ...
#         if(localStorage.getItem("nms_mgo_pincode") && localStorage.getItem("nms_mgo_city")){
#             let city_name = localStorage.getItem("nms_mgo_city");
#             if(city_name.length > 10){
#               city_name = city_name.substring(0,8)+'..';
#             }
#             let delivery_city_pin = city_name+" "+localStorage.getItem("nms_mgo_pincode");
#             document.getElementById("delivery_city_pincode").textContent = delivery_city_pin;
#         }
#
#         if(localStorage.getItem("display_ship_name")){
#             let ship_name = localStorage.getItem("display_ship_name");
#             ship_name = ship_name[0].toUpperCase()+ (ship_name.slice(1)).toLowerCase();
#             if(ship_name.length > 10){
#               ship_name = ship_name.substring(0,8)+'..';
#             }
#             document.getElementById("btn_deli_username").innerHTML = ship_name+",&nbsp;";
#         }
#
#         if(localStorage.getItem("displayname")){
#             let user_name = localStorage.getItem("displayname");
#             if(user_name.length > 8){
#               user_name = user_name.substring(0,8)+'..';
#             }
#             //document.getElementById("sign_in_text").textContent = user_name;
#             document.getElementById("ham_user_name").innerHTML = 'Hello '+localStorage.getItem("displayname")+'!';
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn tertiary small jm-icon" href="/customer/account"><img alt="Go to profile" src="https://www.jiomart.com/assets/ds2web/jds-icons/profile-icon.svg" /></a>';
#         }
#         else{
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn secondary small jm-fc-white" href="/customer/account/login">Sign In</a>'
#         }
#
#         if(localStorage.getItem("userid") && localStorage.getItem("userid") != '0'){
#             document.getElementById("btn_sign_in").style.display = 'none';
#             //document.getElementById("sign_in_text").style.display = 'none';
#             document.getElementById("user_initial").style.display = 'flex';
#             //document.getElementById("jm_header_user_icon").style.display = 'none';
#             //document.getElementById("sb_header_user_icon").style.display = 'none';
#             let firstname = localStorage.getItem("displayname");
#             let lastname = localStorage.getItem("displaylastname");
#             let initial = firstname.charAt(0);
#             if(lastname != null && lastname != 'null'){
#                 initial += lastname.charAt(0);
#             }
#             document.getElementById("user_initial").innerText = initial;
#         }
#         else{
#             //document.getElementById("sign_in_text").style.display = 'block';
#             document.getElementById("user_initial").style.display = 'none';
#             document.getElementById("btn_sign_in").style.display = 'flex';
#             /*if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#                 document.getElementById("sb_header_user_icon").style.display = 'block';
#             }
#             else{
#                 document.getElementById("jm_header_user_icon").style.display = 'block';
#             }*/
#
#         }
#         //document.getElementById("btn_sign_in").style.display = "inline-flex";
#     </script> <main class="main"> <section class="main-section main-container jm-w-100"><div class="jiomart_maincontent" data-totalpages="6"> <div class="static-page-content"> <!--ds2.0 body width --> <!-- <div class="home-content static-page-content" > --> <!-- old theme style --> <style> .sec_custom_height15765{ height:48px !important; } </style> <!-- prev class deals-trending-banner --> <!--section id="section_15765" class="deals-trending-banner" data-mydelay="5000"--> <section class="home-content-ds2 hero_banner_ds2" data-id="section_15765" data-jioads-adspot="" data-mydelay="5000" data-page-id="1" id="section_15765"> <div class="hero_top_carousel_ds2" data-mydelay="5000" id="section_15765"> <div class="gtm_data" data-height="" data-id="15765" data-name="HPMC_Jioutsav Wave 3" data-position="" data-type="banner" data-width=""></div> <div class="home-trending-offer ds2-home-trending-offer" data-id="section_15765"> <div class="jm-d-flex jm-jc-space-between jm-ai-center jm-mb-base"> <!-- <div class="clearfix"></div> <span></span> <small></small> --> </div> <div class="clearfix"></div> <div class="ds2-swiper-arrow"> <div class="swiper-container home-trending-slides hero_top_carousel_ds215765" id="hero_section_15765"> <div class="swiper-wrapper" data-jioads-adspot="" data-slide-count="12" id="hero_web_jioads_ds2-15765"> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70113"> <a class="home_ripple" href="https://www.jiomart.com/sections/apple-iphone-16-deals" rel="nofollow" title="Top Deals_mpc_iphone16hpmc"> <img alt="Top Deals_mpc_iphone16hpmc" class="banner_img" data-src="" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)" title="Top Deals_mpc_iphone16hpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70208"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977" rel="nofollow" title="Top Deals_mpc_oppok12hpmc"> <img alt="Top Deals_mpc_oppok12hpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729744481_OppoK12x5G.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729744481_OppoK12x5G.jpg?im=Resize=(384,224)" title="Top Deals_mpc_oppok12hpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70124"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/jewels_100/23912?prod_mart_master_vertical%5Bpage%5D=2&amp;prod_mart_master_vertical%5BsortBy%5D=prod_mart_master_vertical_products_popularity&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=Gold%20Coins&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B1%5D=Silver%20Coins&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B2%5D=Gold%20Bars&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B3%5D=Silver%20Bars&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B4%5D=Silver%20Coins%20%26%20Bars" rel="nofollow" title="Top Deals_fnl_dhanterashpmc"> <img alt="Top Deals_fnl_dhanterashpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729745929_Gold__Silver_coins_.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729745929_Gold__Silver_coins_.jpg?im=Resize=(384,224)" title="Top Deals_fnl_dhanterashpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70216"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/homepagekaju-katli-starting-rs-289-400g/33995" rel="nofollow" title="Top Deals_gro_kajuburfihpmc"> <img alt="Top Deals_gro_kajuburfihpm ...
# {
#     "@context" : "http://schema.org",
#     "@type" : "WebSite",
#     "url" : "https://www.jiomart.com/",
#     "logo": "https://www.jiomart.com/assets/smartweb/images/jiomart_logo.svg",
#     "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://www.jiomart.com/catalogsearch/result?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#     },
#     "sameAs": [
#         "https://www.facebook.com/JioMartOfficial/",
#         "https://twitter.com/JioMart",
#         "https://www.instagram.com/jiomartofficial"
#     ],
#     "contactPoint" : [
#         { "@type" : "ContactPoint",
#         "telephone" : "18008901222",
#         "email":"cs@jiomart.com",
#         "contactType":"customer service"
#         }
#     ]
# }
#  </script> <script type="text/javascript">
#  var page_name = 'home';
#  var page_identifier = 'home';
#  var page_type = '';
#      var review_enabled = '';
#  var page_log= '1';
#  var mrp_label = 'M.R.P:';
#  var uom_unit =  '{"centimeter":"cm","millimeter":"mm","meter":"m","gram":"g","milligram":"mg","kilogram":"kg","litre":"L","Millileter":"ml","millimeters":"mm","GM":"g","litres":"L","milliliter":"ml","liter":"L","grams":"g","cms":"cm","gms":"g","cubic cm":"ml"}';
#  //var lightning_label = 'LIMITED TIME DEAL';
#  var lightning_label = 'Limited Time Deal';
#  var ds2_lightning_label = '<img src="/assets/ds2msite/jds-icons/flash-t50-s-icon.svg">Limited Time Deal';
#  var ds2_pdp_lightning_label = 'Limited Time Deal';
#  var uom_attribute = '1';
#  var return_content = '';
#  var cancel_content = '';
#  var cart_label =  '{"jiomart" : "", "smartbazaar" : "", "commontoast":"Added to cart", "enable":"1"}';
#  var festive_header_view_count = '1';
#  var festive_header_android_ios_view_count = '1';
#
#  var ds2_seo_footer_heading_content = 'yes';
#  </script> <input id="mstar_api_baseurl" type="hidden" value="https://www.jiomart.com/mst/rest/v1/"/> <input id="mst_api_cart_pin_baseurl" type="hidden" value="/mst/rest/v1/5/"/> <input id="egift_url" type="hidden" value="/api/v1/offers/egiftlist"/> <input id="gtm_status" name="gtm_status" type="hidden" value="1"/> <input id="url_pincode" type="hidden" value="1"/> <script async="" src="https://www.jiomart.com/assets/ds2web/js/lazysizes-umd.min.js" type="text/javascript"></script> <script crossorigin="anonymous" src="https://www.jiomart.com/assets/ds2web/js/jquery-3.4.1.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery-ui.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/bootstrap.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/clipboard.min.js" type="text/javascript"></script> <!-- <script type="text/javascript" src="https://www.jiomart.com/assets/ds2web/js/swiper.min.js" defer crossorigin="anonymous"></script> --> <script src="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.js"></script> <script type="text/javascript">
# 				var package_name = 'jiomart.com';
# 				var languageofArticle = 'english';
# 				//var page_name = 'home';
# 				var jioads_log= '1';
#
# 				var chk_jio_status = 1;
#
#                 var jioads_ads_list = '';
#                 var jioad_general_config = JSON.parse('{"status":1,"mnp":10,"ai":"jiomart.com","vr":"WEB-1.8.2","os":"3","get_ads_api":"https://ads.jiomart.com/ads/ad-server/getAds","impression_api":"https://ads.jiomart.com/ads/ad-token-server/token/impressions","click_api":"https://ads.jiomart.com/ads/ad-token-server/token/clicks","slot":6,"sp_slot":"2,5,8,12","fbt_slot":"1,4,8,12","pdp_mnp":10,"pdp_status":1,"sdk_tracking":0,"sdk_params":0,"custom_slot":"2,6,12,18,24,30,36,42,48,54","pdp_title":"You may also like","pdp_pos":"top","pdp_sub_title":"","pdp_min":1,"pdp_max":20,"newplp_slot":"2, 9, 10, 17, 18, 25, 26, 33, 34, 41"}');
#                 var video_play_enable = '0';
#                 var ios_video_ads = ''
#                 if(/^((?!chrome|android).)*safari/i.test(navigator.userAgent)){
#                     ios_video_ads = 'ios-video-jioads';
#                 }
#                 if($("body").hasClass('jm-ios')) {
#                     ios_video_ads = 'ios-video-jioads';
#                 }
#         </script> <script crossorigin="anonymous" src="https://jioadsweb.akamaized.net/jioads/retargeting/default/stable/v2/jioAds.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/jio_ads_script_ds2.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://cdn.jsdelivr.net/npm/@algolia/autocomplete-js"></script> <!-- <script src="https://www.jiomart.com/assets/ds2web/js/algolia-autocomplete.min.js" defer crossorigin="anonymous"></script> <script src="https://cdn.jsdelivr.net/algoliasearch/3/algoliasearch.min.js" defer crossorigin="anonymous"></script> <script src="https://cdn.jsdelivr.net/npm/algoliasearch@4.5.1/dist/algoliasearch-lite.umd.js" crossorigin="anonymous"></script> --> <script crossorigin="anonymous" src="https://cdn.jsdelivr.net/npm/algoliasearch@4.5.1/dist/algoliasearch.umd.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.cookie.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/bootstrap.notify.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.validate.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/lottie.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.md5.min.js" type="text/javascript"></script> <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script> <script>
#     $(document).ready(function () {
#         $('.combo-view-more').click(function(){
#             var target = $(this).attr("data-target");
#             $(target).modal();
#         });
#     });
# </script> <script>
#     $(document).ready(function(){
#         var userId = localStorage.getItem('userid');
#         var authToken = localStorage.getItem('authtoken');
#         var displayName = localStorage.getItem('displayname');
#         var login_pincode = localStorage.getItem('nms_mgo_pincode');
#                 if(login_pincode && (login_pincode !="")) {
#             $.cookie("nms_mgo_pincode", login_pincode, { expires : 1, path    : '/' });
#         }
#     });
# </script> <script type="text/javascript">
# $(document).ready(function () {
#     localStorage.removeItem('loginpage');
#     window.user_id     = (localStorage.getItem('userid')!=null) ? localStorage.getItem('userid'):"" ;
#     window.auth_token  = (localStorage.getItem('authtoken')!=null) ? localStorage.getItem('authtoken'):"";
#     window.cust_dname  = (localStorage.getItem('displayname')!=null) ? localStorage.getItem('displayname'):"";
#         window.login_session = {
#       "async": true,
#       "crossDomain": true,
#       "url": "https://www.jiomart.com/mst/rest/v1/entity/customer/get_details",
#       "method": "GET",
#       "headers": {
#         "userid": window.user_id,
#         "authtoken": window.auth_token
#       }
#     };
#     if((user_id!="" && user_id != 0) && (cust_dname!="")){
#         $('.login #logged_user').text("");
#         $('.login #logged_user').append(cust_dname);
#         $('.login a:first').hide();
#         $('.login #logged_user').show();
#         $("#customer-name").text("Hello, "+cust_dname);
#         $("#profile-link").attr("href","/customer/account");
#         $("#sign_in_out").text('Logout').attr("href","/customer/account/logout");
#     } else {
#         $('.login #logged_user').hide();
#         $('.login a:first').show();
#     }
#         $('.logged').show();
# });
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_main.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_delivery.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_recommended.min.js" type="module"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/main.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/cart.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/autocomplete_widget.min.js" type="module"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/url.min.js" type="text/javascript"></script> <script>
#     function isInViewport(el) {
# 		var rect = el.getBoundingClientRect();
# 		return (
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.bottom <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
# 		);
# 	}
# 	function isSlideInViewport(el) {
# 		const rect = el.getBoundingClientRect();
# 		return (
# 			(rect.right >= 0) &&
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.bottom <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
#
# 		);
# 	}
# 	function isCategoryViewport(el) {
# 		const rect = el.getBoundingClientRect();
# 		return (
# 			(rect.top > 0 || rect.bottom > 0) &&
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.top <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
#
# 		);
# 	}
# 	function elementViewport(ele) {
# 		const { top, bottom } = ele.getBoundingClientRect();
# 		const vHeight = (window.innerHeight || document.documentElement.clientHeight);
#
# 		return (
# 			(top > 0 || bottom > 0) &&
# 			top < vHeight
# 		);
# 	}
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_scripts.min.js"></script> <!-- <script type="module" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_main.min.js" defer crossorigin="anonymous"></script> --> <script>
#     let jioads_pkg_name = 'jiomart.com';
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_scripts_all_page.min.js"></script> <script>
#         $(document).ready(function(){
#             if((localStorage.getItem('paynowID')) && (localStorage.getItem('paynowID')!=='')){
#                 localStorage.removeItem('paynowID');
#                 localStorage.removeItem('m2_errlist');
#             }
#         });
#     </script> <script>
# function getPageType(){
#     var pageType = 'other pages';
#     if($("body").hasClass("cms-home")){
#         pageType = "Home Page";
#     }else if($("body").hasClass("catalog-category-view")){
#         pageType = "category page";
#     }else if($("body").hasClass("catalog-product-view")){
#         pageType = "Product Details Page";
#     }
#     else if($("body").hasClass("search-result-page")){
#         pageType = "Search Page";
#     }
#     return pageType;
# }
#
# function trackGoogleEvents(category,action,label){
#     if("ga"in window){
#         tracker=ga.getAll()[0];
#         if(tracker){
#             tracker.send("event",category,action,label);
#         }
#     }
# }
#
#
# $(document).ready(function(){
#     $(".add_to_cart_fixed .cartbag").click(function(){
#         trackGoogleEvents("New Click actions","Add to cart button","Product Holder");
#     });
#
#     $("#search").focus(function(){
#         trackGoogleEvents("New Click actions","Search","");
#     });
#
#     $(".mini-cart").click(function(){
#         var pageType = 'other pages';
#         if($("body").hasClass("cms-home")){
#             pageType = "home page";
#         }
#         else if($("body").hasClass("catalog-category-view")){
#             pageType = "category page";
#         }
#         else if($("body").hasClass("catalog-product-view")){
#             pageType = "product page";
#         }
#         trackGoogleEvents("New Click actions","Cart",pageType);
#     });
#
#
#     $(".home-slides .swiper-slide").click(function(){
#         trackGoogleEvents("Home Banner","Primary Banners","Home Page");
#     });
#
#     $(".home-category-swipe .swiper-slide").click(function(){
#         var catname = $(this).find(".clsgetname").text();
#         trackGoogleEvents("Home Explore Categories",catname,"Home Page");
#     });
#
#     $(".home-best-seller .swiper-slide").click(function(){
#         var prodname = $(this).find(".clsgetname").text();
#         trackGoogleEvents("Home Best Sellers",prodname,"Home Page");
#     });
#     });
# </script> <script>
# if ('serviceWorker' in navigator) {
#     window.addEventListener('load', () => {
#         navigator.serviceWorker.register('/service-worker.js?v=1680183837', {
#           scope: '/'
#         });
#     });
# }
# </script> <script>
#   var ALGOLIA_INSIGHTS_SRC = "//cdn.jsdelivr.net/npm/search-insights@1.3.1";
#
#   !function(e,a,t,n,s,i,c){e.AlgoliaAnalyticsObject=s,e[s]=e[s]||function(){
#   (e[s].queue=e[s].queue||[]).push(arguments)},i=a.createElement(t),c=a.getElementsByTagName(t)[0],
#   i.async=1,i.src=n,c.parentNode.insertBefore(i,c)
#   }(window,document,"script",ALGOLIA_INSIGHTS_SRC,"aa");
#
#
#   // Initialize library
#   aa('init', {
#     appId: window.algolia_app_id,
#     apiKey: window.algolia_api_key
#   });
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/seo-optimization-link.min.js" type="text/javascript"></script> <script src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/topdeals_home.min.js" type="module"></script> <script src="https://www.jiomart.com/assets/version1729101399/ds2web/js/home.min.js"></script> <script>
#     $(document).ready(function(){
#         if(window.pdp_separate_tab == true){
#             window.addEventListener('storage', function(event) {
#                 if (event.storageArea === localStorage) {
#                     var redirectionUrl = false;
#                     redirectionUrl = storageUpdate(event);
#                     if(redirectionUrl == true){
#                         window.location.reload(true);
#                     }
#                 }
#             });
#         }
#     });
#     function storageUpdate(event){
#         if(window.pdp_separate_tab == true){
#             if(event.key == "nms_mgo_pincode" || event.key == "userid" || event.key == "authtoken"){
#                 if(event.newValue != undefined && event.newValue != event.oldValue){
#                     return true;
#                 }
#             }
#             if(event.key == "cart_info"){
#                 if(event.newValue != undefined && event.newValue != event.oldValue){
#                     resetCartBtn();
#                     applyPlusMinusButton();
#                     var cart_info = JSON.parse(localStorage.getItem('cart_info'));
#                     if(localStorage.getItem('jio_store_id')){
#                         var cart_info = JSON.parse(localStorage.getItem('pickup_cart_info'));
#                     }
#                     var cart_count = 0;
#                     if (cart_info) {
#                         var cart_prods = cart_info.cart.lines;
#                         cart_count = cart_prods.length;
#                         $(cart_prods).each(function (i, prod) {
#                             var promo_seller_id = "";
#                             var sku = prod.product_code;
#                             var targetSku = $($('.jm-btn[data-sku="'+sku+'"]'));
#                             var bestCart = "";
#                             var prodpage = false;
#                             var vertical = $("#vertical_code").val();
#                             if(targetSku.length > 0){
#                                 if($(targetSku).hasClass('prodbtn')){
#                                     prodpage = true;
#                                 }
#                                 if(prod.qty > 0){
#                                     let seller_id = $(targetSku).attr("data-sellerid");
#                                     $(".jm-btn[data-sku='"+sku+"'][data-sellerid='"+seller_id+"']").each(function(i,el){
#                                         let targetBtn = $(el);
#                                         $(targetBtn).prop('disabled',false);
#                                         $(targetBtn).next().next().prop('disabled',false);
#                                         $(targetBtn).next().next().removeClass('disabled');
#                                         $(targetBtn).next().text(prod.qty);
#                                     });
#
#                                     if($(targetSku).closest("#pdp_best_deals_products").length > 0){
#                                         $("#pdp_best_deals_products .addtocartbtn").prop("disabled",false);
#                                     }
#                                     if($('body').hasClass('otc-product-page')){
#                                         if($(targetSku).closest('.pdp_deals_promo') != null){
#                                             if($(targetSku).closest('.pdp_deals_promo').attr("id") != null){
#                                                 bestCart = "#"+$(targetSku).closest('.pdp_deals_promo').attr("id");
#                                                 applyPlusMinusButton(bestCart);
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         });
#                     }
#                     if(cart_count > 0){
#                         $(".mini-cart .counter-number").text(cart_count).show();
#                     }
#                     else{
#                         $(".mini-cart .counter-number").text(cart_count).hide();
#                     }
#                     return false;
#                 }
#             }
#         }
#     }
#
#     function resetCartBtn(){
#         $(".jm-btn[data-sku]").each(function(index,element){
#             var prod_promo_seller_id = "";
#             var productSku = "";
#             productSku = $(element).attr("data-sku");
#             if($(element).closest("#pdp_best_deals_products").length > 0){
#                 // $("#pdp_best_deals_products .addtocartbtn").prop("disabled",false);
#                 prod_promo_seller_id = $(element).attr("data-sellerid");
#                 var btn_html = `<button class="jm-btn small secondary full-width jm-body-s-bold jm-jc-center toCart addtocartbtn best_cart" data-sellerid="${prod_promo_seller_id}" data-sku="${productSku}"> Add To Cart </button>`;
#                 $("#pdp_best_deals_products .product-card-wrapper").find(".is_cart_status").removeClass("active");
#                 $(element).parent().parent().html(btn_html);
#             } else {
#                 if($(element).hasClass("jm-btn")){
#                     let prod_seller_id = $(element).attr("data-sellerid");
#                     $(".jm-btn[data-sku='"+productSku+"'][data-sellerid='"+prod_seller_id+"']").each(function(i,el){
#                         let targetBtn = $(el);
#
#                         let parent_class = targetBtn.parent().attr("data-parentbtn-class");
#                         let parent_text = targetBtn.parent().attr("data-parentbtn-text");
#                         let parent_image = targetBtn.parent().attr("data-parentbtn-image");
#                         let is_prod_btn = targetBtn.parent().hasClass("prodpage");
#
#                         let el_seller_id = targetBtn.attr("data-sellerid");
#                         if(is_prod_btn){
# ...
#                         <span class="txt_btn">Add to Cart</span>
#                         <span class="add_plus"></span>
#                     </button>`;
#                     $(element).parent().parent().html(btn_html);
#                 }
#             }
#         });
#     }
# </script> <script>
# function JioAdsImpression(placementId=""){
#         var insElements;
#         if(placementId != ""){
#             insElements = $("ins[id='" + placementId + "']:not(.viewed)");
#         }
#         if(insElements && placementId != ""){
#             $(insElements).each(function(insIndex,insElement){
#                 if($(insElement).find("iframe").length > 0){
#                     var iframesContent = $(insElement).find("iframe").contents();
#                     if(iframesContent != undefined && iframesContent != null && iframesContent != ""){
#                         $(iframesContent.find('img')).each(function(index,element){
#                             if(element.src.indexOf("ADSIMPRESSION") > -1){
#                                 if(($.inArray(placementId , window.slideExists) === -1)){
#                                     window.slideExists.push(placementId);
#                                     if(typeof AdsTriggerUrl !== "undefined"){
#                                         AdsTriggerUrl(element.src,"impression");
#                                     }
#                                     $(insElement).addClass("viewed");
#                                 }
#                             }
#                         });
#                     }
#                 }
#             });
#         }
#     }
# $(document).ready(function(e){
#     if (typeof JioAds === undefined){
#             var jsElm   = document.createElement("script");
#             jsElm.type  = "application/javascript";
#             jsElm.src   = window.jioads_sdk;
#             document.body.appendChild(jsElm);
#         }
#     if(typeof JioAds !== "undefined"){
#         JioAds.onAdViewed = function (placementId) {
#             if(localStorage.getItem("console_log_enable") != undefined && localStorage.getItem("console_log_enable") != null && localStorage.getItem("console_log_enable") == "1"){
#                     console.log("CB: onAdViewed", placementId);
#                 }
# if(typeof JioAdsImpression !== "undefined"){
#                     JioAdsImpression(placementId);
#                 }
#         };
#     }
# });
#
# $(document).ready(function(e){
#     var page_type = "other pages";
#     if(typeof getAllGtmPageType !== "undefined"){
#         page_type = getAllGtmPageType();
#     }
#     localStorage.setItem("page_type", page_type);
#     var platform = "website";
#     if($("body").hasClass("nms-mobistore") || $("body").hasClass("jio-msite")){
#         platform = "msite";
#     }
#     if(localStorage.getItem("jio_app_os") != null && localStorage.getItem("jio_app_os") != undefined ){
#         platform = "app_"+localStorage.getItem("jio_app_os");
#     }
#     localStorage.setItem("platform", platform);
#
# 	var login_status = (localStorage.getItem("userid") != undefined && localStorage.getItem("userid") != "0") ? "logged in" : "not logged in";
#     localStorage.setItem("login_status",login_status);
#
#     if(typeof journeyDataLayer !== "undefined"){
# 		journeyDataLayer();
#         if(window.journeyData){
#             localStorage.setItem("journey",window.journeyData);
#         }
# 	}
# });
# </script><script>
# function newTrackGoogleEvents(category,action,label,value){
#     if("ga"in window){
#         newtracker=ga.getAll()[0];
#         if(newtracker){
#             if(value != null && value != ""){
#                 newtracker.send("event",category,action,label,value);
#             }
#         }
#     }
# }
# $(document).ready(function(){
#     var dealskuValue = "";
#     var dealcartskuValue = "";
#     if($('body').hasClass('cms-home')){
#         $(document).on('click','.cms-home .top_deals.new_product_swiper a', function(e){
#             dealskuValue = $(this).closest("div.pro_items").find(".addtocartbtn").attr('data-sku');
#             if(dealskuValue != null && dealskuValue != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Top Deals - product clicks",dealskuValue);
#             }
#         });
#         $(document).on('click','.cms-home .top_deals.new_product_swiper .addtocartbtn', function(e){
#             dealcartskuValue = $(this).attr('data-sku');
#             if(dealcartskuValue != null && dealcartskuValue != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","Top Deals - clicks on add to cart",dealcartskuValue);
#             }
#         });
#     }
#     if($('body').hasClass('otc-product-page')){
#         $(document).on('click','.dont_forget_products .viewed-items a', function(e){
#             var dont_forget_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(dont_forget_products != null && dont_forget_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Don't Forget to Add - product clicks",dont_forget_products);
#             }
#         });
#         $(document).on('click','.dont_forget_products .viewed-items .addtocartbtn', function(e){
#             var dont_forget_productscart = $(this).attr('data-sku');
#             if(dont_forget_productscart != null && dont_forget_productscart != ""){
#              newTrackGoogleEvents("PDP","Add to Cart","Don't Forget to Add - clicks on add to cart",dont_forget_productscart);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items a', function(e){
#             var liked_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(liked_products != null && liked_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","You may also like - product clicks",liked_products);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items .addtocartbtn', function(e){
#             var liked_productscart = $(this).attr('data-sku');
#             if(liked_productscart != null && liked_productscart != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","You may also like - clicks on add to cart",liked_productscart);
#             }
#         });
#     }
# });
# </script> <div class="policy-backdrop jm-d-none"> <div style="top: 0; left: 0; bottom: 0; width: 100%; z-index: 60; position: fixed; background-color: rgba(0,0,0,.65); transition: cubic-bezier(0.35, 0, 0.5, 1) 500ms;"></div> <div class="privacy-popup"> <div class="close-icon" style="height: 72px;"><button class="jm-btn tertiary medium close-privacy"> <img alt="close icon" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/close-icon.svg"> </img></button></div> <div class="contents-popup"> <div><span class="jm-heading-xs privacy-head">Policy Update</span> <div class="jm-body-s privacy-sub">Please note that our <a class="external_link" href="https://www.jiomart.com/privacy-policy" rel="noopener" target="_blank">Privacy Policy.</a> has been updated and we have also added <a class="external_link" href="https://account.relianceretail.com/privacy-policy/" rel="noopener" target="_blank">Retail Account Privacy Policy</a>. By continuing to use our platform and its services, you consent to the updated policies.</div> </div> <div class="privacy-popup-actions jm-d-flex jm-ai-center"><button class="jm-btn large primary accept_policy" data-sellerid="6746" data-sku="490003796">Agree</button></div> </div> </div> </div> <script>
#     $(window).on('load',function(){
#         var isLoggedIn = false;
#         if( localStorage.getItem('userid') != undefined && localStorage.getItem('userid') != null && localStorage.getItem('userid') != '' && localStorage.getItem('userid') != '0' && localStorage.getItem('authtoken') != undefined && localStorage.getItem('authtoken') != null && localStorage.getItem('authtoken') != '' && localStorage.getItem('authtokenexpire') != undefined && localStorage.getItem('authtokenexpire') != null ){
#             var today = new Date();
#             var expiry = localStorage.getItem('authtokenexpire');
#             var expiry_date = new Date(expiry);
#             if(today.getTime() < expiry_date.getTime()){
#                 if(localStorage.getItem('policy_acceptance') == undefined  || localStorage.getItem('policy_acceptance') == null || localStorage.getItem('policy_acceptance') != 'yes'){
#                     isLoggedIn = true;
#                 }
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'iOS')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.16.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#
#                         }
#                 }
#                 if($('body').hasClass('jm-android') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'android')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.20.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#                         }
#                 }
#             }
#         }
#      if(localStorage.getItem('nms_refer_lite') == 'jio'){
#                 isLoggedIn = false;
#             }
#         if(isLoggedIn == true){
#             $('.policy-backdrop').removeClass('jm-d-none');
#             $('body').addClass('disable-scroll');
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 app_sendToApp({'type': 'consentDialogFlag','value':parseInt("1")});
#                 app_deliver_bar_visiblity("0"); //hide
#                 app_bnb_visiblity("0");  //show
#             }
#             if(localStorage.getItem('nms_refer_lite') && (localStorage.getItem('nms_refer_lite') == 'jiomartapp')){
#                 $('.profile-link').attr('href','javascript:void(0);');
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#
#                             }
#
#                         }
#                     // }
#                 }
#                 if($('body').hasClass('jm-android')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#                             }
#                         }
#                     // }
#                 }
#             }
#         }
#     });
#    $(document).on('click tap','.close-privacy, .accept_policy', function(){
#         localStorage.setItem('policy_acceptance', 'yes');
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#         }
#     });
#     $(document).on('click tap','.profile-link',function(e){
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         // if(localStorage.getItem('nms_refer_lite') == 'jio'){
#            // e.preventDefault();
#             //if(typeof handleDeepLink != 'undefined'){
#                // handleDeepLink('jiomart_profile');
#             //}
#         //}
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             e.preventDefault();
#  app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#             if($('body').hasClass('jm-ios')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 "type": "handleDeeplink",
#                                 "value": "jiomart_editProfile"
#                             });
#                         }
#
#                     }
#                 }
#             }
#             if($('body').hasClass('jm-android')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 'type': 'handleDeeplink',
#                                 'value': 'edit_profile_details'
#                             });
#                         }
#                     }
#                 }
#             }
#         }
#     });
# </script><script>
# function bind_all_vertical_tree() {
# return true;
# }
# $(document).ready(function(){
# if($("body").hasClass("cms-home")){
# localStorage.removeItem('jio_smart_delivery_time');
# }
# if($("body").hasClass("jiomart_home")){
# if(localStorage.getItem("jio_smart_bazaar") == "yes"){
# $(".home-content.static-page-content").prevAll().remove();
# }
# }
# });
# </script> <script>
# if(page_log == '1'){
# 	console.clear();
# 	console.log = function(){}
# 	}
# </script> <!-- Review and Rating SDK script --> <script>
# function getSearchQuery() {
#     const url = new Url(window.location.href);
#     let pathname = url.paths();
#     let query = "";
#     if (pathname[0] && pathname[0] == "search" && pathname[1]) {
#         query = pathname[1];
#     }
#     else {
#         query = url.query.q;
#     }
#
#     if (query != null) {
#         let decode = decodeURIComponent(query);
#         decode = decode.toString().replace(/~pct~/g, '%');
#         if (decode.indexOf(',') > -1) {
#             let srch_inx = 0;
#             let keywords = decode.split(',');
#             let total = keywords.length;
#             if (pathname[0] && pathname[0] == "search") {
#                 let sIndex = pathname.findIndex(path => path === "si");
#                 if (sIndex != -1) {
#                     srch_inx = parseInt(pathname[sIndex + 1]);
#                 }
#             }
#             else {
#                 if (url.query.si) {
#                     srch_inx = parseInt(url.query.si);
#                 }
#             }
#
#             if ((srch_inx != '') && (srch_inx < total)) {
#                 if (keywords[srch_inx]) {
#                     return keywords[srch_inx];
#                 }
#             }
#
#             return keywords[0];
#         }
#         else {
#             return decode;
#         }
#     }
#     else {
#         return query;
#     }
# }
# </script> <!-- Review and Rating SDK script --> </body> </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    JioMart: India's online shopping destination
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <meta content="India's online shopping destination for Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty, and more. Great Offers. Low Prices. Easy Returns. Pay on Delivery. Top Brands." name="description">
#    <meta content="Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty" name="keywords">
#     <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#     <meta content="#ffffff" name="theme-color">
#      <link href="https://www.jiomart.com/manifest.json" rel="manifest"/>
#      <link href="https://www.jiomart.com/assets/ds2web/jds-icons/favicon.svg" rel="icon" type="image/x-icon">
#       <link href="https://www.jiomart.com/" rel="canonical"/>
#       <meta content="JioMart" property="og:site_name"/>
#       <meta content="website" property="og:type"/>
#       <meta content="JioMart: India's online shopping destination" property="og:title"/>
#       <meta content="India's online shopping destination for Mobiles, Electronics, Grocery, Fashion, Home &amp; Kitchen, Furniture, Jewellery, Beauty, and more. Great Offers. Low Prices. Easy Returns. Pay on Delivery. Top Brands." property="og:description"/>
#       <meta content="https://www.jiomart.com/" property="og:url"/>
#       <meta content="https://www.jiomart.com/assets/global/logo-fb.png" property="og:image"/>
#       <!-- Appple Touch Icons -->
#       <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png" rel="apple-touch-icon" sizes="48x48"/>
#       <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#       <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-128x128.png" rel="apple-touch-icon" sizes="128x128"/>
#       <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-256x256.png" rel="apple-touch-icon" sizes="256x256"/>
#       <link href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png" rel="apple-touch-icon"/>
#       <meta content="app-id=com.jpl.jiomart" name="google-play-app"/>
#       <meta content="app-id=1522085683" name="apple-itunes-app"/>
#       <link href="https://www.jiomart.com/manifest.json" rel="manifest"/>
#       <link href="https://www.jiomart.com/assets/version1729101399/ds2web/css/bootstrap.min.css" rel="stylesheet" type="text/css">
#        <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/ds2_layout.min.css?v=1729854523" rel="stylesheet" type="text/css">
#         <link href="https://cdn.jsdelivr.net/npm/@algolia/autocomplete-theme-classic" rel="stylesheet">
#          <link href="https://www.jiomart.com/assets/version1729101399/ds2web/css/swiper.min.css" media="all" rel="stylesheet" type="text/css">
#           <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/home-cms.min.css" media="all" rel="stylesheet" type="text/css">
#            <link href="https://www.jiomart.com/assets/version1729101399/ds2web/jds-css/ds2-home-cms.min.css" media="all" rel="stylesheet" type="text/css">
#             <script>
#              function noImageError(element){
#     if(element != undefined && element != null){
#         element.error = null;
#         element.src = window.location.origin+"/assets/global/jiomart-default-image-312x420.png";
#     }
# }
# localStorage.removeItem("controlled_serviceability_data");
# document.cookie = "onep=; Max-Age=-99999999;";
# window.productExists = [];
# window.searchKeyData = {};
# window.bannerKeyData = {};
# window.dimension18 = null;
# window.dimension24 = null;
# window.dimension25 = null;
# window.dimension26 = null;
# window.dimension27 = null;
# window.noresult = false;
# window.google_location_api_key = 'AIzaSyB5sQgEo5BdIkJTyrebFTXUvd3b7_nN284';
# window.default_pin = '400020';
# window.default_city = 'Mumbai';
# window.default_state = 'MH';
# window.algolia_filter = false;
# window.algolia_app_id = "3YP0HP3WSH";
# window.algolia_api_key = "aace3f18430a49e185d2c1111602e4b1";
# window.algolia_suffix = 'prod_mart';
#     let cat_config = '2,8582,4,3,8583,1524,6047,6';
#     window.navigation = {
#         allowed_cats:cat_config,
#         source:'algolia',
#         limit:'8'
#     }
# window.personalised = {
#     api_url:'/api/v1/customer/personalizedproducts',
#     limit:'10'
# }
# window.multivertical = JSON.parse('{"status":1,"GROCERIES":"PREMIUMFRUITS"}');
# window.product_image_path = "";
# window.product_image_path = "https://www.jiomart.com/";
#
# window.location_api = "AIzaSyB5sQgEo5BdIkJTyrebFTXUvd3b7_nN284";
# window.default_vertical_city_code = JSON.parse('{"BEAUTY":["PANINDIABEAUTY"],"ELECTRONICS":["PANINDIADIGITAL"],"FASHION":["PANINDIAFASHION"],"GROCERIES":["6217","PANINDIAGROCERIES"],"JEWELLERY":["PANINDIAJEWEL"],"PREMIUMFRUITS":["S575"]}');
# /* window.inventory_store_code = JSON.parse(''); */
# window.locked_phone_html = '';
# window.slideExists = [];
# window.classExists = [];
# window.journeyData = "JM REGULAR";
# window.listResponse = {};
# window.feedback_categories = null;
#     window.emi_design = 'accordion';
# window.autocomplete_inventory = '0';
# window.preorder_status = '0';
# window.multivertical = JSON.parse('{"status":1,"GROCERIES":"PREMIUMFRUITS"}');
# if(!localStorage.getItem('nms_mgo_pincode')){
#     localStorage.setItem('nms_mgo_pincode',window.default_pin);
#     localStorage.setItem('nms_mgo_city',window.default_city);
# }
# window.fynd_api_url = '/platform/logistics/api/v1/promise';
# window.fynd_token = 'cU8ycF93UWtx';
# window.fynd_app_id = 'NWVhNjgyMWIzNDI1YmIwN2M4MmEyNWMx';
# window.fynd_sample_prod = JSON.parse('{"article_id":"491504124","vertical":"GROCERIES","lookup_inventory":false,"tenant_ids":["1003","1008","1007"],"merchant_id":"1"}');
# window.wishlist_api = "/bamboo/api/v2/catalog/mywishlist";
# window.smart_seller_id = '1';
# window.exchange_status = '0';
# window.popular_categories = JSON.parse('[{"name":"Groceries","url_path":"/c/groceries/2","vertical_code":"GROCERIES","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/grocery.png?v=1673368517"},{"name":"Premium fruits","url_path":"/c/premiumfruits/6047","vertical_code":"PREMIUMFRUITS","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/fruits.png?v=1673368517"},{"name":"Home & Kitchen","url_path":"/c/homeandkitchen/8582","vertical_code":"HOMEANDKITCHEN","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/home_kitchen.png?v=1673368517"},{"name":"Fashion","url_path":"/c/fashion/3","vertical_code":"FASHION","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/fashion.png?v=1673368517"},{"name":"Electronics","url_path":"/c/electronics/4","vertical_code":"ELECTRONICS","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/electronics.png?v=1673368517"},{"name":"Jewellery","url_path":"/c/jewellery/1524","vertical_code":"JEWELLERY","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/jewellery.png?v=1673368517"},{"name":"Home Improvement","url_path":"/c/homeimprovement/8583","vertical_code":"HOMEIMPROVEMENT","thumbnail_image_path":"images/cms/wysiwyg/popular-categories/home_improvement.png?v=1673368517"},{"name":"Wellness","url_path":"/c/wellness/6","vertical_code":"WELLNESS","thumbnail_image_path":"images/cms/section/category-url/12806/6.png"}]');
# window.nms_tracker =  "Category List";
# if(localStorage.getItem("nms_product_tracker") != null && localStorage.getItem("nms_product_tracker") != ""){
#     window.nms_tracker =  localStorage.getItem("nms_product_tracker");
#     localStorage.removeItem("nms_product_tracker");
# }
# if(localStorage.getItem("nms_promo_tag") != null && localStorage.getItem("nms_promo_tag") != ""){
#     window.searchKeyData =  localStorage.getItem("nms_promo_tag");
#     localStorage.removeItem("nms_promo_tag");
# }
# if(localStorage.getItem("nms_banner_tag") != null && localStorage.getItem("nms_banner_tag") != ""){
#     window.bannerKeyData =  localStorage.getItem("nms_banner_tag");
#     localStorage.removeItem("nms_banner_tag");
# }
# window.plp_collection_expiry = 0;
# window.plp_collection_expiry = 1;
# window.pdp_separate_tab = false;
# function pdpSeparateTab(){
#     var appseparate_tabVersion = localStorage.getItem("jio_app_version");
#     var appseparate_tabOs = localStorage.getItem("jio_app_os");
#     window.pdp_separate_tab = false;
#     var nativeFlagseparate_tab = null;
#     var iosseparate_tabVersion = "";
#     var androidseparate_tabVersion = "";
#                 nativeFlagseparate_tab = {'app':{'status':'Y','appVersion':'2.0.11.99','iosVersion':'2.0.10.99'}, 'myjio':{'status':'N','appVersion':'7.0.39.99','iosVersion':'7.0.39.99'}, 'web':{'status':'N'}};
#         if(nativeFlagseparate_tab){
#             if(nativeFlagseparate_tab != ""){
#                 if(nativeFlagseparate_tab.hasOwnProperty('web') && nativeFlagseparate_tab.web.hasOwnProperty('status')){
#                     if(nativeFlagseparate_tab.web.status == "Y"){
#                         window.pdp_separate_tab = true;
#                     }
#                 }
#             }
#         }
#     }
# pdpSeparateTab();
#             </script>
#             <script>
#              window.jioads_product_ad = JSON.parse('{"status":1,"mnp":10,"ai":"jiomart.com","vr":"WEB-1.8.2","os":"3","get_ads_api":"https://ads.jiomart.com/ads/ad-server/getAds","impression_api":"https://ads.jiomart.com/ads/ad-token-server/token/impressions","click_api":"https://ads.jiomart.com/ads/ad-token-server/token/clicks","slot":6,"sp_slot":"2,5,8,12","fbt_slot":"1,4,8,12","pdp_mnp":10,"pdp_status":1,"sdk_tracking":0,"sdk_params":0,"custom_slot":"2,6,12,18,24,30,36,42,48,54","pdp_title":"You may also like","pdp_pos":"top","pdp_sub_title":"","pdp_min":1,"pdp_max":20,"newplp_slot":"2, 9, 10, 17, 18, 25, 26, 33, 34, 41"}');
#             </script>
#             <script>
#              window.filter_verticals = 'ALL';
#
#     window.scheduled_delivery = JSON.parse('{"message":"Scheduled Delivery by $$$","duration":5,"append":1}');
#
#     window.algolia_status = JSON.parse('{"suggestions":1,"products":1,"brands":1,"categories":1,"showcart":1}');
#
#     window.mylist_pincode_status = JSON.parse('1');
#             </script>
#             <script>
#              (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-NQLHTD8');
#             </script>
#             <!--script async src="https://jioadsweb.akamaized.net/jioads/retargeting/default/stable/v2/jioAds.js" crossorigin="anonymous"></script-->
#             <style>
#              .expand-content{ max-height:250px; overflow:hidden; } #btn_deli_username, #sign_in_text{ text-transform:capitalize; } .swiper-button-disabled button{ opacity:0.2; } /*.swiper-button-lock{ display:block !important; }*/ .size_chartBtn {display:none;} .size_chartBtn.active {display:block; color: #0c5273; float: right; font-weight: 500; font-size: 13px;} .jm-modal-open { overflow:hidden; } .compare_icons, .section-offers { display: none;} .selected_container, .product-card-selected.inactive, .product_selection_section.inactive, .showedProducts.inactive, .your_choice.inactive, .select-disable.inactive, .product_compare_added, .added_pdp_count, .is_cart_status, .other_products.inactive{ display: none; } .recommended-product-card-separator{ padding-right:10px; padding-left:10px; } .smart-bazaar .search-discover{ display:none; } .smart-bazaar #btn_deli_username{ display:none; }
#             </style>
#             <script>
#              (window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch","rua.ceh":"false","rua.ueh":"false","rua.ieh.st":"0"}]);
#             </script>
#             <script>
#              !function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="5CJLF-ZA3SK-VL8ML-YPN3B-2NPBS",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"5CJLF-ZA3SK-VL8ML-YPN3B-2NPBS";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="onrcuidujl7rczy3pxlq-f-50d6d25f6-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"39","ak.cp":"1422322","ak.ai":parseInt("871072",10),"ak.ol":"0","ak.cr":178,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"11ad347","ak.r":8809,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"115.98.42.0","ak.cport":64540,"ak.gh":"116.74.255.13","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.0rtt.ed":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1729854935","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"16","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.0rtt.ed","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#             </script>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="jio-web cms-home jiomart_home home_overflow_hidden">
#   <script>
#    if (window.location.pathname == "/") {
#         if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#             localStorage.removeItem("jio_smart_bazaar");
#             localStorage.removeItem("jio_category_tree");
#             localStorage.removeItem("jio_smart_delivery_time");
#         }
#     }
#     localStorage.removeItem("jio_smart_bazaar");
#     localStorage.removeItem("smart_cart_info");
#     localStorage.removeItem("jio_smart_cart_id");
#
#     /*if (window.location.pathname == "/smart-bazaar") {
#         localStorage.setItem("jio_smart_bazaar", "yes");
#         localStorage.removeItem("jio_category_tree");
#     }
#
#     if (localStorage.getItem("jio_smart_bazaar") == "yes") {
#         document.getElementsByTagName('body')[0].classList.add("smart-bazaar");
#     }*/
#   </script>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NQLHTD8" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <style>
#    #main_category_top .vertical_banner .home-item-info .home_ripple .vertical_img {width: 70px !important;height: 100% !important;}.lazyload{min-width:0px !important}.lazyloading{min-width:0px !important}#main_category_top .vertical_banner .swiper-slide{aspect-ratio:1;max-height: 70px;}.gpay-jiomartapp #main-banner[data-id="section_149"]{display:none !important}.time-deal-section, .gpay-jiomartapp #item_1_71_17357, .myjiostore #item_1_71_17357,.gpay-jiomartapp #section_2572,.myjiostore #section_2572,.gpay-jiomartapp #section_2994,.gpay-jiomartapp #main-banner_new[data-id="section_2870"],.gpay-jiomartapp #main-banner_new[data-id="section_1242"],.nms-mobistore #item_1_4134_25632,.nms-mobistore.myjiostore #section_4134,.nms-mobistore.gpay-jiomartapp #section_4134{display:none} .nms-mobistore.jiomartapp #item_1_4134_25632{display:block !important}.new_arrival_section .products_swipe .swiper-slide .pro_items a .cat-img img{max-height:150px;display: flex;margin: 0 auto; width:auto !important}.explore-cat-list img{width: 100%;height: auto;}@supports (-webkit-touch-callout: none) {.widget-product-card-details{min-height:85px !important}} .jio-web .saleday_timer_ds2 .teaser-banner .teaser-content {right: 390px;}
#   </style>
#   <style>
#    .offers-landing-page .copy-code{display:none} #vertical_banner .swiper-slide{width:unset !important} .empty_listing{text-align: center;}.cms-smart-bazaar span{font-size: 14px;} .all-product .product-card-details {min-height:92px; }.widget-product-card-box .swiper-container{padding-right:8px} .jiomart_home .section-seperate{ height:unset} .ds2_json_animation .animation_content svg{ min-height: unset;} .product-return-text ul{list-style-type: disc; padding-left: 20px; } .product-return-text ul li{margin-bottom: 4px;} .header-nav-container .category-ds2-name .ds-categories-menu{ line-height: 18px !important; height: 48px !important;} .cms-home .algolia_products_card_ds2, .cms-home .new_top_deals_product_section_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 { background: #FFE68E !important; max-width: unset !important; padding: 24px 0 !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base { max-width: 1184px !important; margin: 0 auto !important; padding-bottom: 16px !important;} .cms-home .algolia_products_card_ds2 .widget-product-card-box, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box { max-width: 1184px !important; margin: 0 auto !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2 { color: #AA0505 !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-details, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details { padding: 0 12px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container{ background: #fff !important; border-radius: 16px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-wrapper, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper{ height: unset !important; } .cms-home .algolia_products_card_ds2 .ds2-swiper-arrow .widget-product-card-cta, .cms-home .new_top_deals_product_section_ds2 .ds2-swiper-arrow .widget-product-card-cta, .cms-jioutsav-grocery .algolia_products_card_ds2 .ds2-swiper-arrow .widget-product-card-cta{ padding: 0 12px !important; margin-bottom: 8px !important; } .cms-home.jio-web #section_15771 .price_drop_alert .widget-product-card-wrapper a{ padding-bottom: 16px !important; }
#   </style>
#   <script async="" src="https://www.googleoptimize.com/optimize.js?id=OPT-MMWV9C4">
#   </script>
#   <div class="main-backdrop">
#   </div>
#   <header class="header">
#    <section class="header-main">
#     <div class="header-main-wrapper">
#      <section class="header-main-container">
#       <!--<div class="header-hamburger jm-mr-xxs"> <button class="jm-btn primary medium jm-icon jm-border-none" id="btn_ham_menu" aria-label="menu icon"> <img class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/hamburger-icon.svg" id="ham_close"/> </button> </div>-->
#       <div class="header-main-logo jm-mr-m">
#        <a class="jm-btn primary small jm-heading-base jm-fc-white jm-border-none" href="https://www.jiomart.com/">
#         <img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/>
#        </a>
#       </div>
#       <div class="header-main-pincode" id="btn_delivery">
#        <button class="jm-btn primary small jm-border-none header-main-pincode-address" id="btn_pin_code_delivery">
#         <img alt="" class="" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-icon.svg"/>
#         <span class="jm-body-xs deliver-to jm-pr-xxs">
#          Deliver to
#         </span>
#         <span class="jm-body-xs-bold" id="btn_deli_username">
#         </span>
#         <span class="jm-body-xs-bold" id="delivery_city_pincode">
#         </span>
#        </button>
#        <div class="header_popover delivery-wrapper" id="delivery_popup" style="display:none;">
#         <section class="delivery jm-pt-m jm-pb-m">
#          <div id="delivery-content">
#           <div class="delivery-header jm-ph-m">
#            <div class="delivery-header-title" id="delivery_title">
#             Select Delivery Location
#            </div>
#            <div class="delivery-header-subtext" id="delivery_desc">
#             Sign in or set delivery location to see product availability, offers and discounts.
#            </div>
#           </div>
#           <div class="delivery-signin jm-ph-m jm-pt-base" id="delivery_signin">
#            <a href="/customer/account/login">
#             <button class="jm-btn primary large full-width delivery-signin-button jm-border-none">
#              Sign In to select address
#             </button>
#            </a>
#           </div>
#           <div class="delivery-location swiper" style="display:none;">
#            <div class="swiper-wrapper" id="delivery_address">
#            </div>
#           </div>
#           <div class="delivery-cta jm-ph-l">
#            <div class="delivery-cta-pincode">
#             <button class="jm-btn tertiary jm-pl-xs" id="btn_enter_pincode">
#              <img alt="location icon" class="jm-mr-base" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-dark.svg"/>
#              Enter a pincode
#             </button>
#            </div>
#            <div class="delivery-cta-location">
#             <button class="jm-btn tertiary jm-pl-xs" id="btn_detect_location">
#              <img alt="detect location icon" class="jm-mr-s" src="https://www.jiomart.com/assets/ds2web/jds-icons/detect-dark.svg"/>
#              Detect My Location
#             </button>
#             <div class="jm-body-xs" id="detect_locate_msg">
#             </div>
#            </div>
#           </div>
#          </div>
#          <div id="delivery_enter_pincode" style="display:none;">
#           <div class="delivery-header jm-ph-l">
#            <div class="delivery-header-title">
#             Enter PIN Code
#            </div>
#            <div class="delivery-header-subtext">
#             Enter PIN code to see product availability, offers and discounts.
#            </div>
#           </div>
#           <form id="delivery_pincode_form">
#            <div class="delivery-pincode jm-ph-l jm-pt-l jm-pb-m">
#             <div class="delivery-pincode-input">
#              <div class="j-field input-text input-has-prefix input-has-suffix" id="pin_input_holder">
#               <span class="input-icon input-icon-prefix">
#                <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-gray-icon.svg"/>
#               </span>
#               <div class="field-underinfo">
#                <div id="delivery_pin_msg">
#                </div>
#               </div>
#               <input autocomplete="off" class="input-component" id="rel_pincode" maxlength="6" name="rel_pincode" placeholder="Enter your Pincode" type="text" value=""/>
#               <label class="field-label" for="pincode">
#                PIN Code
#               </label>
#              </div>
#             </div>
#             <div class="delivery-pincode-cta jm-mt-base jm-ml-l">
#              <button class="jm-btn primary medium" disabled="" id="btn_pincode_submit">
#               Apply
#              </button>
#             </div>
#             <div>
#             </div>
#            </div>
#           </form>
#          </div>
#         </section>
#         <div class="backdrop">
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="header-main-container header-ds-right-width">
#       <div class="header-main-search">
#        <span class="header-main-search-icon search-icon">
#         <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-web-search.svg"/>
#        </span>
#        <div class="header-main-search-section">
#         <div id="autocomplete">
#         </div>
#        </div>
#        <span class="header-main-search-icon list-icon" id="btn_search_list">
#         <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-list-icon.svg"/>
#        </span>
#        <div class="header_popover scroll_hidden_we custom-scrollbar" id="search_initial" style="display:none">
#         <section class="search hidde_topp custom-scrollbar" id="search_empty_holder">
#          <section class="search-recent jm-mb-xs" id="search_initial_recent">
#          </section>
#          <section class="search-discover">
#           <div class="search-discover-title">
#            Try something new
#           </div>
#           <div class="search-discover-item truncate-text" id="search_initial_discover_more">
#           </div>
#          </section>
#          <section class="search-recommended" id="search_initial_recommended">
#          </section>
#          <section class="search-popular">
#           <div class="search-popular-title">
#            Most trending categories
#           </div>
#           <div class="search-popular-item hide-scroll" id="search_initial_popular_categories">
#           </div>
#          </section>
#         </section>
#         <section id="section_search_suggestions">
#         </section>
#         <div class="backdrop">
#         </div>
#        </div>
#        <div class="header_popover" id="search_by_list" style="display:none">
#         <section class="shopping-list">
#          <div class="shopping-list-title">
#           <div class="shopping-list-title-main">
#            Shopping List
#           </div>
#           <div class="shopping-list-title-icon">
#            <button class="jm-btn tertiary small jm-icon" id="close_search_list">
#             <img alt="" class="icon" src="/assets/ds2web/jds-icons/close-icon.svg"/>
#            </button>
#           </div>
#          </div>
#          <form id="rel_search_form">
#           <div class="shopping-list-container">
#            <div class="shopping-list-subtext">
#             Search multiple products by entering your shopping list below.
#            </div>
#            <div class="j-field input-textarea input-has-label-left">
#             <div class="field-underinfo">
#              <span class="field-description">
#               Add comma as separator
#              </span>
#             </div>
#             <div class="wrapper">
#              <textarea class="input-component custom-scrollbar" id="rel_search_val" name="shopping-list" placeholder="e.g. Milk, Bread, Fruit" rows="1" type="textarea"></textarea>
#              <label class="field-label" for="shopping-list">
#               Enter Item List
#              </label>
#             </div>
#            </div>
#           </div>
#           <div class="shopping-list-cta">
#            <div class="shopping-list-cta-item jm-mr-base">
#             <button class="jm-btn secondary large full-width center shopping-list-cta-button jm-pa-none" type="reset">
#              Clear
#             </button>
#            </div>
#            <div class="shopping-list-cta-item">
#             <button class="jm-btn primary large full-width center shopping-list-cta-button jm-pa-none" type="submit">
#              Search All
#             </button>
#            </div>
#           </div>
#          </form>
#         </section>
#         <div class="backdrop">
#         </div>
#        </div>
#       </div>
#       <div class="header-main-user">
#        <div class="header-main-user-cart mini-cart">
#         <button aria-label="cart icon" class="jm-btn primary medium jm-icon jm-border-none" id="btn_minicart">
#          <img alt="" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/cart-icon.svg"/>
#         </button>
#         <div class="header-main-user-cart-count counter-number" style="display:none;">
#         </div>
#         <div id="minicart_container" style="display:none">
#          <section class="cart">
#           <div class="cart-title">
#            <div class="cart-title-main">
#             Cart Items
#            </div>
#            <div class="cart-title-subtext">
#             <span id="minicart_items_count">
#             </span>
#             Item(s)
#            </div>
#           </div>
#           <div class="cart-list-container">
#            <ul class="cart-list" id="minicart_items">
#            </ul>
#            <div class="cart-list-helper-text" id="minicart_remaining">
#            </div>
#            <div class="cart-list-total">
#             <div class="cart-list-total-text">
#              Total amount to be paid
#             </div>
#             <div class="cart-list-total-price" id="minicart_total">
#              ₹
#             </div>
#            </div>
#            <div class="cart-list-saved-text" id="minicart_saving">
#            </div>
#           </div>
#           <div>
#            <button class="jm-btn primary medium full-width center jm-mt-base cart-cta" id="minicart_proceed">
#             Proceed to Cart
#            </button>
#           </div>
#          </section>
#          <div class="backdrop">
#          </div>
#         </div>
#        </div>
#        <button class="jm-btn primary small ds-user-web-profile jm-border-none" id="btn_sign_in" style="display:none">
#         <img alt="Jiomart user sign in" class="jiomart-user-ds" id="jm_header_user_icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/new-ds2-profile-icon.svg"/>
#         <!-- <img class="sb-user-icon-ds" id="sb_header_user_icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-sb-profile.svg" alt="" style="display:none" /> -->
#         <span class="jm-ml-xs" id="sign_in_text">
#          Sign In
#         </span>
#         <!-- class="header-text-ellipsis" -->
#        </button>
#        <span class="ds2_login jm-ml-m" id="user_initial" style="display:none">
#        </span>
#       </div>
#      </section>
#     </div>
#    </section>
#    <section class="header-nav-wrapper">
#     <div class="header-nav-container">
#      <nav class="header-nav">
#       <ul class="header-nav-l1 custom-scrollbar">
#       </ul>
#       <div class="category-ds2-name">
#        <a class="ds-categories-menu" href="https://www.jiomart.com/all-category" id="top_menu_cat" style="display:none;">
#         <!-- <img class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-categories.svg"/> -->
#         <span>
#          All Categories
#         </span>
#        </a>
#       </div>
#      </nav>
#     </div>
#    </section>
#    <!-- Currently backdrop is not active when mouse is hoverred on L1 items because CSS can't do it. JS has to be used for this. <div class="header-backdrop"></div> -->
#   </header>
#   <div class="side-navigation-wrapper" id="hamburger_menu" style="width:0;overflow:hidden;">
#    <div class="side-navigation custom-scrollbar">
#     <div class="top-section">
#      <!-- When user is not logged in -->
#      <div class="top-section-greeting">
#       <div>
#        <button class="jm-btn primary medium jm-icon" id="ham_close">
#         <img alt="go back" src="https://www.jiomart.com/assets/ds2web/jds-icons/angle-left-icon.svg"/>
#        </button>
#       </div>
#       <div class="top-section-greeting-name" id="ham_user_name">
#        Hello!
#       </div>
#      </div>
#      <div class="top-section-useraction" id="ham_signin_cta">
#      </div>
#      <!-- When user is logged in <div class="top-section-greeting" style="display:none;" id="ham_logged_in"> <img alt="go back" class="icon jm-mr-s" src="/assets/ds2web/jds-icons/angle-left-icon.svg" /> <div> Hello <span id="ham_user_name"></span>! </div> </div> <div class="top-section-useraction"> <a href="/customer/account">O</a> </div> -->
#     </div>
#     <div class="content-section">
#      <div class="nav-section">
#       <ul class="nav-section-list">
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/">
#          <img alt="home" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/home-icon.svg"/>
#          <span class="nav-section-list-title">
#           Home
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/all-category">
#          <img alt="shop by category" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/category-icon.svg"/>
#          <span class="nav-section-list-title">
#           Shop By Category
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="nav-section">
#       <div class="nav-section-title">
#        My Account
#       </div>
#       <ul class="nav-section-list">
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/customer/orderhistory">
#          <img alt="my orders" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-order-icon.svg"/>
#          <span class="nav-section-list-title">
#           My Orders
#          </span>
#         </a>
#        </li>
#        <!--li class="nav-section-list-item divider-h"><a class="d-flex" href="/customer/account"> <img loading="lazy" class="icon jm-mr-xs" src="/assets/ds2web/jds-icons/notification-icon.svg" alt="notification icon" /> <span class="nav-section-list-title">My Notifications</span> </a></li-->
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/customer/mylist">
#          <img alt="my list view" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-viewicon.svg"/>
#          <span class="nav-section-list-title">
#           My List
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/customer/wishlist">
#          <img alt="wishlist icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wishlist-icon.svg"/>
#          <span class="nav-section-list-title">
#           Wishlist
#          </span>
#         </a>
#        </li>
#        <!--li class="nav-section-list-item divider-h"><a class="d-flex" href="/customer/account"> <img loading="lazy" class="icon jm-mr-xs" src="/assets/ds2web/jds-icons/rewards-icon.svg" alt="rewards icon"/> <span class="nav-section-list-title">My Rewards</span> </a></li-->
#        <!--li class="nav-section-list-item divider-h"><a class="d-flex" href="/customer/account"> <img loading="lazy" class="icon jm-mr-xs" src="/assets/ds2web/jds-icons/subscribe-icon.svg" alt="subscribe icon" /> <span class="nav-section-list-title">Subscribe & Save</span> </a></li-->
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/customer/account/jiomartwallets">
#          <img alt="wallet icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wallet-icon.svg"/>
#          <span class="nav-section-list-title">
#           JioMart Wallet
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="nav-section">
#       <div class="nav-section-title">
#        Offers &amp; More
#       </div>
#       <ul class="nav-section-list">
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/offers">
#          <img alt="offer store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/offer-store-icon.svg"/>
#          <span class="nav-section-list-title">
#           Offer Store
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/customer/couponstore">
#          <img alt="coupon store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-newicon.svg"/>
#          <span class="nav-section-list-title">
#           Coupon Store
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/gift-store">
#          <img alt="gift store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/gift-store-icon.svg"/>
#          <span class="nav-section-list-title">
#           Gift Store
#          </span>
#         </a>
#        </li>
#        <!--<li class="nav-section-list-item divider-h"><a class="d-flex" href="/customer/giftcard"> <img loading="lazy" class="icon jm-mr-xs" src="/assets/ds2web/jds-icons/gift-card-icon.svg" alt="jiomart gift card" /> <span class="nav-section-list-title">JioMart Gift Card</span> </a></li>-->
#       </ul>
#      </div>
#      <div class="nav-section">
#       <div class="nav-section-title">
#        Help &amp; Support
#       </div>
#       <ul class="nav-section-list">
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/faqs">
#          <img alt="faq need help icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/faqs-icon.svg"/>
#          <span class="nav-section-list-title">
#           FAQs/Need Help
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/about-us">
#          <img alt="about us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/about-us-icon.svg"/>
#          <span class="nav-section-list-title">
#           About Us
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/contact-us">
#          <img alt="contact us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/contact-us-icon.svg"/>
#          <span class="nav-section-list-title">
#           Contact Us
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/how-to-buy-on-jiomart">
#          <img alt="guide" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/guide-icon.svg"/>
#          <span class="nav-section-list-title">
#           Guide
#          </span>
#         </a>
#        </li>
#        <li class="nav-section-list-item divider-h">
#         <a class="d-flex" href="/caution-notice">
#          <img alt="caution notice" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/caution-notice.svg"/>
#          <span class="nav-section-list-title">
#           Caution Notice
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="bottom-section">
#      <div class="app-section divider-h">
#       <div class="app-section-title">
#        Download the App
#       </div>
#       <div class="app-section-item">
#        <a aria-label="google playstore" class="jm-mr-s" href="https://play.google.com/store/apps/details?id=com.jpl.jiomart">
#         <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/google-play-icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/google-play-icon.svg"/>
#        </a>
#        <a aria-label="apple store" class="jm-mr-s" href="https://apps.apple.com/in/app/jiomart/id1522085683">
#         <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/ios_app_icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/ios_app_icon.svg"/>
#        </a>
#       </div>
#      </div>
#      <div class="info-section text-body-xxs">
#       <div class="info-section-item">
#        Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on
#        <a class="text-link" href="mailto:cs@jiomart.com">
#         cs@jiomart.com
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- <div class="backdrop"></div> -->
#   </div>
#   <script>
#    if(localStorage.getItem("nms_mgo_pincode") && localStorage.getItem("nms_mgo_city")){
#             let city_name = localStorage.getItem("nms_mgo_city");
#             if(city_name.length > 10){
#               city_name = city_name.substring(0,8)+'..';
#             }
#             let delivery_city_pin = city_name+" "+localStorage.getItem("nms_mgo_pincode");
#             document.getElementById("delivery_city_pincode").textContent = delivery_city_pin;
#         }
#
#         if(localStorage.getItem("display_ship_name")){
#             let ship_name = localStorage.getItem("display_ship_name");
#             ship_name = ship_name[0].toUpperCase()+ (ship_name.slice(1)).toLowerCase();
#             if(ship_name.length > 10){
#               ship_name = ship_name.substring(0,8)+'..';
#             }
#             document.getElementById("btn_deli_username").innerHTML = ship_name+",&nbsp;";
#         }
#
#         if(localStorage.getItem("displayname")){
#             let user_name = localStorage.getItem("displayname");
#             if(user_name.length > 8){
#               user_name = user_name.substring(0,8)+'..';
#             }
#             //document.getElementById("sign_in_text").textContent = user_name;
#             document.getElementById("ham_user_name").innerHTML = 'Hello '+localStorage.getItem("displayname")+'!';
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn tertiary small jm-icon" href="/customer/account"><img alt="Go to profile" src="https://www.jiomart.com/assets/ds2web/jds-icons/profile-icon.svg" /></a>';
#         }
#         else{
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn secondary small jm-fc-white" href="/customer/account/login">Sign In</a>'
#         }
#
#         if(localStorage.getItem("userid") && localStorage.getItem("userid") != '0'){
#             document.getElementById("btn_sign_in").style.display = 'none';
#             //document.getElementById("sign_in_text").style.display = 'none';
#             document.getElementById("user_initial").style.display = 'flex';
#             //document.getElementById("jm_header_user_icon").style.display = 'none';
#             //document.getElementById("sb_header_user_icon").style.display = 'none';
#             let firstname = localStorage.getItem("displayname");
#             let lastname = localStorage.getItem("displaylastname");
#             let initial = firstname.charAt(0);
#             if(lastname != null && lastname != 'null'){
#                 initial += lastname.charAt(0);
#             }
#             document.getElementById("user_initial").innerText = initial;
#         }
#         else{
#             //document.getElementById("sign_in_text").style.display = 'block';
#             document.getElementById("user_initial").style.display = 'none';
#             document.getElementById("btn_sign_in").style.display = 'flex';
#             /*if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#                 document.getElementById("sb_header_user_icon").style.display = 'block';
#             }
#             else{
#                 document.getElementById("jm_header_user_icon").style.display = 'block';
#             }*/
#
#         }
#         //document.getElementById("btn_sign_in").style.display = "inline-flex";
#   </script>
#   <main class="main">
#    <section class="main-section main-container jm-w-100">
#     <div class="jiomart_maincontent" data-totalpages="6">
#      <div class="static-page-content">
#       <!--ds2.0 body width -->
#       <!-- <div class="home-content static-page-content" > -->
#       <!-- old theme style -->
#       <style>
#        .sec_custom_height15765{ height:48px !important; }
#       </style>
#       <!-- prev class deals-trending-banner -->
#       <!--section id="section_15765" class="deals-trending-banner" data-mydelay="5000"-->
#       <section class="home-content-ds2 hero_banner_ds2" data-id="section_15765" data-jioads-adspot="" data-mydelay="5000" data-page-id="1" id="section_15765">
#        <div class="hero_top_carousel_ds2" data-mydelay="5000" id="section_15765">
#         <div class="gtm_data" data-height="" data-id="15765" data-name="HPMC_Jioutsav Wave 3" data-position="" data-type="banner" data-width="">
#         </div>
#         <div class="home-trending-offer ds2-home-trending-offer" data-id="section_15765">
#          <div class="jm-d-flex jm-jc-space-between jm-ai-center jm-mb-base">
#           <!-- <div class="clearfix"></div> <span></span> <small></small> -->
#          </div>
#          <div class="clearfix">
#          </div>
#          <div class="ds2-swiper-arrow">
#           <div class="swiper-container home-trending-slides hero_top_carousel_ds215765" id="hero_section_15765">
#            <div class="swiper-wrapper" data-jioads-adspot="" data-slide-count="12" id="hero_web_jioads_ds2-15765">
#             <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70113">
#              <a class="home_ripple" href="https://www.jiomart.com/sections/apple-iphone-16-deals" rel="nofollow" title="Top Deals_mpc_iphone16hpmc">
#               <img alt="Top Deals_mpc_iphone16hpmc" class="banner_img" data-src="" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)" title="Top Deals_mpc_iphone16hpmc"/>
#              </a>
#             </div>
#             <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70208">
#              <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977" rel="nofollow" title="Top Deals_mpc_oppok12hpmc">
# ...
#                     $(element).parent().parent().html(btn_html);
#                 }
#             }
#         });
#     }
#   </script>
#   <script>
#    function JioAdsImpression(placementId=""){
#         var insElements;
#         if(placementId != ""){
#             insElements = $("ins[id='" + placementId + "']:not(.viewed)");
#         }
#         if(insElements && placementId != ""){
#             $(insElements).each(function(insIndex,insElement){
#                 if($(insElement).find("iframe").length > 0){
#                     var iframesContent = $(insElement).find("iframe").contents();
#                     if(iframesContent != undefined && iframesContent != null && iframesContent != ""){
#                         $(iframesContent.find('img')).each(function(index,element){
#                             if(element.src.indexOf("ADSIMPRESSION") > -1){
#                                 if(($.inArray(placementId , window.slideExists) === -1)){
#                                     window.slideExists.push(placementId);
#                                     if(typeof AdsTriggerUrl !== "undefined"){
#                                         AdsTriggerUrl(element.src,"impression");
#                                     }
#                                     $(insElement).addClass("viewed");
#                                 }
#                             }
#                         });
#                     }
#                 }
#             });
#         }
#     }
# $(document).ready(function(e){
#     if (typeof JioAds === undefined){
#             var jsElm   = document.createElement("script");
#             jsElm.type  = "application/javascript";
#             jsElm.src   = window.jioads_sdk;
#             document.body.appendChild(jsElm);
#         }
#     if(typeof JioAds !== "undefined"){
#         JioAds.onAdViewed = function (placementId) {
#             if(localStorage.getItem("console_log_enable") != undefined && localStorage.getItem("console_log_enable") != null && localStorage.getItem("console_log_enable") == "1"){
#                     console.log("CB: onAdViewed", placementId);
#                 }
# if(typeof JioAdsImpression !== "undefined"){
#                     JioAdsImpression(placementId);
#                 }
#         };
#     }
# });
#
# $(document).ready(function(e){
#     var page_type = "other pages";
#     if(typeof getAllGtmPageType !== "undefined"){
#         page_type = getAllGtmPageType();
#     }
#     localStorage.setItem("page_type", page_type);
#     var platform = "website";
#     if($("body").hasClass("nms-mobistore") || $("body").hasClass("jio-msite")){
#         platform = "msite";
#     }
#     if(localStorage.getItem("jio_app_os") != null && localStorage.getItem("jio_app_os") != undefined ){
#         platform = "app_"+localStorage.getItem("jio_app_os");
#     }
#     localStorage.setItem("platform", platform);
#
# 	var login_status = (localStorage.getItem("userid") != undefined && localStorage.getItem("userid") != "0") ? "logged in" : "not logged in";
#     localStorage.setItem("login_status",login_status);
#
#     if(typeof journeyDataLayer !== "undefined"){
# 		journeyDataLayer();
#         if(window.journeyData){
#             localStorage.setItem("journey",window.journeyData);
#         }
# 	}
# });
#   </script>
#   <script>
#    function newTrackGoogleEvents(category,action,label,value){
#     if("ga"in window){
#         newtracker=ga.getAll()[0];
#         if(newtracker){
#             if(value != null && value != ""){
#                 newtracker.send("event",category,action,label,value);
#             }
#         }
#     }
# }
# $(document).ready(function(){
#     var dealskuValue = "";
#     var dealcartskuValue = "";
#     if($('body').hasClass('cms-home')){
#         $(document).on('click','.cms-home .top_deals.new_product_swiper a', function(e){
#             dealskuValue = $(this).closest("div.pro_items").find(".addtocartbtn").attr('data-sku');
#             if(dealskuValue != null && dealskuValue != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Top Deals - product clicks",dealskuValue);
#             }
#         });
#         $(document).on('click','.cms-home .top_deals.new_product_swiper .addtocartbtn', function(e){
#             dealcartskuValue = $(this).attr('data-sku');
#             if(dealcartskuValue != null && dealcartskuValue != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","Top Deals - clicks on add to cart",dealcartskuValue);
#             }
#         });
#     }
#     if($('body').hasClass('otc-product-page')){
#         $(document).on('click','.dont_forget_products .viewed-items a', function(e){
#             var dont_forget_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(dont_forget_products != null && dont_forget_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Don't Forget to Add - product clicks",dont_forget_products);
#             }
#         });
#         $(document).on('click','.dont_forget_products .viewed-items .addtocartbtn', function(e){
#             var dont_forget_productscart = $(this).attr('data-sku');
#             if(dont_forget_productscart != null && dont_forget_productscart != ""){
#              newTrackGoogleEvents("PDP","Add to Cart","Don't Forget to Add - clicks on add to cart",dont_forget_productscart);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items a', function(e){
#             var liked_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(liked_products != null && liked_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","You may also like - product clicks",liked_products);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items .addtocartbtn', function(e){
#             var liked_productscart = $(this).attr('data-sku');
#             if(liked_productscart != null && liked_productscart != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","You may also like - clicks on add to cart",liked_productscart);
#             }
#         });
#     }
# });
#   </script>
#   <div class="policy-backdrop jm-d-none">
#    <div style="top: 0; left: 0; bottom: 0; width: 100%; z-index: 60; position: fixed; background-color: rgba(0,0,0,.65); transition: cubic-bezier(0.35, 0, 0.5, 1) 500ms;">
#    </div>
#    <div class="privacy-popup">
#     <div class="close-icon" style="height: 72px;">
#      <button class="jm-btn tertiary medium close-privacy">
#       <img alt="close icon" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/close-icon.svg">
#       </img>
#      </button>
#     </div>
#     <div class="contents-popup">
#      <div>
#       <span class="jm-heading-xs privacy-head">
#        Policy Update
#       </span>
#       <div class="jm-body-s privacy-sub">
#        Please note that our
#        <a class="external_link" href="https://www.jiomart.com/privacy-policy" rel="noopener" target="_blank">
#         Privacy Policy.
#        </a>
#        has been updated and we have also added
#        <a class="external_link" href="https://account.relianceretail.com/privacy-policy/" rel="noopener" target="_blank">
#         Retail Account Privacy Policy
#        </a>
#        . By continuing to use our platform and its services, you consent to the updated policies.
#       </div>
#      </div>
#      <div class="privacy-popup-actions jm-d-flex jm-ai-center">
#       <button class="jm-btn large primary accept_policy" data-sellerid="6746" data-sku="490003796">
#        Agree
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    $(window).on('load',function(){
#         var isLoggedIn = false;
#         if( localStorage.getItem('userid') != undefined && localStorage.getItem('userid') != null && localStorage.getItem('userid') != '' && localStorage.getItem('userid') != '0' && localStorage.getItem('authtoken') != undefined && localStorage.getItem('authtoken') != null && localStorage.getItem('authtoken') != '' && localStorage.getItem('authtokenexpire') != undefined && localStorage.getItem('authtokenexpire') != null ){
#             var today = new Date();
#             var expiry = localStorage.getItem('authtokenexpire');
#             var expiry_date = new Date(expiry);
#             if(today.getTime() < expiry_date.getTime()){
#                 if(localStorage.getItem('policy_acceptance') == undefined  || localStorage.getItem('policy_acceptance') == null || localStorage.getItem('policy_acceptance') != 'yes'){
#                     isLoggedIn = true;
#                 }
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'iOS')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.16.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#
#                         }
#                 }
#                 if($('body').hasClass('jm-android') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'android')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.20.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#                         }
#                 }
#             }
#         }
#      if(localStorage.getItem('nms_refer_lite') == 'jio'){
#                 isLoggedIn = false;
#             }
#         if(isLoggedIn == true){
#             $('.policy-backdrop').removeClass('jm-d-none');
#             $('body').addClass('disable-scroll');
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 app_sendToApp({'type': 'consentDialogFlag','value':parseInt("1")});
#                 app_deliver_bar_visiblity("0"); //hide
#                 app_bnb_visiblity("0");  //show
#             }
#             if(localStorage.getItem('nms_refer_lite') && (localStorage.getItem('nms_refer_lite') == 'jiomartapp')){
#                 $('.profile-link').attr('href','javascript:void(0);');
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#
#                             }
#
#                         }
#                     // }
#                 }
#                 if($('body').hasClass('jm-android')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#                             }
#                         }
#                     // }
#                 }
#             }
#         }
#     });
#    $(document).on('click tap','.close-privacy, .accept_policy', function(){
#         localStorage.setItem('policy_acceptance', 'yes');
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#         }
#     });
#     $(document).on('click tap','.profile-link',function(e){
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         // if(localStorage.getItem('nms_refer_lite') == 'jio'){
#            // e.preventDefault();
#             //if(typeof handleDeepLink != 'undefined'){
#                // handleDeepLink('jiomart_profile');
#             //}
#         //}
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             e.preventDefault();
#  app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#             if($('body').hasClass('jm-ios')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 "type": "handleDeeplink",
#                                 "value": "jiomart_editProfile"
#                             });
#                         }
#
#                     }
#                 }
#             }
#             if($('body').hasClass('jm-android')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 'type': 'handleDeeplink',
#                                 'value': 'edit_profile_details'
#                             });
#                         }
#                     }
#                 }
#             }
#         }
#     });
#   </script>
#   <script>
#    function bind_all_vertical_tree() {
# return true;
# }
# $(document).ready(function(){
# if($("body").hasClass("cms-home")){
# localStorage.removeItem('jio_smart_delivery_time');
# }
# if($("body").hasClass("jiomart_home")){
# if(localStorage.getItem("jio_smart_bazaar") == "yes"){
# $(".home-content.static-page-content").prevAll().remove();
# }
# }
# });
#   </script>
#   <script>
#    if(page_log == '1'){
# 	console.clear();
# 	console.log = function(){}
# 	}
#   </script>
#   <!-- Review and Rating SDK script -->
#   <script>
#    function getSearchQuery() {
#     const url = new Url(window.location.href);
#     let pathname = url.paths();
#     let query = "";
#     if (pathname[0] && pathname[0] == "search" && pathname[1]) {
#         query = pathname[1];
#     }
#     else {
#         query = url.query.q;
#     }
#
#     if (query != null) {
#         let decode = decodeURIComponent(query);
#         decode = decode.toString().replace(/~pct~/g, '%');
#         if (decode.indexOf(',') > -1) {
#             let srch_inx = 0;
#             let keywords = decode.split(',');
#             let total = keywords.length;
#             if (pathname[0] && pathname[0] == "search") {
#                 let sIndex = pathname.findIndex(path => path === "si");
#                 if (sIndex != -1) {
#                     srch_inx = parseInt(pathname[sIndex + 1]);
#                 }
#             }
#             else {
#                 if (url.query.si) {
#                     srch_inx = parseInt(url.query.si);
#                 }
#             }
#
#             if ((srch_inx != '') && (srch_inx < total)) {
#                 if (keywords[srch_inx]) {
#                     return keywords[srch_inx];
#                 }
#             }
#
#             return keywords[0];
#         }
#         else {
#             return decode;
#         }
#     }
#     else {
#         return query;
#     }
# }
#   </script>
#   <!-- Review and Rating SDK script -->
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>JioMart: India's online shopping destination</title>

# %%
tag=soup.html
type(tag)
# Out:
# bs4.element.Tag

# %%
tag=soup.p
tag
# Out:
# <p id="section_15486_days"></p>

# %%
tag=soup.a
tag
# Out:
# <a class="jm-btn primary small jm-heading-base jm-fc-white jm-border-none" href="https://www.jiomart.com/"> <img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/> </a>

# %%
tag=soup.title
tag
# Out:
# <title>JioMart: India's online shopping destination</title>

# %%
tag=soup.img
tag
# Out:
# <img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/>

# %%
body=soup.body
body
# Out:
# <body class="jio-web cms-home jiomart_home home_overflow_hidden"> <script>
#     if (window.location.pathname == "/") {
#         if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#             localStorage.removeItem("jio_smart_bazaar");
#             localStorage.removeItem("jio_category_tree");
#             localStorage.removeItem("jio_smart_delivery_time");
#         }
#     }
#     localStorage.removeItem("jio_smart_bazaar");
#     localStorage.removeItem("smart_cart_info");
#     localStorage.removeItem("jio_smart_cart_id");
#
#     /*if (window.location.pathname == "/smart-bazaar") {
#         localStorage.setItem("jio_smart_bazaar", "yes");
#         localStorage.removeItem("jio_category_tree");
#     }
#
#     if (localStorage.getItem("jio_smart_bazaar") == "yes") {
#         document.getElementsByTagName('body')[0].classList.add("smart-bazaar");
#     }*/
# </script> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NQLHTD8" style="display:none;visibility:hidden" width="0"></iframe></noscript> <style>#main_category_top .vertical_banner .home-item-info .home_ripple .vertical_img {width: 70px !important;height: 100% !important;}.lazyload{min-width:0px !important}.lazyloading{min-width:0px !important}#main_category_top .vertical_banner .swiper-slide{aspect-ratio:1;max-height: 70px;}.gpay-jiomartapp #main-banner[data-id="section_149"]{display:none !important}.time-deal-section, .gpay-jiomartapp #item_1_71_17357, .myjiostore #item_1_71_17357,.gpay-jiomartapp #section_2572,.myjiostore #section_2572,.gpay-jiomartapp #section_2994,.gpay-jiomartapp #main-banner_new[data-id="section_2870"],.gpay-jiomartapp #main-banner_new[data-id="section_1242"],.nms-mobistore #item_1_4134_25632,.nms-mobistore.myjiostore #section_4134,.nms-mobistore.gpay-jiomartapp #section_4134{display:none} .nms-mobistore.jiomartapp #item_1_4134_25632{display:block !important}.new_arrival_section .products_swipe .swiper-slide .pro_items a .cat-img img{max-height:150px;display: flex;margin: 0 auto; width:auto !important}.explore-cat-list img{width: 100%;height: auto;}@supports (-webkit-touch-callout: none) {.widget-product-card-details{min-height:85px !important}} .jio-web .saleday_timer_ds2 .teaser-banner .teaser-content {right: 390px;}</style> <style> .offers-landing-page .copy-code{display:none} #vertical_banner .swiper-slide{width:unset !important} .empty_listing{text-align: center;}.cms-smart-bazaar span{font-size: 14px;} .all-product .product-card-details {min-height:92px; }.widget-product-card-box .swiper-container{padding-right:8px} .jiomart_home .section-seperate{ height:unset} .ds2_json_animation .animation_content svg{ min-height: unset;} .product-return-text ul{list-style-type: disc; padding-left: 20px; } .product-return-text ul li{margin-bottom: 4px;} .header-nav-container .category-ds2-name .ds-categories-menu{ line-height: 18px !important; height: 48px !important;} .cms-home .algolia_products_card_ds2, .cms-home .new_top_deals_product_section_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 { background: #FFE68E !important; max-width: unset !important; padding: 24px 0 !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base { max-width: 1184px !important; margin: 0 auto !important; padding-bottom: 16px !important;} .cms-home .algolia_products_card_ds2 .widget-product-card-box, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box { max-width: 1184px !important; margin: 0 auto !important; } .cms-home .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-home .new_top_deals_product_section_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2, .cms-jioutsav-grocery .algolia_products_card_ds2 .jm-ai-center.jm-mb-base .viewall_header_ds2 { color: #AA0505 !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-details, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-details { padding: 0 12px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-home .new_top_deals_product_section_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container, .cms-jioutsav-grocery .algolia_products_card_ds2 .widget-product-card-box .widget-product-card-wrapper .widget-product-card-container{ background: #fff !important; border-radius: 16px !important; } .cms-home .algolia_products_card_ds2 .widget-product-card-box .widget-pro ...
#         if(localStorage.getItem("nms_mgo_pincode") && localStorage.getItem("nms_mgo_city")){
#             let city_name = localStorage.getItem("nms_mgo_city");
#             if(city_name.length > 10){
#               city_name = city_name.substring(0,8)+'..';
#             }
#             let delivery_city_pin = city_name+" "+localStorage.getItem("nms_mgo_pincode");
#             document.getElementById("delivery_city_pincode").textContent = delivery_city_pin;
#         }
#
#         if(localStorage.getItem("display_ship_name")){
#             let ship_name = localStorage.getItem("display_ship_name");
#             ship_name = ship_name[0].toUpperCase()+ (ship_name.slice(1)).toLowerCase();
#             if(ship_name.length > 10){
#               ship_name = ship_name.substring(0,8)+'..';
#             }
#             document.getElementById("btn_deli_username").innerHTML = ship_name+",&nbsp;";
#         }
#
#         if(localStorage.getItem("displayname")){
#             let user_name = localStorage.getItem("displayname");
#             if(user_name.length > 8){
#               user_name = user_name.substring(0,8)+'..';
#             }
#             //document.getElementById("sign_in_text").textContent = user_name;
#             document.getElementById("ham_user_name").innerHTML = 'Hello '+localStorage.getItem("displayname")+'!';
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn tertiary small jm-icon" href="/customer/account"><img alt="Go to profile" src="https://www.jiomart.com/assets/ds2web/jds-icons/profile-icon.svg" /></a>';
#         }
#         else{
#             document.getElementById("ham_signin_cta").innerHTML = '<a class="jm-btn secondary small jm-fc-white" href="/customer/account/login">Sign In</a>'
#         }
#
#         if(localStorage.getItem("userid") && localStorage.getItem("userid") != '0'){
#             document.getElementById("btn_sign_in").style.display = 'none';
#             //document.getElementById("sign_in_text").style.display = 'none';
#             document.getElementById("user_initial").style.display = 'flex';
#             //document.getElementById("jm_header_user_icon").style.display = 'none';
#             //document.getElementById("sb_header_user_icon").style.display = 'none';
#             let firstname = localStorage.getItem("displayname");
#             let lastname = localStorage.getItem("displaylastname");
#             let initial = firstname.charAt(0);
#             if(lastname != null && lastname != 'null'){
#                 initial += lastname.charAt(0);
#             }
#             document.getElementById("user_initial").innerText = initial;
#         }
#         else{
#             //document.getElementById("sign_in_text").style.display = 'block';
#             document.getElementById("user_initial").style.display = 'none';
#             document.getElementById("btn_sign_in").style.display = 'flex';
#             /*if(localStorage.getItem("jio_smart_bazaar") == "yes"){
#                 document.getElementById("sb_header_user_icon").style.display = 'block';
#             }
#             else{
#                 document.getElementById("jm_header_user_icon").style.display = 'block';
#             }*/
#
#         }
#         //document.getElementById("btn_sign_in").style.display = "inline-flex";
#     </script> <main class="main"> <section class="main-section main-container jm-w-100"><div class="jiomart_maincontent" data-totalpages="6"> <div class="static-page-content"> <!--ds2.0 body width --> <!-- <div class="home-content static-page-content" > --> <!-- old theme style --> <style> .sec_custom_height15765{ height:48px !important; } </style> <!-- prev class deals-trending-banner --> <!--section id="section_15765" class="deals-trending-banner" data-mydelay="5000"--> <section class="home-content-ds2 hero_banner_ds2" data-id="section_15765" data-jioads-adspot="" data-mydelay="5000" data-page-id="1" id="section_15765"> <div class="hero_top_carousel_ds2" data-mydelay="5000" id="section_15765"> <div class="gtm_data" data-height="" data-id="15765" data-name="HPMC_Jioutsav Wave 3" data-position="" data-type="banner" data-width=""></div> <div class="home-trending-offer ds2-home-trending-offer" data-id="section_15765"> <div class="jm-d-flex jm-jc-space-between jm-ai-center jm-mb-base"> <!-- <div class="clearfix"></div> <span></span> <small></small> --> </div> <div class="clearfix"></div> <div class="ds2-swiper-arrow"> <div class="swiper-container home-trending-slides hero_top_carousel_ds215765" id="hero_section_15765"> <div class="swiper-wrapper" data-jioads-adspot="" data-slide-count="12" id="hero_web_jioads_ds2-15765"> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70113"> <a class="home_ripple" href="https://www.jiomart.com/sections/apple-iphone-16-deals" rel="nofollow" title="Top Deals_mpc_iphone16hpmc"> <img alt="Top Deals_mpc_iphone16hpmc" class="banner_img" data-src="" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)" title="Top Deals_mpc_iphone16hpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70208"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977" rel="nofollow" title="Top Deals_mpc_oppok12hpmc"> <img alt="Top Deals_mpc_oppok12hpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729744481_OppoK12x5G.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729744481_OppoK12x5G.jpg?im=Resize=(384,224)" title="Top Deals_mpc_oppok12hpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70124"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/jewels_100/23912?prod_mart_master_vertical%5Bpage%5D=2&amp;prod_mart_master_vertical%5BsortBy%5D=prod_mart_master_vertical_products_popularity&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=Gold%20Coins&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B1%5D=Silver%20Coins&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B2%5D=Gold%20Bars&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B3%5D=Silver%20Bars&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B4%5D=Silver%20Coins%20%26%20Bars" rel="nofollow" title="Top Deals_fnl_dhanterashpmc"> <img alt="Top Deals_fnl_dhanterashpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729745929_Gold__Silver_coins_.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729745929_Gold__Silver_coins_.jpg?im=Resize=(384,224)" title="Top Deals_fnl_dhanterashpmc"/> </a> </div> <div class="swiper-slide ripple_effect three-col" data-adtype="hero_top_carousel_ds2" data-type="heroweb" id="rb_slide_70216"> <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/homepagekaju-katli-starting-rs-289-400g/33995" rel="nofollow" title="Top Deals_gro_kajuburfihpmc"> <img alt="Top Deals_gro_kajuburfihpm ...
# {
#     "@context" : "http://schema.org",
#     "@type" : "WebSite",
#     "url" : "https://www.jiomart.com/",
#     "logo": "https://www.jiomart.com/assets/smartweb/images/jiomart_logo.svg",
#     "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://www.jiomart.com/catalogsearch/result?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#     },
#     "sameAs": [
#         "https://www.facebook.com/JioMartOfficial/",
#         "https://twitter.com/JioMart",
#         "https://www.instagram.com/jiomartofficial"
#     ],
#     "contactPoint" : [
#         { "@type" : "ContactPoint",
#         "telephone" : "18008901222",
#         "email":"cs@jiomart.com",
#         "contactType":"customer service"
#         }
#     ]
# }
#  </script> <script type="text/javascript">
#  var page_name = 'home';
#  var page_identifier = 'home';
#  var page_type = '';
#      var review_enabled = '';
#  var page_log= '1';
#  var mrp_label = 'M.R.P:';
#  var uom_unit =  '{"centimeter":"cm","millimeter":"mm","meter":"m","gram":"g","milligram":"mg","kilogram":"kg","litre":"L","Millileter":"ml","millimeters":"mm","GM":"g","litres":"L","milliliter":"ml","liter":"L","grams":"g","cms":"cm","gms":"g","cubic cm":"ml"}';
#  //var lightning_label = 'LIMITED TIME DEAL';
#  var lightning_label = 'Limited Time Deal';
#  var ds2_lightning_label = '<img src="/assets/ds2msite/jds-icons/flash-t50-s-icon.svg">Limited Time Deal';
#  var ds2_pdp_lightning_label = 'Limited Time Deal';
#  var uom_attribute = '1';
#  var return_content = '';
#  var cancel_content = '';
#  var cart_label =  '{"jiomart" : "", "smartbazaar" : "", "commontoast":"Added to cart", "enable":"1"}';
#  var festive_header_view_count = '1';
#  var festive_header_android_ios_view_count = '1';
#
#  var ds2_seo_footer_heading_content = 'yes';
#  </script> <input id="mstar_api_baseurl" type="hidden" value="https://www.jiomart.com/mst/rest/v1/"/> <input id="mst_api_cart_pin_baseurl" type="hidden" value="/mst/rest/v1/5/"/> <input id="egift_url" type="hidden" value="/api/v1/offers/egiftlist"/> <input id="gtm_status" name="gtm_status" type="hidden" value="1"/> <input id="url_pincode" type="hidden" value="1"/> <script async="" src="https://www.jiomart.com/assets/ds2web/js/lazysizes-umd.min.js" type="text/javascript"></script> <script crossorigin="anonymous" src="https://www.jiomart.com/assets/ds2web/js/jquery-3.4.1.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery-ui.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/bootstrap.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/clipboard.min.js" type="text/javascript"></script> <!-- <script type="text/javascript" src="https://www.jiomart.com/assets/ds2web/js/swiper.min.js" defer crossorigin="anonymous"></script> --> <script src="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.js"></script> <script type="text/javascript">
# 				var package_name = 'jiomart.com';
# 				var languageofArticle = 'english';
# 				//var page_name = 'home';
# 				var jioads_log= '1';
#
# 				var chk_jio_status = 1;
#
#                 var jioads_ads_list = '';
#                 var jioad_general_config = JSON.parse('{"status":1,"mnp":10,"ai":"jiomart.com","vr":"WEB-1.8.2","os":"3","get_ads_api":"https://ads.jiomart.com/ads/ad-server/getAds","impression_api":"https://ads.jiomart.com/ads/ad-token-server/token/impressions","click_api":"https://ads.jiomart.com/ads/ad-token-server/token/clicks","slot":6,"sp_slot":"2,5,8,12","fbt_slot":"1,4,8,12","pdp_mnp":10,"pdp_status":1,"sdk_tracking":0,"sdk_params":0,"custom_slot":"2,6,12,18,24,30,36,42,48,54","pdp_title":"You may also like","pdp_pos":"top","pdp_sub_title":"","pdp_min":1,"pdp_max":20,"newplp_slot":"2, 9, 10, 17, 18, 25, 26, 33, 34, 41"}');
#                 var video_play_enable = '0';
#                 var ios_video_ads = ''
#                 if(/^((?!chrome|android).)*safari/i.test(navigator.userAgent)){
#                     ios_video_ads = 'ios-video-jioads';
#                 }
#                 if($("body").hasClass('jm-ios')) {
#                     ios_video_ads = 'ios-video-jioads';
#                 }
#         </script> <script crossorigin="anonymous" src="https://jioadsweb.akamaized.net/jioads/retargeting/default/stable/v2/jioAds.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/jio_ads_script_ds2.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://cdn.jsdelivr.net/npm/@algolia/autocomplete-js"></script> <!-- <script src="https://www.jiomart.com/assets/ds2web/js/algolia-autocomplete.min.js" defer crossorigin="anonymous"></script> <script src="https://cdn.jsdelivr.net/algoliasearch/3/algoliasearch.min.js" defer crossorigin="anonymous"></script> <script src="https://cdn.jsdelivr.net/npm/algoliasearch@4.5.1/dist/algoliasearch-lite.umd.js" crossorigin="anonymous"></script> --> <script crossorigin="anonymous" src="https://cdn.jsdelivr.net/npm/algoliasearch@4.5.1/dist/algoliasearch.umd.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.cookie.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/bootstrap.notify.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.validate.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/lottie.min.js"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/jquery.md5.min.js" type="text/javascript"></script> <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script> <script>
#     $(document).ready(function () {
#         $('.combo-view-more').click(function(){
#             var target = $(this).attr("data-target");
#             $(target).modal();
#         });
#     });
# </script> <script>
#     $(document).ready(function(){
#         var userId = localStorage.getItem('userid');
#         var authToken = localStorage.getItem('authtoken');
#         var displayName = localStorage.getItem('displayname');
#         var login_pincode = localStorage.getItem('nms_mgo_pincode');
#                 if(login_pincode && (login_pincode !="")) {
#             $.cookie("nms_mgo_pincode", login_pincode, { expires : 1, path    : '/' });
#         }
#     });
# </script> <script type="text/javascript">
# $(document).ready(function () {
#     localStorage.removeItem('loginpage');
#     window.user_id     = (localStorage.getItem('userid')!=null) ? localStorage.getItem('userid'):"" ;
#     window.auth_token  = (localStorage.getItem('authtoken')!=null) ? localStorage.getItem('authtoken'):"";
#     window.cust_dname  = (localStorage.getItem('displayname')!=null) ? localStorage.getItem('displayname'):"";
#         window.login_session = {
#       "async": true,
#       "crossDomain": true,
#       "url": "https://www.jiomart.com/mst/rest/v1/entity/customer/get_details",
#       "method": "GET",
#       "headers": {
#         "userid": window.user_id,
#         "authtoken": window.auth_token
#       }
#     };
#     if((user_id!="" && user_id != 0) && (cust_dname!="")){
#         $('.login #logged_user').text("");
#         $('.login #logged_user').append(cust_dname);
#         $('.login a:first').hide();
#         $('.login #logged_user').show();
#         $("#customer-name").text("Hello, "+cust_dname);
#         $("#profile-link").attr("href","/customer/account");
#         $("#sign_in_out").text('Logout').attr("href","/customer/account/logout");
#     } else {
#         $('.login #logged_user').hide();
#         $('.login a:first').show();
#     }
#         $('.logged').show();
# });
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_main.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_delivery.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/ds2_recommended.min.js" type="module"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/main.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/cart.min.js" type="text/javascript"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/autocomplete_widget.min.js" type="module"></script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/ds2web/js/url.min.js" type="text/javascript"></script> <script>
#     function isInViewport(el) {
# 		var rect = el.getBoundingClientRect();
# 		return (
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.bottom <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
# 		);
# 	}
# 	function isSlideInViewport(el) {
# 		const rect = el.getBoundingClientRect();
# 		return (
# 			(rect.right >= 0) &&
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.bottom <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
#
# 		);
# 	}
# 	function isCategoryViewport(el) {
# 		const rect = el.getBoundingClientRect();
# 		return (
# 			(rect.top > 0 || rect.bottom > 0) &&
# 			rect.top >= 0 &&
# 			rect.left >= 0 &&
# 			rect.top <= (window.innerHeight || document.documentElement.clientHeight) &&
# 			rect.right <= (window.innerWidth || document.documentElement.clientWidth)
#
# 		);
# 	}
# 	function elementViewport(ele) {
# 		const { top, bottom } = ele.getBoundingClientRect();
# 		const vHeight = (window.innerHeight || document.documentElement.clientHeight);
#
# 		return (
# 			(top > 0 || bottom > 0) &&
# 			top < vHeight
# 		);
# 	}
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_scripts.min.js"></script> <!-- <script type="module" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_main.min.js" defer crossorigin="anonymous"></script> --> <script>
#     let jioads_pkg_name = 'jiomart.com';
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/gtm_scripts_all_page.min.js"></script> <script>
#         $(document).ready(function(){
#             if((localStorage.getItem('paynowID')) && (localStorage.getItem('paynowID')!=='')){
#                 localStorage.removeItem('paynowID');
#                 localStorage.removeItem('m2_errlist');
#             }
#         });
#     </script> <script>
# function getPageType(){
#     var pageType = 'other pages';
#     if($("body").hasClass("cms-home")){
#         pageType = "Home Page";
#     }else if($("body").hasClass("catalog-category-view")){
#         pageType = "category page";
#     }else if($("body").hasClass("catalog-product-view")){
#         pageType = "Product Details Page";
#     }
#     else if($("body").hasClass("search-result-page")){
#         pageType = "Search Page";
#     }
#     return pageType;
# }
#
# function trackGoogleEvents(category,action,label){
#     if("ga"in window){
#         tracker=ga.getAll()[0];
#         if(tracker){
#             tracker.send("event",category,action,label);
#         }
#     }
# }
#
#
# $(document).ready(function(){
#     $(".add_to_cart_fixed .cartbag").click(function(){
#         trackGoogleEvents("New Click actions","Add to cart button","Product Holder");
#     });
#
#     $("#search").focus(function(){
#         trackGoogleEvents("New Click actions","Search","");
#     });
#
#     $(".mini-cart").click(function(){
#         var pageType = 'other pages';
#         if($("body").hasClass("cms-home")){
#             pageType = "home page";
#         }
#         else if($("body").hasClass("catalog-category-view")){
#             pageType = "category page";
#         }
#         else if($("body").hasClass("catalog-product-view")){
#             pageType = "product page";
#         }
#         trackGoogleEvents("New Click actions","Cart",pageType);
#     });
#
#
#     $(".home-slides .swiper-slide").click(function(){
#         trackGoogleEvents("Home Banner","Primary Banners","Home Page");
#     });
#
#     $(".home-category-swipe .swiper-slide").click(function(){
#         var catname = $(this).find(".clsgetname").text();
#         trackGoogleEvents("Home Explore Categories",catname,"Home Page");
#     });
#
#     $(".home-best-seller .swiper-slide").click(function(){
#         var prodname = $(this).find(".clsgetname").text();
#         trackGoogleEvents("Home Best Sellers",prodname,"Home Page");
#     });
#     });
# </script> <script>
# if ('serviceWorker' in navigator) {
#     window.addEventListener('load', () => {
#         navigator.serviceWorker.register('/service-worker.js?v=1680183837', {
#           scope: '/'
#         });
#     });
# }
# </script> <script>
#   var ALGOLIA_INSIGHTS_SRC = "//cdn.jsdelivr.net/npm/search-insights@1.3.1";
#
#   !function(e,a,t,n,s,i,c){e.AlgoliaAnalyticsObject=s,e[s]=e[s]||function(){
#   (e[s].queue=e[s].queue||[]).push(arguments)},i=a.createElement(t),c=a.getElementsByTagName(t)[0],
#   i.async=1,i.src=n,c.parentNode.insertBefore(i,c)
#   }(window,document,"script",ALGOLIA_INSIGHTS_SRC,"aa");
#
#
#   // Initialize library
#   aa('init', {
#     appId: window.algolia_app_id,
#     apiKey: window.algolia_api_key
#   });
# </script> <script crossorigin="anonymous" defer="" src="https://www.jiomart.com/assets/version1729101399/ds2web/js/seo-optimization-link.min.js" type="text/javascript"></script> <script src="https://www.jiomart.com/assets/version1729101399/ds2web/js/ds2/topdeals_home.min.js" type="module"></script> <script src="https://www.jiomart.com/assets/version1729101399/ds2web/js/home.min.js"></script> <script>
#     $(document).ready(function(){
#         if(window.pdp_separate_tab == true){
#             window.addEventListener('storage', function(event) {
#                 if (event.storageArea === localStorage) {
#                     var redirectionUrl = false;
#                     redirectionUrl = storageUpdate(event);
#                     if(redirectionUrl == true){
#                         window.location.reload(true);
#                     }
#                 }
#             });
#         }
#     });
#     function storageUpdate(event){
#         if(window.pdp_separate_tab == true){
#             if(event.key == "nms_mgo_pincode" || event.key == "userid" || event.key == "authtoken"){
#                 if(event.newValue != undefined && event.newValue != event.oldValue){
#                     return true;
#                 }
#             }
#             if(event.key == "cart_info"){
#                 if(event.newValue != undefined && event.newValue != event.oldValue){
#                     resetCartBtn();
#                     applyPlusMinusButton();
#                     var cart_info = JSON.parse(localStorage.getItem('cart_info'));
#                     if(localStorage.getItem('jio_store_id')){
#                         var cart_info = JSON.parse(localStorage.getItem('pickup_cart_info'));
#                     }
#                     var cart_count = 0;
#                     if (cart_info) {
#                         var cart_prods = cart_info.cart.lines;
#                         cart_count = cart_prods.length;
#                         $(cart_prods).each(function (i, prod) {
#                             var promo_seller_id = "";
#                             var sku = prod.product_code;
#                             var targetSku = $($('.jm-btn[data-sku="'+sku+'"]'));
#                             var bestCart = "";
#                             var prodpage = false;
#                             var vertical = $("#vertical_code").val();
#                             if(targetSku.length > 0){
#                                 if($(targetSku).hasClass('prodbtn')){
#                                     prodpage = true;
#                                 }
#                                 if(prod.qty > 0){
#                                     let seller_id = $(targetSku).attr("data-sellerid");
#                                     $(".jm-btn[data-sku='"+sku+"'][data-sellerid='"+seller_id+"']").each(function(i,el){
#                                         let targetBtn = $(el);
#                                         $(targetBtn).prop('disabled',false);
#                                         $(targetBtn).next().next().prop('disabled',false);
#                                         $(targetBtn).next().next().removeClass('disabled');
#                                         $(targetBtn).next().text(prod.qty);
#                                     });
#
#                                     if($(targetSku).closest("#pdp_best_deals_products").length > 0){
#                                         $("#pdp_best_deals_products .addtocartbtn").prop("disabled",false);
#                                     }
#                                     if($('body').hasClass('otc-product-page')){
#                                         if($(targetSku).closest('.pdp_deals_promo') != null){
#                                             if($(targetSku).closest('.pdp_deals_promo').attr("id") != null){
#                                                 bestCart = "#"+$(targetSku).closest('.pdp_deals_promo').attr("id");
#                                                 applyPlusMinusButton(bestCart);
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         });
#                     }
#                     if(cart_count > 0){
#                         $(".mini-cart .counter-number").text(cart_count).show();
#                     }
#                     else{
#                         $(".mini-cart .counter-number").text(cart_count).hide();
#                     }
#                     return false;
#                 }
#             }
#         }
#     }
#
#     function resetCartBtn(){
#         $(".jm-btn[data-sku]").each(function(index,element){
#             var prod_promo_seller_id = "";
#             var productSku = "";
#             productSku = $(element).attr("data-sku");
#             if($(element).closest("#pdp_best_deals_products").length > 0){
#                 // $("#pdp_best_deals_products .addtocartbtn").prop("disabled",false);
#                 prod_promo_seller_id = $(element).attr("data-sellerid");
#                 var btn_html = `<button class="jm-btn small secondary full-width jm-body-s-bold jm-jc-center toCart addtocartbtn best_cart" data-sellerid="${prod_promo_seller_id}" data-sku="${productSku}"> Add To Cart </button>`;
#                 $("#pdp_best_deals_products .product-card-wrapper").find(".is_cart_status").removeClass("active");
#                 $(element).parent().parent().html(btn_html);
#             } else {
#                 if($(element).hasClass("jm-btn")){
#                     let prod_seller_id = $(element).attr("data-sellerid");
#                     $(".jm-btn[data-sku='"+productSku+"'][data-sellerid='"+prod_seller_id+"']").each(function(i,el){
#                         let targetBtn = $(el);
#
#                         let parent_class = targetBtn.parent().attr("data-parentbtn-class");
#                         let parent_text = targetBtn.parent().attr("data-parentbtn-text");
#                         let parent_image = targetBtn.parent().attr("data-parentbtn-image");
#                         let is_prod_btn = targetBtn.parent().hasClass("prodpage");
#
#                         let el_seller_id = targetBtn.attr("data-sellerid");
#                         if(is_prod_btn){
#                             targetBtn.parent().removeClass("product-footer-item-added").addClass("product-footer-item");
#                         }
#
#                         let img_src = '/assets/ds2msite/jds-icons/add-icon.svg';
#                         let is_buybox_popup = targetBtn.parent().attr("data-seller-popup");
#                         if(is_buybox_popup == "yes"){
#                             img_src = '/assets/ds2msite/jds-icons/add-white-icon.svg';
#                         }
#
#                         let btn_html = `<button class="jm-btn ${parent_class} addtocartbtn" data-sku="${productSku}" data-sellerid="${el_seller_id}">
#                             ${parent_text}
#                             ${parent_image == "1" ? `<img src="${img_src}" alt="Add to cart" class="jm-ml-xs" />`:``}
#                         </button>`;
#                         targetBtn.parent().html(btn_html);
#                     });
#                 }
#                 else{
#                     var btn_html = `<button type="button" title="ADD TO CART" class="toCart addtocartbtn" data-sku="${productSku}">
#                         <span class="txt_btn">Add to Cart</span>
#                         <span class="add_plus"></span>
#                     </button>`;
#                     $(element).parent().parent().html(btn_html);
#                 }
#             }
#         });
#     }
# </script> <script>
# function JioAdsImpression(placementId=""){
#         var insElements;
#         if(placementId != ""){
#             insElements = $("ins[id='" + placementId + "']:not(.viewed)");
#         }
#         if(insElements && placementId != ""){
#             $(insElements).each(function(insIndex,insElement){
#                 if($(insElement).find("iframe").length > 0){
#                     var iframesContent = $(insElement).find("iframe").contents();
#                     if(iframesContent != undefined && iframesContent != null && iframesContent != ""){
#                         $(iframesContent.find('img')).each(function(index,element){
#                             if(element.src.indexOf("ADSIMPRESSION") > -1){
#                                 if(($.inArray(placementId , window.slideExists) === -1)){
#                                     window.slideExists.push(placementId);
#                                     if(typeof AdsTriggerUrl !== "undefined"){
#                                         AdsTriggerUrl(element.src,"impression");
#                                     }
#                                     $(insElement).addClass("viewed");
#                                 }
#                             }
#                         });
#                     }
#                 }
#             });
#         }
#     }
# $(document).ready(function(e){
#     if (typeof JioAds === undefined){
#             var jsElm   = document.createElement("script");
#             jsElm.type  = "application/javascript";
#             jsElm.src   = window.jioads_sdk;
#             document.body.appendChild(jsElm);
#         }
#     if(typeof JioAds !== "undefined"){
#         JioAds.onAdViewed = function (placementId) {
#             if(localStorage.getItem("console_log_enable") != undefined && localStorage.getItem("console_log_enable") != null && localStorage.getItem("console_log_enable") == "1"){
#                     console.log("CB: onAdViewed", placementId);
#                 }
# if(typeof JioAdsImpression !== "undefined"){
#                     JioAdsImpression(placementId);
#                 }
#         };
#     }
# });
#
# $(document).ready(function(e){
#     var page_type = "other pages";
#     if(typeof getAllGtmPageType !== "undefined"){
#         page_type = getAllGtmPageType();
#     }
#     localStorage.setItem("page_type", page_type);
#     var platform = "website";
#     if($("body").hasClass("nms-mobistore") || $("body").hasClass("jio-msite")){
#         platform = "msite";
#     }
#     if(localStorage.getItem("jio_app_os") != null && localStorage.getItem("jio_app_os") != undefined ){
#         platform = "app_"+localStorage.getItem("jio_app_os");
#     }
#     localStorage.setItem("platform", platform);
#
# 	var login_status = (localStorage.getItem("userid") != undefined && localStorage.getItem("userid") != "0") ? "logged in" : "not logged in";
#     localStorage.setItem("login_status",login_status);
#
#     if(typeof journeyDataLayer !== "undefined"){
# 		journeyDataLayer();
#         if(window.journeyData){
#             localStorage.setItem("journey",window.journeyData);
#         }
# 	}
# });
# </script><script>
# function newTrackGoogleEvents(category,action,label,value){
#     if("ga"in window){
#         newtracker=ga.getAll()[0];
#         if(newtracker){
#             if(value != null && value != ""){
#                 newtracker.send("event",category,action,label,value);
#             }
#         }
#     }
# }
# $(document).ready(function(){
#     var dealskuValue = "";
#     var dealcartskuValue = "";
#     if($('body').hasClass('cms-home')){
#         $(document).on('click','.cms-home .top_deals.new_product_swiper a', function(e){
#             dealskuValue = $(this).closest("div.pro_items").find(".addtocartbtn").attr('data-sku');
#             if(dealskuValue != null && dealskuValue != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Top Deals - product clicks",dealskuValue);
#             }
#         });
#         $(document).on('click','.cms-home .top_deals.new_product_swiper .addtocartbtn', function(e){
#             dealcartskuValue = $(this).attr('data-sku');
#             if(dealcartskuValue != null && dealcartskuValue != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","Top Deals - clicks on add to cart",dealcartskuValue);
#             }
#         });
#     }
#     if($('body').hasClass('otc-product-page')){
#         $(document).on('click','.dont_forget_products .viewed-items a', function(e){
#             var dont_forget_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(dont_forget_products != null && dont_forget_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","Don't Forget to Add - product clicks",dont_forget_products);
#             }
#         });
#         $(document).on('click','.dont_forget_products .viewed-items .addtocartbtn', function(e){
#             var dont_forget_productscart = $(this).attr('data-sku');
#             if(dont_forget_productscart != null && dont_forget_productscart != ""){
#              newTrackGoogleEvents("PDP","Add to Cart","Don't Forget to Add - clicks on add to cart",dont_forget_productscart);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items a', function(e){
#             var liked_products = $(this).closest("div.viewed-items").find(".addtocartbtn").attr('data-sku');
#             if(liked_products != null && liked_products != ""){
#                 newTrackGoogleEvents("PDP","Product Click","You may also like - product clicks",liked_products);
#             }
#         });
#         $(document).on('click','.liked_products .viewed-items .addtocartbtn', function(e){
#             var liked_productscart = $(this).attr('data-sku');
#             if(liked_productscart != null && liked_productscart != ""){
#                 newTrackGoogleEvents("PDP","Add to Cart","You may also like - clicks on add to cart",liked_productscart);
#             }
#         });
#     }
# });
# </script> <div class="policy-backdrop jm-d-none"> <div style="top: 0; left: 0; bottom: 0; width: 100%; z-index: 60; position: fixed; background-color: rgba(0,0,0,.65); transition: cubic-bezier(0.35, 0, 0.5, 1) 500ms;"></div> <div class="privacy-popup"> <div class="close-icon" style="height: 72px;"><button class="jm-btn tertiary medium close-privacy"> <img alt="close icon" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/close-icon.svg"> </img></button></div> <div class="contents-popup"> <div><span class="jm-heading-xs privacy-head">Policy Update</span> <div class="jm-body-s privacy-sub">Please note that our <a class="external_link" href="https://www.jiomart.com/privacy-policy" rel="noopener" target="_blank">Privacy Policy.</a> has been updated and we have also added <a class="external_link" href="https://account.relianceretail.com/privacy-policy/" rel="noopener" target="_blank">Retail Account Privacy Policy</a>. By continuing to use our platform and its services, you consent to the updated policies.</div> </div> <div class="privacy-popup-actions jm-d-flex jm-ai-center"><button class="jm-btn large primary accept_policy" data-sellerid="6746" data-sku="490003796">Agree</button></div> </div> </div> </div> <script>
#     $(window).on('load',function(){
#         var isLoggedIn = false;
#         if( localStorage.getItem('userid') != undefined && localStorage.getItem('userid') != null && localStorage.getItem('userid') != '' && localStorage.getItem('userid') != '0' && localStorage.getItem('authtoken') != undefined && localStorage.getItem('authtoken') != null && localStorage.getItem('authtoken') != '' && localStorage.getItem('authtokenexpire') != undefined && localStorage.getItem('authtokenexpire') != null ){
#             var today = new Date();
#             var expiry = localStorage.getItem('authtokenexpire');
#             var expiry_date = new Date(expiry);
#             if(today.getTime() < expiry_date.getTime()){
#                 if(localStorage.getItem('policy_acceptance') == undefined  || localStorage.getItem('policy_acceptance') == null || localStorage.getItem('policy_acceptance') != 'yes'){
#                     isLoggedIn = true;
#                 }
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'iOS')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.16.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#
#                         }
#                 }
#                 if($('body').hasClass('jm-android') || (localStorage.getItem('jio_app_os') != undefined && localStorage.getItem('jio_app_os') != null &&  localStorage.getItem('jio_app_os') == 'android')){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(compareAppVersion('2.0.20.99',localStorage.getItem('jio_app_version'))){
#                                 isLoggedIn = false;
#                             }
#                         }
#                 }
#             }
#         }
#      if(localStorage.getItem('nms_refer_lite') == 'jio'){
#                 isLoggedIn = false;
#             }
#         if(isLoggedIn == true){
#             $('.policy-backdrop').removeClass('jm-d-none');
#             $('body').addClass('disable-scroll');
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 app_sendToApp({'type': 'consentDialogFlag','value':parseInt("1")});
#                 app_deliver_bar_visiblity("0"); //hide
#                 app_bnb_visiblity("0");  //show
#             }
#             if(localStorage.getItem('nms_refer_lite') && (localStorage.getItem('nms_refer_lite') == 'jiomartapp')){
#                 $('.profile-link').attr('href','javascript:void(0);');
#             }
#             if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#                 if($('body').hasClass('jm-ios')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#
#                             }
#
#                         }
#                     // }
#                 }
#                 if($('body').hasClass('jm-android')){
#                     // if(typeof app_sendToApp == 'undefined'){
#                         if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                             if(!compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                                 $('.profile-link').css({'display':'none'})
# //$(".app-text").css({'display':'block'});
#                             }
#                         }
#                     // }
#                 }
#             }
#         }
#     });
#    $(document).on('click tap','.close-privacy, .accept_policy', function(){
#         localStorage.setItem('policy_acceptance', 'yes');
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#         }
#     });
#     $(document).on('click tap','.profile-link',function(e){
#         $('.policy-backdrop').addClass('jm-d-none');
#         $('body').removeClass('disable-scroll');
#         // if(localStorage.getItem('nms_refer_lite') == 'jio'){
#            // e.preventDefault();
#             //if(typeof handleDeepLink != 'undefined'){
#                // handleDeepLink('jiomart_profile');
#             //}
#         //}
#         if(localStorage.getItem('nms_refer_lite') == 'jiomartapp'){
#             e.preventDefault();
#  app_deliver_bar_visiblity("1"); //hide
#             app_bnb_visiblity("1");  //show
#             app_sendToApp({'type': 'consentDialogFlag','value':parseInt("0")});
#             if($('body').hasClass('jm-ios')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.11.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 "type": "handleDeeplink",
#                                 "value": "jiomart_editProfile"
#                             });
#                         }
#
#                     }
#                 }
#             }
#             if($('body').hasClass('jm-android')){
#                 if(typeof app_sendToApp != 'undefined'){
#                     if(localStorage.getItem('jio_app_version') != undefined && localStorage.getItem('jio_app_version') != null){
#                         if(compareAppVersion('2.0.12.99',localStorage.getItem('jio_app_version'))){
#                             app_sendToApp({
#                                 'type': 'handleDeeplink',
#                                 'value': 'edit_profile_details'
#                             });
#                         }
#                     }
#                 }
#             }
#         }
#     });
# </script><script>
# function bind_all_vertical_tree() {
# return true;
# }
# $(document).ready(function(){
# if($("body").hasClass("cms-home")){
# localStorage.removeItem('jio_smart_delivery_time');
# }
# if($("body").hasClass("jiomart_home")){
# if(localStorage.getItem("jio_smart_bazaar") == "yes"){
# $(".home-content.static-page-content").prevAll().remove();
# }
# }
# });
# </script> <script>
# if(page_log == '1'){
# 	console.clear();
# 	console.log = function(){}
# 	}
# </script> <!-- Review and Rating SDK script --> <script>
# function getSearchQuery() {
#     const url = new Url(window.location.href);
#     let pathname = url.paths();
#     let query = "";
#     if (pathname[0] && pathname[0] == "search" && pathname[1]) {
#         query = pathname[1];
#     }
#     else {
#         query = url.query.q;
#     }
#
#     if (query != null) {
#         let decode = decodeURIComponent(query);
#         decode = decode.toString().replace(/~pct~/g, '%');
#         if (decode.indexOf(',') > -1) {
#             let srch_inx = 0;
#             let keywords = decode.split(',');
#             let total = keywords.length;
#             if (pathname[0] && pathname[0] == "search") {
#                 let sIndex = pathname.findIndex(path => path === "si");
#                 if (sIndex != -1) {
#                     srch_inx = parseInt(pathname[sIndex + 1]);
#                 }
#             }
#             else {
#                 if (url.query.si) {
#                     srch_inx = parseInt(url.query.si);
#                 }
#             }
#
#             if ((srch_inx != '') && (srch_inx < total)) {
#                 if (keywords[srch_inx]) {
#                     return keywords[srch_inx];
#                 }
#             }
#
#             return keywords[0];
#         }
#         else {
#             return decode;
#         }
#     }
#     else {
#         return query;
#     }
# }
# </script> <!-- Review and Rating SDK script --> </body>

# %%
soup.find_all("p")
# Out:
# [<p id="section_15486_days"></p>,
#  <p id="section_15486_hours"></p>,
#  <p id="section_15486_minutes"></p>,
#  <p id="section_15486_seconds"></p>]

# %%
soup.find_all("a")
# Out:
# [<a class="jm-btn primary small jm-heading-base jm-fc-white jm-border-none" href="https://www.jiomart.com/"> <img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/> </a>,
#  <a href="/customer/account/login"> <button class="jm-btn primary large full-width delivery-signin-button jm-border-none"> Sign In to select address </button> </a>,
#  <a class="ds-categories-menu" href="https://www.jiomart.com/all-category" id="top_menu_cat" style="display:none;"> <!-- <img class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-categories.svg"/> --> <span>All Categories</span> </a>,
#  <a class="d-flex" href="/"> <img alt="home" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/home-icon.svg"/> <span class="nav-section-list-title">Home</span> </a>,
#  <a class="d-flex" href="/all-category"> <img alt="shop by category" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/category-icon.svg"/> <span class="nav-section-list-title">Shop By Category</span> </a>,
#  <a class="d-flex" href="/customer/orderhistory"> <img alt="my orders" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-order-icon.svg"/> <span class="nav-section-list-title">My Orders</span> </a>,
#  <a class="d-flex" href="/customer/mylist"> <img alt="my list view" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-viewicon.svg"/> <span class="nav-section-list-title">My List</span> </a>,
#  <a class="d-flex" href="/customer/wishlist"> <img alt="wishlist icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wishlist-icon.svg"/> <span class="nav-section-list-title">Wishlist</span> </a>,
#  <a class="d-flex" href="/customer/account/jiomartwallets"> <img alt="wallet icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wallet-icon.svg"/> <span class="nav-section-list-title">JioMart Wallet</span> </a>,
#  <a class="d-flex" href="/offers"> <img alt="offer store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/offer-store-icon.svg"/> <span class="nav-section-list-title">Offer Store</span> </a>,
#  <a class="d-flex" href="/customer/couponstore"> <img alt="coupon store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-newicon.svg"/> <span class="nav-section-list-title">Coupon Store</span> </a>,
#  <a class="d-flex" href="/gift-store"> <img alt="gift store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/gift-store-icon.svg"/> <span class="nav-section-list-title">Gift Store</span> </a>,
#  <a class="d-flex" href="/faqs"> <img alt="faq need help icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/faqs-icon.svg"/> <span class="nav-section-list-title">FAQs/Need Help</span> </a>,
#  <a class="d-flex" href="/about-us"> <img alt="about us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/about-us-icon.svg"/> <span class="nav-section-list-title">About Us</span> </a>,
#  <a class="d-flex" href="/contact-us"> <img alt="contact us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/contact-us-icon.svg"/> <span class="nav-section-list-title">Contact Us</span> </a>,
#  <a class="d-flex" href="/how-to-buy-on-jiomart"> <img alt="guide" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/guide-icon.svg"/> <span class="nav-section-list-title">Guide</span> </a>,
#  <a class="d-flex" href="/caution-notice"> <img alt="caution notice" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/caution-notice.svg"/> <span class="nav-section-list-title">Caution Notice</span> </a>,
#  <a aria-label="google playstore" class="jm-mr-s" href="https://play.google.com/store/apps/details?id=com.jpl.jiomart"> <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/google-play-icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/google-play-icon.svg"/> </a>,
#  <a aria-label="apple store" class="jm-mr-s" href="https://apps.apple.com/in/app/jiomart/id1522085683"> <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/ios_app_icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/ios_app_icon.svg"/> </a>,
#  <a class="text-link" href="mailto:cs@jiomart.com">cs@jiomart.com</a>,
#  <a class="home_ripple" href="https://www.jiomart.com/sections/apple-iphone-16-deals" rel="nofollow" title="Top Deals_mpc_iphone16hpmc"> <img alt="Top Deals_mpc_iphone16hpmc" class="banner_img" data-src="" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)" title="Top Deals_mpc_iphone16hpmc"/> </a>,
#  <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977" rel="nofollow" title="Top Deals_mpc_oppok12hpmc"> <img alt="Top Deals_mpc_oppok12hpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729744481_OppoK12x5G.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729744481_OppoK12x5G.jpg?im=Resize=(384,224)" title="Top Deals_mpc_oppok12hpmc"/> </a>,
#  <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/jewels_100/23912?prod_mart_master_vertical%5Bpage%5D=2&amp;prod_mart_master_vertical%5BsortBy%5D=prod_mart_master_vertical_products_popularity&amp;prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=
> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="605537653" id="wishlist_605537653"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Skybags GRAF PLUS 01 LAPTOP BACKPACK (E) BLACK" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494241521/skybags-graf-plus-black-laptop-backpack-product-images-o494241521-p605537653-0-202310101430.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494241521/skybags-graf-plus-black-laptop-backpack-product-images-o494241521-p605537653-0-202310101430.jpg?im=Resize=(50,50)" title="Skybags GRAF PLUS 01 LAPTOP BACKPACK (E) BLACK"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Skybags GRAF PLUS 01 LAPTOP BACKPAC.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹599.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹2,200.00 </span> <!--span class="save_price">Save &#8377; 1,601.00</span--> <span class="jm-badge jm-ml-xxs"> 72% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="605537653"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-icon jm-mr-base" data-parentbtn-class="small secondary full-width jm-body-s-bold" data-parentbtn-image="0" data-par ...
#  <a class="widget-product-card-container widget_product_list" data-objid="609971944" href="/p/electronics/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone/609971944" title="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone"> <div class="gtmEvents" data-3p-available="1P" data-alternate="494422937" data-brandid="1659" data-cate="Mobiles &amp; Tablets" data-categoryid="757" data-exchange="Eligible" data-id="609971944" data-image="494422937/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone-digital-o494422937-p609971944-0-202409161631.jpeg" data-l4category="Smartphones" data-l4categoryid="32294" data-manu="Realme" data-name="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone" data-position="3" data-price="9799" data-sellername="Reliance Retail" data-subcate="Mobiles" data-subcategoryid="32118" data-tag="false" data-type="list" data-vertical="Electronics" data-verticalid="4"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="609971944" id="wishlist_609971944"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494422937/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone-digital-o494422937-p609971944-0-202409161631.jpeg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494422937/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone-digital-o494422937-p609971944-0-202409161631.jpeg?im=Resize=(50,50)" title="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Realme Narzo N65 5G 128 GB, 4 GB RA.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹9,799.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹13,999.00 </span> <!--span class="save_price">Save &#8377; 4,200.00</span--> <span class="jm-badge jm-ml-xxs"> 30% OFF </span> </div> </div> </div> <!-- Product Details --> </a>,
#  <a class="widget-product-card-container widget_product_list" data-objid="594550377" href="/p/fashion/bangalore-refinery-metal-silver-bar/594550377" title="Bangalore Refinery 999 Silver Bar 100g"> <div class="gtmEvents" data-3p-available="3P" data-alternate="RVOJM65XHH" data-brandid="16592" data-cate="Women" data-categoryid="493" data-exchange="Not eligible" data-id="594550377" data-image="rvojm65xhh/bangalore-refinery-metal-silver-bar-product-images-rvojm65xhh-0-202210171050.jpg" data-l4category="Silver Coins &amp; Bars" data-l4categoryid="6402" data-manu="BANGALORE REFINERY" data-name="Bangalore Refinery 999 Silver Bar 100g" data-position="4" data-price="10787" data-sellername="Bangalore refinery private limited" data-subcate="Gemstones Coins &amp; Bars" data-subcategoryid="6126" data-tag="false" data-type="list" data-vertical="Fashion" data-verticalid="3"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="594550377" id="wishlist_594550377"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Bangalore Refinery 999 Silver Bar 100g" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvojm65xhh/bangalore-refinery-metal-silver-bar-product-images-rvojm65xhh-0-202210171050.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvojm65xhh/bangalore-refinery-metal-silver-bar-product-images-rvojm65xhh-0-202210171050.jpg?im=Resize=(50,50)" title="Bangalore Refinery 999 Silver Bar 100g"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100">
OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="490162348"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-icon jm-mr-base" data-parentbtn-class="small secondary full-width jm-body-s-bold" data-parentbtn-image="0" data-parentbtn-text="Add" data-plusclass="secondary small jm-icon jm-ml-base"> <button class="jm-btn small secondary full-wid ...
#  <a class="widget-product-card-container widget_product_list" data-objid="603872541" href="/p/groceries/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm/603872541" title="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm"> <div class="gtmEvents" data-3p-available="3P" data-alternate="RVVTZJPMHJ" data-brandid="14668" data-cate="Biscuits, Drinks &amp; Packaged Foods" data-categoryid="28997" data-exchange="Not eligible" data-id="603872541" data-image="rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png" data-l4category="Namkeen &amp; Savoury Snacks" data-l4categoryid="29498" data-manu="Haldiram Bhujiawala" data-name="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm" data-position="7" data-price="149" data-sellername="HALDIRAM BHUJIAWALA INC" data-subcate="Chips &amp; Namkeens" data-subcategoryid="29000" data-tag="false" data-type="list" data-vertical="Groceries" data-verticalid="2"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <span class="food_type_sec"><span class="text-veg"></span></span> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="603872541" id="wishlist_603872541"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png?im=Resize=(50,50)" title="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Haldiram Bhujiawala Bhujia Namkeen.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹149.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹222.00 </span> <!--span class="save_price">Save &#8377; 73.00</span--> <span class="jm-badge jm-ml-xxs"> 32% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="603872541"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version17291 ...
#  <a class="widget-product-card-container widget_product_list" data-objid="605569524" href="/p/homeandkitchen/dimpy-endearing-sitting-yellow-lion-nestled-with-a-charming-brown-ribbon-toy-25-cm/605569524" title="Dimpy Stuff Soft Toy for Girls, Boys &amp; Kids| Lion Plush Toy | Adorable Gift | Yellow 25cm"> <div class="gtmEvents" data-3p-available="1P" data-alternate="494260087" data-brandid="199540" data-cate="Toys &amp; Games" data-categoryid="31513" data-exchange="Not eligible" data-id="605569524" data-image="494260087/dimpy-stuff-soft-toy-for-girls-boys-kids-lion-plush-toy-adorable-gift-yellow-25cm-product-images-o494260087-p605569524-0-202311091120.jpg" data-l4category="Stuffed Animals" data-l4categoryid="31649" data-manu="DIMPY" data-name="Dimpy Stuff Soft Toy for Girls, Boys &amp; Kids| Lion Plush Toy | Adorable Gift | Yellow 25cm" data-position="8" data-price="155" data-sellername="Reliance Retail" data-subcate="Indoor &amp; Board Games" data-subcategoryid="31516" data-tag="false" data-type="list" data-vertical="Home &amp; Lifestyle" data-verticalid="8582"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="605569524" id="wishlist_605569524"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Dimpy Stuff Soft Toy for Girls, Boys &amp; Kids| Lion Plush Toy | Adorable Gift | Yellow 25cm" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494260087/dimpy-stuff-soft-toy-for-girls-boys-kids-lion-plush-toy-adorable-gift-yellow-25cm-product-images-o494260087-p605569524-0-202311091120.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494260087/dimpy-stuff-soft-toy-for-girls-boys-kids-lion-plush-toy-adorable-gift-yellow-25cm-product-images-o494260087-p605569524-0-202311091120.jpg?im=Resize=(50,50)" title="Dimpy Stuff Soft Toy for Girls, Boys &amp; Kids| Lion Plush Toy | Adorable Gift | Yellow 25cm"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Dimpy Stuff Soft Toy for Girls, Boy.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹155.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹499.00 </span> <!--span class="save_price">Save &#8377; 344.00</span--> <span class="jm-badge jm-ml-xxs"> 68% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="605569524"> Add <img class="jm-ml-xs" src="https://www.j ...
#  <a class="widget-product-card-container widget_product_list" data-objid="606594842" href="/p/fashion/lzard-men-blue-slim-stretch-jeans/606594842" title="Lzard Men Blue Slim Stretch Jeans"> <div class="gtmEvents" data-3p-available="3P" data-alternate="RVSZAWNTK4" data-brandid="13985" data-cate="Men" data-categoryid="496" data-exchange="Not eligible" data-id="606594842" data-image="rvszawntk4/lzard-men-blue-slim-stretch-jeans-product-images-rvszawntk4-0-202312070230.jpg" data-l4category="Deals" data-l4categoryid="20219" data-manu="Lzard" data-name="Lzard Men Blue Slim Stretch Jeans" data-position="9" data-price="319" data-sellername="AG INTERNATIONAL" data-subcate="Western Wear" data-subcategoryid="504" data-tag="false" data-type="list" data-vertical="Fashion" data-verticalid="3"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="606594842" id="wishlist_606594842"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Lzard Men Blue Slim Stretch Jeans" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvszawntk4/lzard-men-blue-slim-stretch-jeans-product-images-rvszawntk4-0-202312070230.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvszawntk4/lzard-men-blue-slim-stretch-jeans-product-images-rvszawntk4-0-202312070230.jpg?im=Resize=(50,50)" title="Lzard Men Blue Slim Stretch Jeans"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Lzard Men Blue Slim Stretch Jeans </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹319.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹2,299.00 </span> <!--span class="save_price">Save &#8377; 1,980.00</span--> <span class="jm-badge jm-ml-xxs"> 86% OFF </span> </div> </div> </div> <!-- Product Details --> </a>,
# ...
#  <a class="widget-product-card-container widget_product_list" data-objid="602262449" href="/p/groceries/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2/602262449" title="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)"> <div class="gtmEvents" data-3p-available="3P" data-alternate="RVJSXHK5F0" data-brandid="1043" data-cate="Personal Care" data-categoryid="91" data-exchange="Not eligible" data-id="602262449" data-image="rvjsxhk5f0/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2-product-images-orvjsxhk5f0-p602262449-0-202306090832.jpg" data-l4category="Body Lotion &amp; Cream" data-l4categoryid="6090" data-manu="joy" data-name="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)" data-position="19" data-price="290" data-sellername="RSH GLOBAL PRIVATE LIMITED" data-subcate="Skin Care" data-subcategoryid="122" data-tag="false" data-type="list" data-vertical="Groceries" data-verticalid="2"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="602262449" id="wishlist_602262449"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvjsxhk5f0/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2-product-images-orvjsxhk5f0-p602262449-0-202306090832.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvjsxhk5f0/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2-product-images-orvjsxhk5f0-p602262449-0-202306090832.jpg?im=Resize=(50,50)" title="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)"/> </div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Joy Honey and Almonds Nourishing Bo.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹290.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹580.00 </span> <!--span class="save_price">Save &#8377; 290.00</span--> <span class="jm-badge jm-ml-xxs"> 50% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="602262449"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-ico ...
#  <a href="https://apps.apple.com/in/app/jiomart/id1522085683"> <img alt="" src="/assets/ds2web/jds-icons/ios_app_icon.svg"> </img></a>,
#  <a class="external_link" href="https://www.jiomart.com/privacy-policy" rel="noopener" target="_blank">Privacy Policy.</a>,
#  <a class="external_link" href="https://account.relianceretail.com/privacy-policy/" rel="noopener" target="_blank">Retail Account Privacy Policy</a>]

# %%
for l in soup.find_all("a"):
    print(l)
# Out:
# <a class="jm-btn primary small jm-heading-base jm-fc-white jm-border-none" href="https://www.jiomart.com/"> <img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/> </a>
# <a href="/customer/account/login"> <button class="jm-btn primary large full-width delivery-signin-button jm-border-none"> Sign In to select address </button> </a>
# <a class="ds-categories-menu" href="https://www.jiomart.com/all-category" id="top_menu_cat" style="display:none;"> <!-- <img class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-categories.svg"/> --> <span>All Categories</span> </a>
# <a class="d-flex" href="/"> <img alt="home" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/home-icon.svg"/> <span class="nav-section-list-title">Home</span> </a>
# <a class="d-flex" href="/all-category"> <img alt="shop by category" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/category-icon.svg"/> <span class="nav-section-list-title">Shop By Category</span> </a>
# <a class="d-flex" href="/customer/orderhistory"> <img alt="my orders" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-order-icon.svg"/> <span class="nav-section-list-title">My Orders</span> </a>
# <a class="d-flex" href="/customer/mylist"> <img alt="my list view" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-viewicon.svg"/> <span class="nav-section-list-title">My List</span> </a>
# <a class="d-flex" href="/customer/wishlist"> <img alt="wishlist icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wishlist-icon.svg"/> <span class="nav-section-list-title">Wishlist</span> </a>
# <a class="d-flex" href="/customer/account/jiomartwallets"> <img alt="wallet icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wallet-icon.svg"/> <span class="nav-section-list-title">JioMart Wallet</span> </a>
# <a class="d-flex" href="/offers"> <img alt="offer store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/offer-store-icon.svg"/> <span class="nav-section-list-title">Offer Store</span> </a>
# <a class="d-flex" href="/customer/couponstore"> <img alt="coupon store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-newicon.svg"/> <span class="nav-section-list-title">Coupon Store</span> </a>
# <a class="d-flex" href="/gift-store"> <img alt="gift store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/gift-store-icon.svg"/> <span class="nav-section-list-title">Gift Store</span> </a>
# <a class="d-flex" href="/faqs"> <img alt="faq need help icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/faqs-icon.svg"/> <span class="nav-section-list-title">FAQs/Need Help</span> </a>
# <a class="d-flex" href="/about-us"> <img alt="about us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/about-us-icon.svg"/> <span class="nav-section-list-title">About Us</span> </a>
# <a class="d-flex" href="/contact-us"> <img alt="contact us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/contact-us-icon.svg"/> <span class="nav-section-list-title">Contact Us</span> </a>
# <a class="d-flex" href="/how-to-buy-on-jiomart"> <img alt="guide" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/guide-icon.svg"/> <span class="nav-section-list-title">Guide</span> </a>
# <a class="d-flex" href="/caution-notice"> <img alt="caution notice" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons
OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="j ...
# <a class="widget-product-card-container widget_product_list" data-objid="490162348" href="/p/groceries/moti-sandal-luxury-bath-soap-150-g/490162348" title="Moti Sandal Luxury Bath Soap 150 g"> <div class="gtmEvents" data-3p-available="1P" data-alternate="490162348" data-brandid="1049" data-cate="Personal Care" data-categoryid="91" data-exchange="Not eligible" data-id="490162348" data-image="490162348/moti-sandal-luxury-bath-soap-150-g-product-images-o490162348-p490162348-0-202208121832.jpg" data-l4category="Bathing Bars &amp; Soaps" data-l4categoryid="120" data-manu="moti" data-name="Moti Sandal Luxury Bath Soap 150 g" data-position="6" data-price="57" data-sellername="Reliance Retail" data-subcate="Bath &amp; Hand Wash" data-subcategoryid="119" data-tag="false" data-type="list" data-vertical="Groceries" data-verticalid="2"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="490162348" id="wishlist_490162348"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Moti Sandal Luxury Bath Soap 150 g" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/490162348/moti-sandal-luxury-bath-soap-150-g-product-images-o490162348-p490162348-0-202208121832.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/490162348/moti-sandal-luxury-bath-soap-150-g-product-images-o490162348-p490162348-0-202208121832.jpg?im=Resize=(50,50)" title="Moti Sandal Luxury Bath Soap 150 g"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Moti Sandal Luxury Bath Soap 150 g </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹57.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹75.00 </span> <!--span class="save_price">Save &#8377; 18.00</span--> <span class="jm-badge jm-ml-xxs"> 24% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="490162348"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-icon jm-mr-base" data-parentbtn-class="small secondary full-width jm-body-s-bold" data-parentbtn-image="0" data-parentbtn-text="Add" data-plusclass="secondary small jm-icon jm-ml-base"> <button class="jm-btn small secondary full-widt ...
# <a class="widget-product-card-container widget_product_list" data-objid="603872541" href="/p/groceries/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm/603872541" title="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm"> <div class="gtmEvents" data-3p-available="3P" data-alternate="RVVTZJPMHJ" data-brandid="14668" data-cate="Biscuits, Drinks &amp; Packaged Foods" data-categoryid="28997" data-exchange="Not eligible" data-id="603872541" data-image="rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png" data-l4category="Namkeen &amp; Savoury Snacks" data-l4categoryid="29498" data-manu="Haldiram Bhujiawala" data-name="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm" data-position="7" data-price="149" data-sellername="HALDIRAM BHUJIAWALA INC" data-subcate="Chips &amp; Namkeens" data-subcategoryid="29000" data-tag="false" data-type="list" data-vertical="Groceries" data-verticalid="2"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <span class="food_type_sec"><span class="text-veg"></span></span> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="603872541" id="wishlist_603872541"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvvtzjpmhj/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm-product-images-orvvtzjpmhj-p603872541-0-202308141326.png?im=Resize=(50,50)" title="Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm"> </img></div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Haldiram Bhujiawala Bhujia Namkeen.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹149.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹222.00 </span> <!--span class="save_price">Save &#8377; 73.00</span--> <span class="jm-badge jm-ml-xxs"> 32% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="603872541"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version172910 ...
# <a class="widget-product-card-container widget_product_list" data-objid="605569524" href="/p/homeandkitchen/dimpy-endearing-sitting-yellow-lion-nestled-with-a-charming-brown-ribbon-toy-25-cm/605569524" title="Dimpy Stuff Soft Toy for Girls, Boys &amp; Kids| Lion Plush Toy | Adorable Gift | Yellow 25c
joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)" data-position="19" data-price="290" data-sellername="RSH GLOBAL PRIVATE LIMITED" data-subcate="Skin Care" data-subcategoryid="122" data-tag="false" data-type="list" data-vertical="Groceries" data-verticalid="2"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="602262449" id="wishlist_602262449"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/rvjsxhk5f0/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2-product-images-orvjsxhk5f0-p602262449-0-202306090832.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/rvjsxhk5f0/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2-product-images-orvjsxhk5f0-p602262449-0-202306090832.jpg?im=Resize=(50,50)" title="Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)"/> </div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Joy Honey and Almonds Nourishing Bo.. </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹290.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹580.00 </span> <!--span class="save_price">Save &#8377; 290.00</span--> <span class="jm-badge jm-ml-xxs"> 50% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="602262449"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-icon ...
# <a class="widget-product-card-container widget_product_list" data-objid="605496265" href="/p/homeandkitchen/panchami-deepam-oil-pouch-1-l/605496265" title="Panchami Deepam Oil Pouch 1 L"> <div class="gtmEvents" data-3p-available="1P" data-alternate="494263650" data-brandid="7621" data-cate="Prayer &amp; Spiritual Needs" data-categoryid="8746" data-exchange="Not eligible" data-id="605496265" data-image="494263650/panchami-deepam-oil-pouch-1-l-product-images-o494263650-p605496265-0-202310061913.jpg" data-l4category="Decorative Lanterns" data-l4categoryid="10269" data-manu="Panchami" data-name="Panchami Deepam Oil Pouch 1 L" data-position="20" data-price="139" data-sellername="Reliance Retail" data-subcate="Lanterns" data-subcategoryid="8755" data-tag="false" data-type="list" data-vertical="Home &amp; Lifestyle" data-verticalid="8582"> </div> <!-- Image Container --> <div class="widget-product-card-image-container"> <!-- Wishlist Button --> <div class="widget-product-card-wishlist" style=""> <!--button type="button" class="jm-btn tertiary small jm-icon"> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/wishlist-outline-icon.svg" alt="" /> </button--> <div class="product-card-wishlist"> <span class="jm-wishlist-btn medium wishlist_btn" data-showtoast="no" data-sku="605496265" id="wishlist_605496265"></span> </div> </div> <div class="widget-product-card-image"> <img alt="Panchami Deepam Oil Pouch 1 L" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494263650/panchami-deepam-oil-pouch-1-l-product-images-o494263650-p605496265-0-202310061913.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494263650/panchami-deepam-oil-pouch-1-l-product-images-o494263650-p605496265-0-202310061913.jpg?im=Resize=(50,50)" title="Panchami Deepam Oil Pouch 1 L"/> </div> </div> <!-- Product Details --> <div class="widget-product-card-details"> <!-- widget-product-card-title --> <div class="jm-body-xs line-clamp jm-fc-primary-grey-100"> Panchami Deepam Oil Pouch 1 L </div> <!-- Aaj-ki-Review --> <!--span class="jm-d-flex jm-ai-center jm-jc-flex-start jm-mt-xxs ds2-review"> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_ic_star.svg" alt=""> </span> <span> <img src="https://www.jiomart.com/assets/ds2web/jds-icons/ds2_icon_white.svg" alt=""> </span> <span class="jm-body-xxs jm-fc-primary-grey-60 jm-ml-xxs">44</span> </span--> <div class="widget-product-card-price jm-mt-xs"> <!-- widget-product-card-price-original --> <div class="jm-body-xs-bold jm-fc-black">₹139.00</div> <!-- widget-product-card-price-display --> <div> <span class="jm-body-xs jm-fc-primary-grey-60 line-through jm-mt-xxs"> ₹250.00 </span> <!--span class="save_price">Save &#8377; 111.00</span--> <span class="jm-badge jm-ml-xxs"> 44% OFF </span> </div> </div> </div> <!-- Product Details --> <!-- New Update Just Add Button Only --> <!--div class="widget-product-card-cta add jm-mt-s cart_btn"> <button type="button" title="ADD TO CART" class="jm-btn small secondary full-width jm-body-s-bold toCart addtocartbtn" data-sku="605496265"> Add <img class="jm-ml-xs" src="https://www.jiomart.com/assets/version1729101399/ds2web/jds-icons/add-icon.svg" alt="" /> </button> </div--> <div class="widget-product-card-cta add jm-mt-s" data-countclass="widget-product-card-cta-qty" data-minusclass="secondary small jm-icon jm-mr-base" data-parentbtn-class="small secondary full-width jm-body-s-bold" data-parentbtn-image="0" data-parentbtn-text="Add" data-plusclass="secondary small jm-icon jm-ml-base"> <button class="jm-btn small secondary full-width jm-body-s-bold ad ...
# <a class="home_ripple" rel="nofollow"> <img alt="Top Deals_naa_handpicked offers header_web" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729238208_Handpicked_Offers_2368x400.jpg?im=Resize=(2368,400)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729238208_Handpicked_Offers_2368x400.jpg?im=Resize=(1184,200)" title="Top Deals_naa_handpicked offers header_web"> </img></a>
# <a class="home_ripple" href="https://www.jiomart.com/c/fashion/best-deals/fw_starting99_wave3/34112" rel="nofollow" title="Top Deals_fnl_menfootwearst"> <img alt="Top Deals_fnl_menfootwearst" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729228392_Mens_Footwear2x.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729228392_Mens_Footwear2x.jpg?im=Resize=(184,226)" title="Top Deals_fnl_menfootwearst"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977" rel="nofollow" title="Top Deals_mpc_oppok12st"> <img alt="Top Deals_mpc_oppok12st" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729575548_Oppo_K12x_5G.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729575548_Oppo_K12x_5G.jpg?im=Resize=(184,226)" title="Top Deals_mpc_oppok12st"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/cycle_top_deals_08_05/28258" rel="nofollow" title="Top Deals_gmo_cyclest"> <img alt="Top Deals_gmo_cyclest" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729489687_Mountain_Bikes.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729489687_Mountain_Bikes.jpg?im=Resize=(184,226)" title="Top Deals_gmo_cyclest"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/cooking-essentials-jio-utsav/33599" rel="nofollow" title="Top Deals_gro_cookingessentialsst"> <img alt="Top Deals_gro_cookingessentialsst" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729227936_Cooking_Essentials.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729227936_Cooking_Essentials.jpg?im=Resize=(184,226)" title="Top Deals_gro_cookingessentialsst"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/bestofwomen_oct/33852" rel="nofollow" title="Top Deals_fnl_womenaccessoriesst"> <img alt="Top Deals_fnl_womenaccessoriesst" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729227869_Womens_Accessories2x.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729227869_Womens_Accessories2x.jpg?im=Resize=(184,226)" title="Top Deals_fnl_womenaccessoriesst"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/sections/large-appliances-hk" rel="nofollow" title="Top Deals_apn_acwashingmachinest"> <img alt="Top Deals_apn_acwashingmachinest" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729400078_Acs_and_Washinh_Machine.jpg?im=Resize=(368,452)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729400078_Acs_and_Washinh_Machine.jpg?im=Resize=(184,226)" title="Top Deals_apn_acwashingmachinest"/> </a>
# <a class="home_ripple" href="https://www.jiomart.com/c/bestdeals/furniture-best-sellers/29115" rel="nofollow" title="Top Deals_gmo_furniturest"> <img alt="Top Deals_gmo_furniturest" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1
    print(l.get("href"))
# Out:
# https://www.jiomart.com/
# /customer/account/login
# https://www.jiomart.com/all-category
# /
# /all-category
# /customer/orderhistory
# /customer/mylist
# /customer/wishlist
# /customer/account/jiomartwallets
# /offers
# /customer/couponstore
# /gift-store
# /faqs
# /about-us
# /contact-us
# /how-to-buy-on-jiomart
# /caution-notice
# https://play.google.com/store/apps/details?id=com.jpl.jiomart
# https://apps.apple.com/in/app/jiomart/id1522085683
# mailto:cs@jiomart.com
# https://www.jiomart.com/sections/apple-iphone-16-deals
# https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977
# https://www.jiomart.com/c/bestdeals/jewels_100/23912?prod_mart_master_vertical%5Bpage%5D=2&prod_mart_master_vertical%5BsortBy%5D=prod_mart_master_vertical_products_popularity&prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=Gold%20Coins&prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B1%5D=Silver%20Coins&prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B2%5D=Gold%20Bars&prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B3%5D=Silver%20Bars&prod_mart_master_vertical%5BrefinementList%5D%5Bcategory_level.level4%5D%5B4%5D=Silver%20Coins%20%26%20Bars
# https://www.jiomart.com/c/bestdeals/homepagekaju-katli-starting-rs-289-400g/33995
# https://www.jiomart.com/c/bestdeals/kitchen_hpmc_1/21353
# https://www.jiomart.com/c/fashion/men/496?prod_mart_fashion_products_popularity%5Bpage%5D=5&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=Blazers%20%26%20Coats&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B1%5D=Deals&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B2%5D=Ethnic%20Jackets&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B3%5D=Ethnic%20Suit%20Sets&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B4%5D=Jackets&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B5%5D=Jackets%20%26%20Coats&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B6%5D=Jeans&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B7%5D=Kurta%20Pyjama%20Sets&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B8%5D=Kurtas&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B9%5D=Shirt%20Pieces&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B10%5D=Shirts&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B11%5D=Track%20Pants&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B12%5D=Tracksuits&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B13%5D=Trousers%20%26%20Pants&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B14%5D=Tshirts&prod_mart_fashion_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B15%5D=Shorts%20%26%203%2F4ths
# https://www.jiomart.com/c/bestdeals/df-hpmc-diwali-gift-pack/33991
# https://www.jiomart.com/c/bestdeals/sweets-hpmc-diwali-gift-pack/33993
# https://www.jiomart.com/c/groceries/home-care/36?prod_mart_master_vertical_products_popularity%5Bpage%5D=2&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B0%5D=Floor%20%26%20Other%20Cleaners&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B1%5D=Dishwash%20Liquids%20%26%20Pastes&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B2%5D=Air%20Freshener&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B3%5D=Toilet%20Cleaners&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B4%5D=Dishwasher%20Liquid%20Detergent&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B5%5D=Combo%20Cleaning%20Set&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B6%5D=Bathroom%20Accessories&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B7%5D=Dustbin&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B8%5D=Kitchen%2C%20Glass%20%26%20Drain&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B9%5D=Mops%2C%20Wipers%20%26%20Gloves&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B10%5D=Mosquito%20Repellent&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B11%5D=Dishwash%20Bars%20%26%20Powders&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B12%5D=Dustbin%2C%20Brooms%20%26%20Dust%20Pans&prod_mart_master_vertical_products_popularity%5BrefinementList%5D%5Bcategory_level.level4%5D%5B13%5D=Dust%20Cloth%20%26%20Wipes
# https://www.jiomart.com/sections/jioutsav-grocery
# https://www.jiomart.com/sections/diwali-gift-packs
# https://www.jiomart.com/c/bestdeals/indepedence-day-deals-on-laptops_gis/32129
# /all-topdeals?section_id=15375
# /p/electronics/apple-iphone-16-256-gb-black/609946228
# /p/homeandkitchen/skybags-graf-plus-black-laptop-backpack/605537653
# /p/electronics/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone/609971944
# /p/fashion/bangalore-refinery-metal-silver-bar/594550377
# /p/groceries/shree-misthan-kaju-katli-400g-200g-x-2/604027500
# /p/groceries/moti-sandal-luxury-bath-soap-150-g/490162348
# /p/groceries/haldiram-bhujiawala-bhujia-namkeen-snacks-for-satisfying-hunger-800-gm/603872541
# /p/homeandkitchen/dimpy-endearing-sitting-yellow-lion-nestled-with-a-charming-brown-ribbon-toy-25-cm/605569524
# /p/fashion/lzard-men-blue-slim-stretch-jeans/606594842
# /p/groceries/indiyum-kaju-dodha-burfi-treditional-indian-sweets-classic-dodha-burfi-made-special-with-kaju-nuts-200g/609581179
# /p/electronics/alibaba-supreme-seven-star-7-jar-wonder-750-mixer-grinder-7-jars-white-blue/608849210
# /p/groceries/good-life-diwali-healthy-treats-dry-fruits-gift-pack-300-g/594029331
# /p/groceries/aakash-namkeen-gulab-jamun-and-rasgulla-combo-1kg-each-pack-of-2/600177503
# /p/groceries/rush-note-books-a4-size-200-pages-spiral-notebook-unruled-spiral-register-note-books-unruled/604836950
# /p/fashion/aadi-men-s-black-mesh-running-sport-shoes/591812777
# /p/groceries/active-white-detergent-powder-10-kg-family-pack/603002057
# /p/electronics/realme-t110-tws-earbuds-punk-black/608763167
# /p/groceries/godrej-aer-matic-violet-valley-bloom-diffuser-machine-refill-225-ml/491441370
# /p/groceries/joy-honey-and-almonds-nourishing-body-lotion-300ml-pack-of-2/602262449
# /p/homeandkitchen/panchami-deepam-oil-pouch-1-l/605496265
# None
# https://www.jiomart.com/c/fashion/best-deals/fw_starting99_wave3/34112
# https://www.jiomart.com/c/bestdeals/oppo-k12x-5g/31977
# https://www.jiomart.com/c/bestdeals/cycle_top_deals_08_05/28258
# https://www.jiomart.com/c/bestdeals/cooking-essentials-jio-utsav/33599
# https://www.jiomart.com/c/bestdeals/bestofwomen_oct/33852
# https://www.jiomart.com/sections/large-appliances-hk
# https://www.jiomart.com/c/bestdeals/furniture-best-sellers/29115
# /c/groceries/2
# /c/electronics/4
# /c/fashion/3
# /c/homeandkitchen/8582
# /c/premiumfruits/6047
# /c/groceries/books/2831
# /c/furniture/12884
# /c/groceries/biscuits-drinks-packaged-foods/28997
# /c/groceries/fruits-vegetables/219
# /c/groceries/cooking-essentials/28984
# /c/groceries/dairy-bakery/61
# /c/groceries/personal-care/91
# /c/groceries/beauty/6607
# /c/groceries/home-care/36
# /c/groceries/mom-baby-care/2551
# /c/groceries/school-office-stationery/29985
# /customer/account
# /customer/orderhistory
# /customer/wishlist
# /customer/account/address
# /customer/account/jiomartwallets
# /about-us
# /faqs
# /terms-and-conditions
# /privacy-policy
# /reliance-retail-e-waste-recycling-policy
# /cancellation-return-refund-policy
# /delivery-and-shipping-policy
# /ac-installation-by-reliance-resq
# https://wa.me/917000370003
# tel:+9118008901222
# https://play.google.com/store/apps/details?id=com.jpl.jiomart
# https://apps.apple.com/in/app/jiomart/id1522085683
# https://www.jiomart.com/privacy-policy
# https://account.relianceretail.com/privacy-policy/

# %%
img=soup.find_all("img")
img
# Out:
# [<img alt="JioMart" src="https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24"/>,
#  <img alt="" class="" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-icon.svg"/>,
#  <img alt="location icon" class="jm-mr-base" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-dark.svg"/>,
#  <img alt="detect location icon" class="jm-mr-s" src="https://www.jiomart.com/assets/ds2web/jds-icons/detect-dark.svg"/>,
#  <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/location-gray-icon.svg"/>,
#  <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-web-search.svg"/>,
#  <img alt="" src="https://www.jiomart.com/assets/ds2web/jds-icons/ds-list-icon.svg"/>,
#  <img alt="" class="icon" src="/assets/ds2web/jds-icons/close-icon.svg"/>,
#  <img alt="" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/cart-icon.svg"/>,
#  <img alt="Jiomart user sign in" class="jiomart-user-ds" id="jm_header_user_icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/new-ds2-profile-icon.svg"/>,
#  <img alt="go back" src="https://www.jiomart.com/assets/ds2web/jds-icons/angle-left-icon.svg"/>,
#  <img alt="home" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/home-icon.svg"/>,
#  <img alt="shop by category" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/category-icon.svg"/>,
#  <img alt="my orders" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-order-icon.svg"/>,
#  <img alt="my list view" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-viewicon.svg"/>,
#  <img alt="wishlist icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wishlist-icon.svg"/>,
#  <img alt="wallet icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/wallet-icon.svg"/>,
#  <img alt="offer store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/offer-store-icon.svg"/>,
#  <img alt="coupon store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/my-list-newicon.svg"/>,
#  <img alt="gift store" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/gift-store-icon.svg"/>,
#  <img alt="faq need help icon" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/faqs-icon.svg"/>,
#  <img alt="about us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/about-us-icon.svg"/>,
#  <img alt="contact us" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/contact-us-icon.svg"/>,
#  <img alt="guide" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/guide-icon.svg"/>,
#  <img alt="caution notice" class="icon jm-mr-xs" loading="lazy" src="/assets/ds2web/jds-icons/caution-notice.svg"/>,
#  <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/google-play-icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/google-play-icon.svg"/>,
#  <img alt="" class="lazyload" data-src="/assets/ds2web/jds-icons/ios_app_icon.svg" loading="lazy" src="/assets/ds2web/jds-icons/ios_app_icon.svg"/>,
#  <img alt="Top Deals_mpc_iphone16hpmc" class="banner_img" data-src="" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)" title="Top Deals_mpc_iphone16hpmc"/>,
#  <img alt="Top Deals_mpc_oppok12hpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729744481_OppoK12x5G.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729744481_OppoK12x5G.jpg?im=Resize=(384,224)" title="Top Deals_mpc_oppok12hpmc"/>,
#  <img alt="Top Deals_fnl_dhanterashpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729745929_Gold__Silver_coins_.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729745929_Gold__Silver_coins_.jpg?im=Resize=(384,224)" title="Top Deals_fnl_dhanterashpmc"/>,
#  <img alt="Top Deals_gro_kajuburfihpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729619744_Kaju_Barfi.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729619744_Kaju_Barfi.jpg?im=Resize=(384,224)" title="Top Deals_gro_kajuburfihpmc"/>,
#  <img alt="Top Deals_gmo_kitchendininghpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729247149_Kitchen_Dining_Upgrade.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729247149_Kitchen_Dining_Upgrade.jpg?im=Resize=(384,224)" title="Top Deals_gmo_kitchendininghpmc"/>,
#  <img alt="Top Deals_fnl_festivewearmenhpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729784329_Festive_Mens_Wear.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729784329_Festive_Mens_Wear.jpg?im=Resize=(384,224)" title="Top Deals_fnl_festivewearmenhpmc"/>,
#  <img alt="Top Deals_sta_dryfruitshpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729589388_DryFruit.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589388_DryFruit.jpg?im=Resize=(384,224)" title="Top Deals_sta_dryfruitshpmc"/>,
#  <img alt="Top Deals_nfc_sweetshpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729589353_sweets.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589353_sweets.jpg?im=Resize=(384,224)" title="Top Deals_nfc_sweetshpmc"/>,
#  <img alt="Top Deals_nfc_householdcleaninghpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729228829_Household__Cleaning.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729228829_Household__Cleaning.jpg?im=Resize=(384,224)" title="Top Deals_nfc_householdcleaninghpmc"/>,
#  <img alt="Top Deals_gro_stockupfordiwalihpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729589420_StockUpForDiwali.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589420_StockUpForDiwali.jpg?im=Resize=(384,224)" title="Top Deals_gro_stockupfordiwalihpmc"/>,
#  <img alt="Top Deals_fmc_diwaligiftinghpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729511377_DiwaliGifting_.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729511377_DiwaliGifting_.jpg?im=Resize=(384,224)" title="Top Deals_fmc_diwaligiftinghpmc"/>,
#  <img alt="Top Deals_mpc_laptophpmc" class="lazyload banner_img" data-src="https://www.jiomart.com/images/cms/aw_rbslider/slides/1729784504_Lowest_Prices_Ever.jpg?im=Resize=(768,448)" src="https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729784504_Lowest_Prices_Ever.jpg?im=Resize=(384,224)" title="Top Deals_mpc_laptophpmc"/>,
#  <img alt="teaser banner" class="lazyload" data-src="https://www.jiomart.com/images/cms/section/images/1727416484_desktop.jpg?im=Resize=(2368,400)" src="https://www.jiomart.com/images/cms/section/images/1727416484_desktop.jpg?im=Resize=(1184,160)"> <h1></h1> <div class="teaser-content"> <div class="timer"> <p id="section_15486_days"></p> <span>Days</span> </div> <div class="ds2-dots"> <span class="timer-dots"> </span> <span class="timer-dots"> </span> </div> <div class="timer"> <p id="section_15486_hours"></p> <span>Hrs</span> </div> <div class="ds2-dots"> <span class="timer-dots"> </span> <span class="timer-dots"> </span> </div> <div class="timer"> <p id="section_15486_minutes"></p> <span>Min</span> </div> <div class="ds2-dots"> <span class="timer-dots"> </span> <span class="timer-dots"> </span> </div> <div class="timer"> <p id="section_15486_seconds"></p> <span>Sec</span> </div> </div> </img>,
#  <img alt="" src="https://www.jiomart.com/assets/ds2web/images/icons/slider-prev-ds2.svg"/>,
#  <img alt="Apple iPhone 16 256 GB, Black" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494423018/apple-iphone-16-256-gb-black-digital-o494423018-p609946228-0-202409111651.jpeg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494423018/apple-iphone-16-256-gb-black-digital-o494423018-p609946228-0-202409111651.jpeg?im=Resize=(50,50)" title="Apple iPhone 16 256 GB, Black"> </img>,
#  <img alt="Skybags GRAF PLUS 01 LAPTOP BACKPACK (E) BLACK" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494241521/skybags-graf-plus-black-laptop-backpack-product-images-o494241521-p605537653-0-202310101430.jpg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494241521/skybags-graf-plus-black-laptop-backpack-product-images-o494241521-p605537653-0-202310101430.jpg?im=Resize=(50,50)" title="Skybags GRAF PLUS 01 LAPTOP BACKPACK (E) BLACK"> </img>,
#  <img alt="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone" class="lazyload" data-sizes="auto" data-src="https://www.jiomart.com//images/product/original/494422937/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone-digital-o494422937-p609971944-0-202409161631.jpeg?im=Resize=(310,310)" onerror="this.src='/assets/global/jiomart-default-image.png'" src="https://www.jiomart.com//images/product/original/494422937/realme-narzo-n65-5g-128-gb-4-gb-ram-amber-gold-mobile-phone-digital-o494422937-p609971944-0-202409161631.jpeg?im=Resize=(50,50)" title="Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Ph
://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729227803_Furniture_Bestsellers2x.jpg?im=Resize=(184,226)" title="Top Deals_gmo_furniturest"/>,
#  <img alt="down icon" height="24" src="../../../../../../assets/ds2msite/jds-icons/angle-up-icon.svg" width="24"/>,
#  <img alt="" src="/assets/ds2web/jds-icons/google-play-icon.svg"> </img>,
#  <img alt="" src="/assets/ds2web/jds-icons/ios_app_icon.svg"> </img>,
#  <img class="jm-mr-s" src="/assets/ds2web/jds-icons/jiomart-logo-icon.svg">© 2024 All rights reserved. Reliance Retail Ltd.</img>,
#  <img alt="close icon" class="icon" src="https://www.jiomart.com/assets/ds2web/jds-icons/close-icon.svg"> </img>]

# %%
for i in img:
    print(i.get("src"))
# Out:
# https://www.jiomart.com/assets/ds2web/images/Jiomart-logo-ds2.0.svg?v=24
# https://www.jiomart.com/assets/ds2web/jds-icons/location-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/location-dark.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/detect-dark.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/location-gray-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/ds-web-search.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/ds-list-icon.svg
# /assets/ds2web/jds-icons/close-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/cart-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/new-ds2-profile-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/angle-left-icon.svg
# /assets/ds2web/jds-icons/home-icon.svg
# /assets/ds2web/jds-icons/category-icon.svg
# /assets/ds2web/jds-icons/my-order-icon.svg
# /assets/ds2web/jds-icons/my-list-viewicon.svg
# /assets/ds2web/jds-icons/wishlist-icon.svg
# /assets/ds2web/jds-icons/wallet-icon.svg
# /assets/ds2web/jds-icons/offer-store-icon.svg
# /assets/ds2web/jds-icons/my-list-newicon.svg
# /assets/ds2web/jds-icons/gift-store-icon.svg
# /assets/ds2web/jds-icons/faqs-icon.svg
# /assets/ds2web/jds-icons/about-us-icon.svg
# /assets/ds2web/jds-icons/contact-us-icon.svg
# /assets/ds2web/jds-icons/guide-icon.svg
# /assets/ds2web/jds-icons/caution-notice.svg
# /assets/ds2web/jds-icons/google-play-icon.svg
# /assets/ds2web/jds-icons/ios_app_icon.svg
# https://www.jiomart.com/images/cms/aw_rbslider/slides/1729837311_Price_Drop_Alert.jpg?im=Resize=(768,448)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729744481_OppoK12x5G.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729745929_Gold__Silver_coins_.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729619744_Kaju_Barfi.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729247149_Kitchen_Dining_Upgrade.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729784329_Festive_Mens_Wear.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589388_DryFruit.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589353_sweets.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729228829_Household__Cleaning.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729589420_StockUpForDiwali.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729511377_DiwaliGifting_.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729784504_Lowest_Prices_Ever.jpg?im=Resize=(384,224)
# https://www.jiomart.com/images/cms/section/images/1727416484_desktop.jpg?im=Resize=(1184,160)
# https://www.jiomart.com/assets/ds2web/images/icons/slider-prev-ds2.svg
# https://www.jiomart.com//images/product/original/494423018/apple-iphone-16-256-gb-black-digital-o494423018-p609946228-0-202409111651.jpeg?im=Resize=(50,50)
# https://www.jiomart.com//images/product/original

# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729227869_Womens_Accessories2x.jpg?im=Resize=(184,226)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729400078_Acs_and_Washinh_Machine.jpg?im=Resize=(184,226)
# https://www.jiomart.com/images/cms/aw_rbslider/slides/50/1729227803_Furniture_Bestsellers2x.jpg?im=Resize=(184,226)
# ../../../../../../assets/ds2msite/jds-icons/angle-up-icon.svg
# /assets/ds2web/jds-icons/google-play-icon.svg
# /assets/ds2web/jds-icons/ios_app_icon.svg
# /assets/ds2web/jds-icons/jiomart-logo-icon.svg
# https://www.jiomart.com/assets/ds2web/jds-icons/close-icon.svg

# %%
for i in img:
    print(i.get("alt"))
# Out:
# JioMart
#
# location icon
# detect location icon
#
#
#
#
#
# Jiomart user sign in
# go back
# home
# shop by category
# my orders
# my list view
# wishlist icon
# wallet icon
# offer store
# coupon store
# gift store
# faq need help icon
# about us
# contact us
# guide
# caution notice
#
#
# Top Deals_mpc_iphone16hpmc
# Top Deals_mpc_oppok12hpmc
# Top Deals_fnl_dhanterashpmc
# Top Deals_gro_kajuburfihpmc
# Top Deals_gmo_kitchendininghpmc
# Top Deals_fnl_festivewearmenhpmc
# Top Deals_sta_dryfruitshpmc
# Top Deals_nfc_sweetshpmc
# Top Deals_nfc_householdcleaninghpmc
# Top Deals_gro_stockupfordiwalihpmc
# Top Deals_fmc_diwaligiftinghpmc
# Top Deals_mpc_laptophpmc
# teaser banner
#
# Apple iPhone 16 256 GB, Black
# Skybags GRAF PLUS 01 LAPTOP BACKPACK (E) BLACK
# Realme Narzo N65 5G 128 GB, 4 GB RAM, Amber Gold, Mobile Phone
# Bangalore Refinery 999 Silver Bar 100g
# Shree Misthan Kaju Katli 400g (200g X 2) (Kaju Barfi / Kaju Burfi / Kaju Katri | Indian Mithai / Festive Sweets Gift Pack / Box | Diwali Sweet Gifts)
# Moti Sandal Luxury Bath Soap 150 g
# Haldiram Bhujiawala Bhujia Namkeen Snacks For Satisfying Hunger- 800 gm
# Dimpy Stuff Soft Toy for Girls, Boys & Kids| Lion Plush Toy | Adorable Gift | Yellow 25cm
# Lzard Men Blue Slim Stretch Jeans
# Indiyum Kaju Dodha Burfi | Treditional Indian Sweets | Classic Dodha Burfi Made Special with Kaju & Nuts 200g
# Alibaba Supreme Seven Star 7 Jar Wonder 750 Mixer Grinder (7 Jars, White, Blue)
# Good Life Utsava Assorted Diwali Healthy Treats Dry Fruits Gift Pack 300 g
# Aakash Gulab Jamun And Rasgulla Combo 1kg Each (Pack Of 2)
# Rush Note Books A4 Size 200 Pages Spiral Notebook Unruled - Spiral Register note books Unruled
# Aadi Men's Black Mesh Running Sport Shoes
# Active White Detergent Powder - 10 kg Family Pack
# Realme Buds T110 with AI ENC for calls, upto 38 hours of Playback and Fast Charging Bluetooth Headset  (Punk Black, True Wireless)
# Aer Matic Violet Valley Bloom Diffuser Machine + Refill 225 ml
# Joy Honey and Almonds Nourishing Body Lotion, 300ml (Pack of 2)
# Panchami Deepam Oil Pouch 1 L
#
# Top Deals_naa_handpicked offers header_web
# Top Deals_fnl_menfootwearst
# Top Deals_mpc_oppok12st
# Top Deals_gmo_cyclest
# Top Deals_gro_cookingessentialsst
# Top Deals_fnl_womenaccessoriesst
# Top Deals_apn_acwashingmachinest
# Top Deals_gmo_furniturest
# down icon
#
#
# None
# close icon

# %%
text=soup.find_all("div")
for i in text:
    print(i.text)
# Out:
#            Deliver to         Select Delivery Location   Sign in or set delivery location to see product availability, offers and discounts.      Sign In to select address            Enter a pincode      Detect My Location         Enter PIN Code   Enter PIN code to see product availability, offers and discounts.              PIN Code    Apply                           Try something new        Most trending categories           Shopping List          Search multiple products by entering your shopping list below.    Add comma as separator    Enter Item List       Clear     Search All                   Cart Items  Item(s)       Total amount to be paid ₹      Proceed to Cart          Sign In
#
#    Deliver to         Select Delivery Location   Sign in or set delivery location to see product availability, offers and discounts.      Sign In to select address            Enter a pincode      Detect My Location         Enter PIN Code   Enter PIN code to see product availability, offers and discounts.              PIN Code    Apply
#      Select Delivery Location   Sign in or set delivery location to see product availability, offers and discounts.      Sign In to select address            Enter a pincode      Detect My Location         Enter PIN Code   Enter PIN code to see product availability, offers and discounts.              PIN Code    Apply
#    Select Delivery Location   Sign in or set delivery location to see product availability, offers and discounts.      Sign In to select address            Enter a pincode      Detect My Location
#   Select Delivery Location   Sign in or set delivery location to see product availability, offers and discounts.
#  Select Delivery Location
#  Sign in or set delivery location to see product availability, offers and discounts.
#    Sign In to select address
#
#
#     Enter a pincode      Detect My Location
#    Enter a pincode
#    Detect My Location
#
#    Enter PIN Code   Enter PIN code to see product availability, offers and discounts.              PIN Code    Apply
#   Enter PIN Code   Enter PIN code to see product availability, offers and discounts.
#  Enter PIN Code
#  Enter PIN code to see product availability, offers and discounts.
#           PIN Code    Apply
#          PIN Code
#         PIN Code
#
#
#  Apply
#
#
#                Try something new        Most trending categories           Shopping List          Search multiple products by entering your shopping list below.    Add comma as separator    Enter Item List       Clear     Search All
#
#
#      Try something new        Most trending categories
#  Try something new
#
# Most trending categories
#
#
#    Shopping List          Search multiple products by entering your shopping list below.    Add comma as separator    Enter Item List       Clear     Search All
#  Shopping List
# Shopping List
#
#   Search multiple products by entering your shopping list below.    Add comma as separator    Enter Item List
#  Search multiple products by entering your shopping list below.
#   Add comma as separator    Enter Item List
#  Add comma as separator
#   Enter Item List
#    Clear     Search All
#   Clear
#   Search All
#
#           Cart Items  Item(s)       Total amount to be paid ₹      Proceed to Cart          Sign In
#          Cart Items  Item(s)       Total amount to be paid ₹      Proceed to Cart
#
#    Cart Items  Item(s)       Total amount to be paid ₹      Proceed to Cart
#  Cart Items  Item(s)
# Cart Items
#  Item(s)
#      Total amount to be paid ₹
#
#  Total amount to be paid ₹
# Total amount to be paid
# ₹
#
#   Proceed to Cart
#
#        All Categories
#    All Categories
#            Hello!            Home    Shop By Category     My Account    My Orders     My List    Wishlist      JioMart Wallet     Offers & More    Offer Store    Coupon Store    Gift Store     Help & Support    FAQs/Need Help    About Us    Contact Us    Guide    Caution Notice       Download the App         Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on cs@jiomart.com
#           Hello!            Home    Shop By Category     My Account    My Orders     My List    Wishlist      JioMart Wallet     Offers & More    Offer Store    Coupon Store    Gift Store     Help & Support    FAQs/Need Help    About Us    Contact Us    Guide    Caution Notice       Download the App         Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on cs@jiomart.com
#          Hello!
#        Hello!
#
#  Hello!
#
#      Home    Shop By Category     My Account    My Orders     My List    Wishlist      JioMart Wallet     Offers & More    Offer Store    Coupon Store    Gift Store     Help & Support    FAQs/Need Help    About Us    Contact Us    Guide    Caution Notice
#     Home    Shop By Category
#  My Account    My Orders     My List    Wishlist      JioMart Wallet
# My Account
#  Offers & More    Offer Store    Coupon Store    Gift Store
# Offers & More
#  Help & Support    FAQs/Need Help    About Us    Contact Us    Guide    Caution Notice
# Help & Support
#   Download the App         Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on cs@jiomart.com
#  Download the App
# Download the App
#
#  Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on cs@jiomart.com
# Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website, please email us on cs@jiomart.com
#                                                                                                   Days          Hrs          Min          Sec                           Limited Time Deals  *Refreshes at 12 AM    View All                          Apple iPhone 16 256 GB, Black      ₹85,990.00    ₹89,900.00    4% OFF                             Skybags GRAF PLUS 01 LAPTOP BACKPAC..      ₹599.00    ₹2,200.00    72% OFF          Add                           Realme Narzo N65 5G 128 GB, 4 GB RA..      ₹9,799.00    ₹13,999.00    30% OFF                             Bangalore Refinery 999 Silver Bar 1..      ₹10,787.00    ₹13,000.00    17% OFF                              Shree Misthan Kaju Katli 400g (200g..      ₹249.00    ₹520.00    52% OFF          Add                           Moti Sandal Luxury Bath Soap 150 g      ₹57.00    ₹75.00    24% OFF          Add                            Haldiram Bhujiawala Bhujia Namkeen..      ₹149.00    ₹222.00    32% OFF          Add                           Dimpy Stuff Soft Toy for Girls, Boy..      ₹155.00    ₹499.00    68% OFF          Add                           Lzard Men Blue Slim Stretch Jeans      ₹319.00    ₹2,299.00    86% OFF                              Indiyum Kaju Dodha Burfi | Treditio..      ₹95.00    ₹250.00    62% OFF          Add                           Alibaba Supreme Seven Star 7 Jar Wo..      ₹1,469.00    ₹9,999.00    85% OFF                              Good Life Utsava Assorted Diwali He..      ₹324.00    ₹649.00    50% OFF          Add                            Aakash Gulab Jamun And Rasgulla Com..      ₹299.00    ₹460.00    35% OFF          Add                           Rush Note Books A4 Size 200 Pages S..      ₹99.00    ₹150.00    34% OFF          Add                           Aadi Men's Black Mesh Running Sport..      ₹219.00    ₹999.00    78% OFF                             Active White Detergent Powder - 10..      ₹379.00    ₹500.00    24% OFF          Add                           Realme Buds T110 with AI ENC for ca..      ₹1,099.00    ₹2,999.00    63% OFF                             Aer Matic Violet Valley Bloom Diffu..      ₹419.00    ₹625.00    32% OFF          Add                           Joy Honey and Almonds Nourishing Bo..      ₹290.00    ₹580.00    50% OFF          Add                           Panchami Deepam Oil Pouch 1 L      ₹139.00    ₹250.00    44% OFF          Add
#        Limited Time Deals  *Refreshes at 12 AM    View All
#
#   Limited Time Deals  *Refreshes at 12 AM    View All
#  Limited Time Deals
# *Refreshes at 12 AM
#   View All
#                      Apple iPhone 16 256 GB, Black      ₹85,990.00    ₹89,900.00    4% OFF
#
#
#
#
#
#    Apple iPhone 16 256 GB, Black      ₹85,990.00    ₹89,900.00    4% OFF
#  Apple iPhone 16 256 GB, Black
#   ₹85,990.00    ₹89,900.00    4% OFF
# ₹85,990.00
#   ₹89,900.00    4% OFF
#                      Skybags GRAF PLUS 01 LAPTOP BACKPAC..      ₹599.00    ₹2,200.00    72% OFF          Add
#
#
#
#
#
#    Skybags GRAF PLUS 01 LAPTOP BACKPAC..      ₹599.00    ₹2,200.00    72% OFF
#  Skybags GRAF PLUS 01 LAPTOP BACKPAC..
#   ₹599.00    ₹2,200.00    72% OFF
# ₹599.00
#   ₹2,200.00    72% OFF
#   Add
#                      Realme Narzo N65 5G 128 GB, 4 GB RA..      ₹9,799.00    ₹13,999.00    30% OFF
#
#
#
#
#
#    Realme Narzo N65 5G 128 GB, 4 GB RA..      ₹9,799.00    ₹13,999.00    30% OFF
#  Realme Narzo N65 5G 128 GB, 4 GB RA..
#   ₹9,799.00    ₹13,999.00    30% OFF
# ₹9,799.00
#   ₹13,999.00    30% OFF
#                      Bangalore Refinery 999 Silver Bar 1..      ₹10,787.00    ₹13,000.00    17% OFF
#
#
#
#
#
#    Bangalore Refinery 999 Silver Bar 1..      ₹10,787.00    ₹13,000.00    17% OFF
#  Bangalore Refinery 999 Silver Bar 1..
#   ₹10,787.00    ₹13,000.00    17% OFF
# ₹10,787.00
#   ₹13,000.00    17% OFF
#                       Shree Misthan Kaju Katli 400g (200g..      ₹249.00    ₹520.00    52% OFF          Add
#
#
#
#
#
#    Shree Misthan Kaju Katli 400g (200g..      ₹249.00    ₹520.00    52% OFF
#  Shree Misthan Kaju Katli 400g (200g..
#   ₹249.00    ₹520.00    52% OFF
# ₹249.00
#   ₹520.00    52% OFF
#   Add
#                      Moti Sandal Luxury Bath Soap 150 g      ₹57.00    ₹75.00    24% OFF          Add
#
#
#
#
#
#    Moti Sandal Luxury Bath Soap 150 g      ₹57.00    ₹75.00    24% OFF
#  Moti Sandal Luxury Bath Soap 150 g
#   ₹57.00    ₹75.00    24% OFF
# ₹57.00
#   ₹75.00    24% OFF
#   Add
#                       Haldiram Bhujiawala Bhujia Namkeen..      ₹149.00    ₹222.00    32% OFF          Add
#
#
#
#
#
#    Haldiram Bhujiawala Bhujia Namkeen..      ₹149.00    ₹222.00    32% OFF
#  Haldiram Bhujiawala Bhujia Namkeen..
#   ₹149.00    ₹222.00    32% OFF
# ₹149.00
#   ₹222.00    32% OFF
#   Add
#                      Dimpy Stuff Soft Toy for Girls, Boy..      ₹155.00    ₹499.00    68% OFF          Add
#
#
#
#
#
#    Dimpy Stuff Soft Toy for Girls, Boy..      ₹155.00    ₹499.00    68% OFF
#  Dimpy Stuff Soft Toy for Girls, Boy..
#   ₹155.00    ₹499.00    68% OFF
# ₹155.00
#   ₹499.00    68% OFF
#   Add
#                      Lzard Men Blue Slim Stretch Jeans      ₹319.00    ₹2,299.00    86% OFF
#
#
#
#
#
#    Lzard Men Blue Slim Stretch Jeans      ₹319.00    ₹2,299.00    86% OFF
#  Lzard Men Blue Slim Stretch Jeans
#   ₹319.00    ₹2,299.00    86% OFF
# ₹319.00
#   ₹2,299.00    86% OFF
#                       Indiyum Kaju Dodha Burfi | Treditio..      ₹95.00    ₹250.00    62% OFF          Add
#
#
#
#
#
#    Indiyum Kaju Dodha Burfi | Treditio..      ₹95.00    ₹250.00    62% OFF
#  Indiyum Kaju Dodha Burfi | Treditio..
#   ₹95.00    ₹250.00    62% OFF
# ₹95.00
#   ₹250.00    62% OFF
#   Add
#                      Alibaba Supreme Seven Star 7 Jar Wo..      ₹1,469.00    ₹9,999.00    85% OFF
#
#
#
#
#
#    Alibaba Supreme Seven Star 7 Jar Wo..      ₹1,469.00    ₹9,999.00    85% OFF
#  Alibaba Supreme Seven Star 7 Jar Wo..
#   ₹1,469.00    ₹9,999.00    85% OFF
# ₹1,469.00
#   ₹9,999.00    85% OFF
#                       Good Life Utsava Assorted Diwali He..      ₹324.00    ₹649.00    50% OFF          Add
#
#
#
#
#
#    Good Life Utsava Assorted Diwali He..      ₹324.00    ₹649.00    50% OFF
#  Good Life Utsava Assorted Diwali He..
#   ₹324.00    ₹649.00    50% OFF
# ₹324.00
#   ₹649.00    50% OFF
#   Add
#                       Aakash Gulab Jamun And Rasgulla Com..      ₹299.00    ₹460.00    35% OFF          Add
#
#
#
#
#
#    Aakash Gulab Jamun And Rasgulla Com..      ₹299.00    ₹460.00    35% OFF
#  Aakash Gulab Jamun And Rasgulla Com..
#   ₹299.00    ₹460.00    35% OFF
# ₹299.00
#   ₹460.00    35% OFF
#   Add
#                      Rush Note Books A4 Size 200 Pages S..      ₹99.00    ₹150.00    34% OFF          Add
#
#
#
#
#
#    Rush Note Books A4 Size 200 Pages S..      ₹99.00    ₹150.00    34% OFF
#  Rush Note Books A4 Size 200 Pages S..
#   ₹99.00    ₹150.00    34% OFF
# ₹99.00
#   ₹150.00    34% OFF
#   Add
#                      Aadi Men's Black Mesh Running Sport..      ₹219.00    ₹999.00    78% OFF
#
#
#
#
#
#    Aadi Men's Black Mesh Running Sport..      ₹219.00    ₹999.00    78% OFF
#  Aadi Men's Black Mesh Running Sport..
#   ₹219.00    ₹999.00    78% OFF
# ₹219.00
#   ₹999.00    78% OFF
#                      Active White Detergent Powder - 10..      ₹379.00    ₹500.00    24% OFF          Add
#
#
#
#
#
#    Active White Detergent Powder - 10..      ₹379.00    ₹500.00    24% OFF
#  Active White Detergent Powder - 10..
#   ₹379.00    ₹500.00    24% OFF
# ₹379.00
#   ₹500.00    24% OFF
#   Add
#                      Realme Buds T110 with AI ENC for ca..      ₹1,099.00    ₹2,999.00    63% OFF
#
#
#
#
#
#    Realme Buds T110 with AI ENC for ca..      ₹1,099.00    ₹2,999.00    63% OFF
#  Realme Buds T110 with AI ENC for ca..
#   ₹1,099.00    ₹2,999.00    63% OFF
# ₹1,099.00
#   ₹2,999.00    63% OFF
#                      Aer Matic Violet Valley Bloom Diffu..      ₹419.00    ₹625.00    32% OFF          Add
#
#
#
#
#
#    Aer Matic Violet Valley Bloom Diffu..      ₹419.00    ₹625.00    32% OFF
#  Aer Matic Violet Valley Bloom Diffu..
#   ₹419.00    ₹625.00    32% OFF
# ₹419.00
#   ₹625.00    32% OFF
#   Add
#                      Joy Honey and Almonds Nourishing Bo..      ₹290.00    ₹580.00    50% OFF          Add
#
#
#
#
#
#    Joy Honey and Almonds Nourishing Bo..      ₹290.00    ₹580.00    50% OFF
#  Joy Honey and Almonds Nourishing Bo..
#   ₹290.00    ₹580.00    50% OFF
# ₹290.00
#   ₹580.00    50% OFF
#   Add
#                      Panchami Deepam Oil Pouch 1 L      ₹139.00    ₹250.00    44% OFF          Add
#
#
#
#
#
#    Panchami Deepam Oil Pouch 1 L      ₹139.00    ₹250.00    44% OFF
#  Panchami Deepam Oil Pouch 1 L
#   ₹139.00    ₹250.00    44% OFF
# ₹139.00
#   ₹250.00    44% OFF
#   Add
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   JioMart: Your Go-to Online Grocery Store
#  JioMart: Your Go-to Online Grocery Store
#
#     All Categories  Grocery   Electronics   Fashion  Home & Lifestyle   Premium Fruits   Books   Furniture    Popular Categories  Biscuits, Drinks & Packaged Foods   Fruits & Vegetables   Cooking Essentials   Dairy & Bakery   Personal Care   Beauty   Home Care   Mom & Baby Care   School, Office & Stationery    Customer Account  My Account   My Orders   Wishlist   Delivery Addresses   JioMart Wallet    Help & Support  About Us   FAQ   Terms & Conditions   Privacy Policy   E-waste Policy   Cancellation & Return Policy   Shipping & Delivery Policy   AC Installation by resQ      Contact Us  WhatsApp us:  70003 70003 Call us: 1800 890 1222 8:00 AM to 8:00 PM, 365 days   Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website.   Download the app
#    All Categories  Grocery   Electronics   Fashion  Home & Lifestyle   Premium Fruits   Books   Furniture    Popular Categories  Biscuits, Drinks & Packaged Foods   Fruits & Vegetables   Cooking Essentials   Dairy & Bakery   Personal Care   Beauty   Home Care   Mom & Baby Care   School, Office & Stationery    Customer Account  My Account   My Orders   Wishlist   Delivery Addresses   JioMart Wallet    Help & Support  About Us   FAQ   Terms & Conditions   Privacy Policy   E-waste Policy   Cancellation & Return Policy   Shipping & Delivery Policy   AC Installation by resQ      Contact Us  WhatsApp us:  70003 70003 Call us: 1800 890 1222 8:00 AM to 8:00 PM, 365 days   Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website.   Download the app
#   All Categories  Grocery   Electronics   Fashion  Home & Lifestyle   Premium Fruits   Books   Furniture    Popular Categories  Biscuits, Drinks & Packaged Foods   Fruits & Vegetables   Cooking Essentials   Dairy & Bakery   Personal Care   Beauty   Home Care   Mom & Baby Care   School, Office & Stationery    Customer Account  My Account   My Orders   Wishlist   Delivery Addresses   JioMart Wallet    Help & Support  About Us   FAQ   Terms & Conditions   Privacy Policy   E-waste Policy   Cancellation & Return Policy   Shipping & Delivery Policy   AC Installation by resQ
#  All Categories  Grocery   Electronics   Fashion  Home & Lifestyle   Premium Fruits   Books   Furniture
# All Categories
#  Grocery
#  Electronics
#  Fashion
# Home & Lifestyle
#  Premium Fruits
#  Books
#  Furniture
#  Popular Categories  Biscuits, Drinks & Packaged Foods   Fruits & Vegetables   Cooking Essentials   Dairy & Bakery   Personal Care   Beauty   Home Care   Mom & Baby Care   School, Office & Stationery
# Popular Categories
#  Biscuits, Drinks & Packaged Foods
#  Fruits & Vegetables
#  Cooking Essentials
#  Dairy & Bakery
#  Personal Care
#  Beauty
#  Home Care
#  Mom & Baby Care
#  School, Office & Stationery
#  Customer Account  My Account   My Orders   Wishlist   Delivery Addresses   JioMart Wallet
# Customer Account
#  My Account
#  My Orders
#  Wishlist
#  Delivery Addresses
#  JioMart Wallet
#  Help & Support  About Us   FAQ   Terms & Conditions   Privacy Policy   E-waste Policy   Cancellation & Return Policy   Shipping & Delivery Policy   AC Installation by resQ
# Help & Support
#  About Us
#  FAQ
#  Terms & Conditions
#  Privacy Policy
#  E-waste Policy
#  Cancellation & Return Policy
#  Shipping & Delivery Policy
#  AC Installation by resQ
#   Contact Us  WhatsApp us:  70003 70003 Call us: 1800 890 1222 8:00 AM to 8:00 PM, 365 days   Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website.   Download the app
#  Contact Us  WhatsApp us:  70003 70003 Call us: 1800 890 1222 8:00 AM to 8:00 PM, 365 days   Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website.
# Contact Us
#  WhatsApp us:  70003 70003 Call us: 1800 890 1222 8:00 AM to 8:00 PM, 365 days
# WhatsApp us:  70003 70003
# Call us: 1800 890 1222
# 8:00 AM to 8:00 PM, 365 days
# Should you encounter any bugs, glitches, lack of functionality, delayed deliveries, billing errors or other problems on the website.
#  Download the app
# Download the app
#
#
#   © 2024 All rights reserved. Reliance Retail Ltd. Best viewed on Microsoft Edge 81+, Mozilla Firefox 75+, Safari 5.1.5+, Google Chrome 80+
#  © 2024 All rights reserved. Reliance Retail Ltd. Best viewed on Microsoft Edge 81+, Mozilla Firefox 75+, Safari 5.1.5+, Google Chrome 80+
# © 2024 All rights reserved. Reliance Retail Ltd.
# Best viewed on Microsoft Edge 81+, Mozilla Firefox 75+, Safari 5.1.5+, Google Chrome 80+
#        Policy Update Please note that our Privacy Policy. has been updated and we have also added Retail Account Privacy Policy. By continuing to use our platform and its services, you consent to the updated policies.  Agree
#
#      Policy Update Please note that our Privacy Policy. has been updated and we have also added Retail Account Privacy Policy. By continuing to use our platform and its services, you consent to the updated policies.  Agree
#
#  Policy Update Please note that our Privacy Policy. has been updated and we have also added Retail Account Privacy Policy. By continuing to use our platform and its services, you consent to the updated policies.  Agree
# Policy Update Please note that our Privacy Policy. has been updated and we have also added Retail Account Privacy Policy. By continuing to use our platform and its services, you consent to the updated policies.
# Please note that our Privacy Policy. has been updated and we have also added Retail Account Privacy Policy. By continuing to use our platform and its services, you consent to the updated policies.
# Agree
